# %% [markdown]
# # MAST Astroquery API

# %% [markdown]
# ## Table of Contents
#
# 1. [Module Design](#MAST-Astroquery-Module-Design)
# 2. [Imports](#Imports)
# 3. [Observations Class](#Observations-Class)
#     - [Searching for MAST observations](#Searching-for-MAST-observations)
#     - [Getting observation counts](#Getting-observation-counts)
#     - [Listing available missions](#Listing-available-missions)
#     - [Getting a list of data products](#Getting-a-list-of-data-products)
#     - [Downloading products](#Downloading-products) <br><br>
# 4. [Catalogs Class](#Catalogs-Class)
#     - [Query by position/object](#Query-by-position/object)
#     - [Query by criteria](#Query-by-criteria)
#     - [HSC Specific queries](#HSC-Specific-queries)<br><br>
# 5. [Proprietary Data Access](#Proprietary-Data-Access)
# 6. [Mast Class](#Mast-Class)

# %% [markdown]
# ## MAST Astroquery Module Design

# %% [markdown]
# ### MastClass:
# * <font color='#009402'>**service_request**</font>(<font color='#7800b9'>service, params, </font>\*\*kwargs): Astropy Table of mashup results
# * <font color='#009402'>**login**</font>(username, password, session_token, store_password, reenter_password)
# * <font color='#009402'>**logout**</font>()
# * <font color='#009402'>**get_token**</font>(): Session token cookie
# * <font color='#009402'>**session_info**</font>(silent): Dictionary of session info
#
# ### ObservationsClass(MastClass):
# * <font color='#009402'>**query_object**</font>(<font color='#7800b9'>objectname, </font>radius, pagesize, page): Astropy Table of observations
# * <font color='#009402'>**query_region**</font>({<font color='#7800b9'>coordinates,</font> radius, pagesize, page): Astropy Table of observations
# * <font color='#009402'>**query_criteria**</font>(pagesize, page, <font color='#7800b9'>**criteria</font>): Astropy Table of observations
#
# * <font color='#009402'>**query_object_count**</font>(<font color='#7800b9'>objectname,</font> radius): Number of observations
# * <font color='#009402'>**query_region_count**</font>(<font color='#7800b9'>coordinates,</font> radius): Number of observations
# * <font color='#009402'>**query_criteria_count**</font>(<font color='#7800b9'>**criteria</font>): Number of observations
#
# * <font color='#009402'>**get_product_list**</font>(<font color='#7800b9'>obsidOrRow</font>): Astropy Table of data products
# * <font color='#009402'>**filter_products**</font>(<font color='#7800b9'>products, **filters</font>): Astropy Table of data products
# * <font color='#009402'>**download_products**</font>(<font color='#7800b9'>obsidsOrProductRows,</font> downloadDir, mrpOnly, curlFlag, **filters): Astropy Table manifest of downloaded files
#
# * <font color='#009402'>**list_missions**</font>(): List of Available Missions
#
# ### CatalogClass(MastClass)
# * <font color='#009402'>**query_object**</font>(<font color='#7800b9'>objectname,</font> radius, catalog, pagesize, page): Astropy Table of catalog entries
# * <font color='#009402'>**query_region**</font>(<font color='#7800b9'>coordinates,</font> radius, catalog, pagesize, page): Astropy Table of catalog entries
# * <font color='#009402'>**query_criteria**</font>(<font color='#7800b9'>catalog</font>, pagesize, page, <font color='#7800b9'>**criteria</font>): Astropy Table of catalog entries
# * <font color='#009402'>**query_hsc_matchid**</font>(<font color='#7800b9'>matchid,</font> pagesize, page): Astropy Table of catalog entries
# * <font color='#009402'>**get_hsc_spectra**</font>(pagesize, page): Astropy Table of hsc spectra
# * <font color='#009402'>**download_hsc_spectra**</font>(<font color='#7800b9'>spectra</font>)Astropy Table manifest of downloaded files
# * <font color='#c52700'>**list_catalogs**</font>(): List of Available Catalogs

# %% [markdown]
# ## Imports
# <div style="text-align: right">[(top)](#MAST-Astroquery-API)</div>

# %%
from astroquery.mast import Mast
from astroquery.mast import Observations
from astroquery.mast import Catalogs

# %% [markdown]
# ## Observations Class
# <div style="text-align: right">[(top)](#MAST-Astroquery-API)</div>

# %% [markdown]
# ### Searching for MAST observations
# <div style="text-align: right">[(top)](#MAST-Astroquery-API)</div>

# %%
caomObservations = Observations.query_region("322.49324 12.16683", radius="0.4 deg")
print("Number of results:",len(caomObservations))
print(caomObservations[:10])
# Out:
# Number of results: 1699
# dataproduct_type obs_collection instrument_name ...    objID    distance
# ---------------- -------------- --------------- ... ----------- --------
#             cube          SWIFT            UVOT ... 15000288230      0.0
#             cube          SWIFT            UVOT ... 15000722047      0.0
#             cube          SWIFT            UVOT ... 15000436293      0.0
#             cube          SWIFT            UVOT ... 15000288232      0.0
#             cube          SWIFT            UVOT ... 15000501726      0.0
#             cube          SWIFT            UVOT ... 15000501728      0.0
#             cube          SWIFT            UVOT ... 15000278604      0.0
#             cube          SWIFT            UVOT ... 15000373400      0.0
#             cube          SWIFT            UVOT ... 15000455063      0.0
#             cube          SWIFT            UVOT ... 15000455065      0.0

# %%
m8Observations = Observations.query_object("M8",radius=".02 deg")
print("Number of results:",len(m8Observations))
print(m8Observations[:10])
# Out:
# Number of results: 220
# dataproduct_type obs_collection instrument_name ...   objID       distance
# ---------------- -------------- --------------- ... ---------- -------------
#             cube             K2          Kepler ... 9500243833 39.4914065162
#         spectrum            IUE             LWP ... 3000061114           0.0
#         spectrum            IUE             LWP ... 3000061117           0.0
#         spectrum            IUE             LWP ... 3000061118           0.0
#         spectrum            IUE             LWR ... 3000013903           0.0
#         spectrum            IUE             LWR ... 3000017101           0.0
#         spectrum            IUE             LWR ... 3000018362           0.0
#         spectrum            IUE             LWR ... 3000018363           0.0
#         spectrum            IUE             LWR ... 3000020326           0.0
#         spectrum            IUE             LWR ... 3500030260           0.0

# %%
ostenObservations = Observations.query_criteria(dataproduct_type=["image"], proposal_pi="Osten", s_dec=[43.5,45.5])
print(ostenObservations)
# Out:
# dataproduct_type calib_level obs_collection ... intentType   obsid      objID
# ---------------- ----------- -------------- ... ---------- ---------- ----------
#            image           1            HST ...    science 2003520266 2011133418
#            image           1            HST ...    science 2003520267 2011133419
#            image           1            HST ...    science 2003520268 2011133420

# %%
m101uv = Observations.query_criteria(filters=["NUV","FUV"],objectname="M101")
print(m101uv)
# Out:
# dataproduct_type calib_level obs_collection ...   objID1      distance
# ---------------- ----------- -------------- ... ---------- -------------
#            image           2          GALEX ... 1000055044           0.0
#            image           2          GALEX ... 1000004937 3.83290685323
#            image           2          GALEX ... 1000045953 371.718371962
#            image           2          GALEX ... 1000055047 229.810616011
#            image           2          GALEX ... 1000045952           0.0
#            image           2          GALEX ... 1000001326           0.0
#            image           2          GALEX ... 1000001327 371.718371962
#            image           2          GALEX ... 1000004203           0.0
#            image           2          GALEX ... 1000016641           0.0
#            image           2          GALEX ... 1000016644 229.810616011
#            image           2          GALEX ... 1000048357           0.0
#            image           2          GALEX ... 1000048943 3.83290685323

# %% [markdown]
# ### Getting observation counts
# <div style="text-align: right">[(top)](#MAST-Astroquery-API)</div>

# %%
Observations.query_region_count("322.49324 12.16683")
# Out:
# 1677

# %%
Observations.query_object_count("M8",radius=".02 deg")
# Out:
# 220

# %%
Observations.query_criteria_count(target_classification=["*solar*planet*","disk"])
# Out:
# 21646

# %% [markdown]
# ### Listing available missions
# <div style="text-align: right">[(top)](#MAST-Astroquery-API)</div>

# %%
print(Observations.list_missions())
# Out:
# ['IUE', 'Kepler', 'K2FFI', 'JWST', 'EUVE', 'HLA', 'KeplerFFI', 'FUSE', 'K2', 'HST', 'WUPPE', 'BEFS', 'GALEX', 'TUES', 'HUT', 'HLSP', 'SWIFT']

# %% [markdown]
# ### Getting a list of data products
# <div style="text-align: right">[(top)](#MAST-Astroquery-API)</div>

# %%
dataProducts = Observations.get_product_list(m8Observations[0:4])
print("Number of results:",len(dataProducts))
print(dataProducts[:10])
# Out:
# Number of results: 40
#   obsID    obs_collection dataproduct_type ...  size  parent_obsid
# ---------- -------------- ---------------- ... ------ ------------
# 3000007760            IUE         spectrum ... 185727   3000007760
# 3000007760            IUE         spectrum ... 183350   3000007760
# 3000007760            IUE         spectrum ... 612715   3000007760
# 3000007760            IUE         spectrum ...  12416   3000007760
# 3000007760            IUE         spectrum ...  12064   3000007760
# 3000007760            IUE         spectrum ... 410846   3000007760
# 3000007760            IUE         spectrum ... 416435   3000007760
# 3000007760            IUE         spectrum ... 100682   3000007760
# 3000007760            IUE         spectrum ...   8971   3000007760
# 3000007760            IUE         spectrum ...  18206   3000007760

# %%
dataProductsByID = Observations.get_product_list('2003738726')
print("Number of results:",len(dataProductsByID))
print(dataProductsByID[:6])
# Out:
# Number of results: 22
#   obsID    obs_collection dataproduct_type ...  size  parent_obsid
# ---------- -------------- ---------------- ... ------ ------------
# 2003738726            HST            image ... 207360   2003738726
# 2003738726            HST            image ... 210240   2003738726
# 2003738726            HST            image ...  31680   2003738726
# 2003738726            HST            image ...  31680   2003738726
# 2003738726            HST            image ...  34560   2003738726
# 2003738726            HST            image ...  25920   2003738726

# %%
Observations.filter_products(dataProductsByID,productType=["SCIENCE"],mrp_only=False)
# Out:
# <Table masked=True length=7>
#   obsID    obs_collection dataproduct_type ...   size   parent_obsid
#   str10         str3            str5       ...  int64      str10
# ---------- -------------- ---------------- ... -------- ------------
# 2003738726            HST            image ... 10307520   2003738726
# 2003738726            HST            image ...  5178240   2003738726
# 2003738726            HST            image ...  5184000   2003738726
# 2003738726            HST            image ...  5178240   2003738726
# 2003738726            HST            image ... 10307520   2003738726
# 2003738726            HST            image ...  5184000   2003738726
# 2003738726            HST            image ... 27227520   2003738726

# %% [markdown]
# ### Downloading products
# <div style="text-align: right">[(top)](#MAST-Astroquery-API)</div>

# %%
Observations.download_products('2003738726',productType=["SCIENCE"],mrp_only=False,cache=False)
# Out:
# Downloading URL https://mast.stsci.edu/api/v0/download/file?uri=mast:HST/product/u9o40504m/u9o40504m_c0m.fits to ./mastDownload/HST/U9O40504M/u9o40504m_c0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0/download/file?uri=mast:HST/product/u9o40504m/u9o40504m_c1m.fits to ./mastDownload/HST/U9O40504M/u9o40504m_c1m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0/download/file?uri=mast:HST/product/u9o40504m/u9o40504m_d0f.fits to ./mastDownload/HST/U9O40504M/u9o40504m_d0f.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0/download/file?uri=mast:HST/product/u9o40504m/u9o40504m_d0m.fits to ./mastDownload/HST/U9O40504M/u9o40504m_d0m.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0/download/file?uri=mast:HST/product/u9o40504m/u9o40504m_c0f.fits to ./mastDownload/HST/U9O40504M/u9o40504m_c0f.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0/download/file?uri=mast:HST/product/u9o40504m/u9o40504m_c1f.fits to ./mastDownload/HST/U9O40504M/u9o40504m_c1f.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0/download/file?uri=mast:HST/product/u9o40504m/u9o40504m_drz.fits to ./mastDownload/HST/U9O40504M/u9o40504m_drz.fits ... [Done]
# <Table length=7>
#                    Local Path                    Status  Message  URL
#                      str47                        str8    object object
# ----------------------------------------------- -------- ------- ------
# ./mastDownload/HST/U9O40504M/u9o40504m_c0m.fits COMPLETE    None   None
# ./mastDownload/HST/U9O40504M/u9o40504m_c1m.fits COMPLETE    None   None
# ./mastDownload/HST/U9O40504M/u9o40504m_d0f.fits COMPLETE    None   None
# ./mastDownload/HST/U9O40504M/u9o40504m_d0m.fits COMPLETE    None   None
# ./mastDownload/HST/U9O40504M/u9o40504m_c0f.fits COMPLETE    None   None
# ./mastDownload/HST/U9O40504M/u9o40504m_c1f.fits COMPLETE    None   None
# ./mastDownload/HST/U9O40504M/u9o40504m_drz.fits COMPLETE    None   None

# %%
Observations.download_products(dataProductsByID,curl_flag=True)
# Out:
# Downloading URL https://mast.stsci.edu/portal/Download/stage/anonymous/public/ff001682-152f-4e78-a82c-7061996a8c34/mastDownload_20180228090512.sh to ./mastDownload_20180228090512.sh ... [Done]
# <Table length=1>
#            Local Path             Status  Message  URL
#              str32                 str8    object object
# -------------------------------- -------- ------- ------
# ./mastDownload_20180228090512.sh COMPLETE    None   None

# %% [markdown]
# ## Catalogs Class
# <div style="text-align: right">[(top)](#MAST-Astroquery-API)</div>

# %% [markdown]
# ### Query by position/object
# <div style="text-align: right">[(top)](#MAST-Astroquery-API)</div>

# %%
catalogData = Catalogs.query_region("158.47924 -7.30962", radius=0.1, catalog="Gaia")
print("Number of results:",len(catalogData))
print(catalogData[:4])
# Out:
# Number of results: 82
#     solution_id          source_id      ...      mag         distance
# ------------------- ------------------- ... ------------- --------------
# 1635378410781933568 3774902350511581696 ... 19.2406527918 0.632819842044
# 1635378410781933568 3774902144356360960 ...   14.74818686 0.919822239277
# 1635378410781933568 3774902453590798208 ... 18.5984070104  1.35823630602
# 1635378410781933568 3774901525877785984 ... 18.6348893106  1.45194202227

# %%
catalogData = Catalogs.query_region("322.49324 12.16683", catalog="HSC", magtype=2)
print("Number of results:",len(catalogData))
print(catalogData[:4])
# Out:
# Number of results: 50000
# MatchID      Distance        MatchRA    ... W3_F160W W3_F160W_Sigma W3_F160W_N
# -------- ---------------- ------------- ... -------- -------------- ----------
# 82371983 0.00445549943203 322.493181974 ...       --             --          0
# 82603024   0.006890683763 322.493352058 ...       --             --          0
# 82374767 0.00838818765315  322.49337203 ...       --             --          0
# 82368728  0.0088064912074 322.493272691 ...       --             --          0
# WARNING: MaxResultsWarning: Maximum catalog results returned, may not include all sources within radius. [astroquery.mast.core]

# %%
catalogData = Catalogs.query_criteria(catalog="Tic",Bmag=[30,50],objType="STAR")
print("Number of results:",len(catalogData))
print(catalogData)
# Out:
# Number of results: 3
#     ID    version  HIP TYC ... disposition duplicate_id priority   objID
# --------- -------- --- --- ... ----------- ------------ -------- ---------
# 406300991 20171221  --  -- ...          --           --       -- 400575018
#  81609218 20171221  --  -- ...          --           --       -- 217917514
#  23868624 20171221  --  -- ...          --           --       -- 296973171

# %%
catalogData = Catalogs.query_object("M10", radius=.02, catalog="TIC")
print("Number of results:",len(catalogData))
print(catalogData[:10])
# Out:
# Number of results: 305
#     ID          ra           dec       ... duplicate_id priority   dstArcSec
# --------- ------------- -------------- ... ------------ -------- -------------
# 189844423    254.287989      -4.099644 ...           --       -- 2.21043178558
# 189844434 254.286301884 -4.09872352783 ...           --       -- 4.69684511346
# 189844449    254.288157      -4.097959 ...           --       -- 5.53390173242
# 189844403    254.286864      -4.101237 ...           --       -- 7.19103845641
# 189844459 254.286798163  -4.0973143956 ...           --       -- 7.63543964382
# 189844400    254.285379      -4.100856 ...           --       -- 9.27452417927
# 189844461 254.285647884 -4.09722647575 ...           --       -- 9.98427869106
# 189844385 254.289725042 -4.10156744653 ...           --       -- 11.4468393777
# 189844419    254.290767      -4.099757 ...           --       -- 11.9738216615
# 189844454 254.290349435 -4.09754191392 ...           --       -- 12.2100186781

# %%
catalogData = Catalogs.query_object("M10", radius=.001, catalog="HSC",magtype=1)
print("Number of results:",len(catalogData))
print(catalogData[:10])
# Out:
# Number of results: 97
# MatchID      Distance        MatchRA    ... A_F814W_Sigma A_F814W_N
# -------- ---------------- ------------- ... ------------- ---------
# 17554326 0.00816349930145 254.287340985 ...           0.0         1
# 17554339  0.0111314873308 254.287442253 ...           0.0         1
# 17312295  0.0132308976165  254.28755768 ...           0.0         1
# 17307344  0.0132340172404 254.287681083 ...           0.0         1
# 17312106  0.0132883806305 254.287241075 ...           0.0         1
# 17312922  0.0137126230376 254.287304714 ...           0.0         1
# 17308111  0.0138519236707  254.28757612 ...           0.0         1
# 17310937  0.0144643213976 254.287457146 ...           0.0         1
# 17306539  0.0182168510975 254.287161749 ...           0.0         1
# 17312779  0.0197253962267 254.287226254 ...           0.0         1

# %% [markdown]
# ### Query by criteria
# <div style="text-align: right">[(top)](#MAST-Astroquery-API)</div>
# **\* Only available for TIC and Disk Detective catalogs**

# %%
catalogData = Catalogs.query_criteria(catalog="Tic",objectname="M10",objType="EXTENDED")
print("Number of results:",len(catalogData))
print(catalogData)
# Out:
# Number of results: 7
#      ID     version  HIP TYC ... disposition duplicate_id priority   objID
# ----------- -------- --- --- ... ----------- ------------ -------- ---------
# 10000869229 20171221  --  -- ...          --           --       -- 353286195
# 10000732586 20171221  --  -- ...          --           --       -- 353285956
# 10000732587 20171221  --  -- ...          --           --       -- 353285957
# 10000869228 20171221  --  -- ...          --           --       -- 353287226
# 10000732589 20171221  --  -- ...          --           --       -- 353285958
# 10000732652 20171221  --  -- ...          --           --       -- 353285983
# 10000732653 20171221  --  -- ...          --           --       -- 353287217

# %%
catalogData = Catalogs.query_criteria(catalog="DiskDetective",objectname="M10",radius=2,state="complete")
print("Number of results:",len(catalogData))
print(catalogData)
# Out:
# Number of results: 7
#     designation     ...                    ZooniverseURL
# ------------------- ... ----------------------------------------------------
# J170314.11-035210.4 ... https://talk.diskdetective.org/#/subjects/AWI0005ckv
# J165749.79-040315.1 ... https://talk.diskdetective.org/#/subjects/AWI0005cke
# J165327.01-042546.2 ... https://talk.diskdetective.org/#/subjects/AWI0005ck3
# J165949.90-054300.7 ... https://talk.diskdetective.org/#/subjects/AWI0005ckk
# J165628.40-054630.8 ... https://talk.diskdetective.org/#/subjects/AWI0005cka
# J165748.96-054915.4 ... https://talk.diskdetective.org/#/subjects/AWI0005ckd
# J165427.11-022700.4 ... https://talk.diskdetective.org/#/subjects/AWI0005ck5

# %%
catalogData = Catalogs.query_criteria(catalog="DiskDetective",state=["inactive","disabled"],oval=[8,10],multi=[3,7])
print("Number of results:",len(catalogData))
print(catalogData[:10])
# Out:
# Number of results: 39
#     designation     ...                    ZooniverseURL
# ------------------- ... ----------------------------------------------------
# J043401.21-372522.1 ... https://talk.diskdetective.org/#/subjects/AWI0000me4
# J013156.85-590657.9 ... https://talk.diskdetective.org/#/subjects/AWI0000h25
# J021657.72-512827.0 ... https://talk.diskdetective.org/#/subjects/AWI000089o
# J014733.52-360102.1 ... https://talk.diskdetective.org/#/subjects/AWI00009ok
# J235528.65-384338.9 ... https://talk.diskdetective.org/#/subjects/AWI0000c2e
# J020613.28-444453.6 ... https://talk.diskdetective.org/#/subjects/AWI00008q5
# J005254.84-161414.1 ... https://talk.diskdetective.org/#/subjects/AWI0000ag2
# J125341.76-233509.3 ... https://talk.diskdetective.org/#/subjects/AWI00005r5
# J023326.58-230931.4 ... https://talk.diskdetective.org/#/subjects/AWI0000axo
# J085343.01+251308.1 ... https://talk.diskdetective.org/#/subjects/AWI0000116

# %% [markdown]
# ### HSC Specific queries
# <div style="text-align: right">[(top)](#MAST-Astroquery-API)</div>

# %%
catalogData = Catalogs.query_object("M10", radius=.001, catalog="HSC",magtype=1)
matches = Catalogs.query_hsc_matchid(catalogData[0]["MatchID"])
print("Number of results:",len(matches))
print(matches)
# Out:
# Number of results: 8
#   CatID   MatchID  ...                       cd_matrix
# --------- -------- ... ------------------------------------------------------
# 303940283 17554326 ...   -1.10059e-005 6.90694e-010 6.90694e-010 1.10059e-005
# 303936256 17554326 ...   -1.10059e-005 6.90694e-010 6.90694e-010 1.10059e-005
# 303938261 17554326 ...   -1.10059e-005 6.90694e-010 6.90694e-010 1.10059e-005
# 301986299 17554326 ...   -1.10049e-005 -1.6278e-010 -1.6278e-010 1.10049e-005
# 301988274 17554326 ...   -1.10049e-005 -1.6278e-010 -1.6278e-010 1.10049e-005
# 301990418 17554326 ...   -1.10049e-005 -1.6278e-010 -1.6278e-010 1.10049e-005
# 206511399 17554326 ... -1.38889e-005 -1.36001e-009 -1.36001e-009 1.38889e-005
# 206507082 17554326 ... -1.38889e-005 -1.36001e-009 -1.36001e-009 1.38889e-005

# %%
allSpectra = Catalogs.get_hsc_spectra() 
print("Number of results:",len(allSpectra))
print(allSpectra[:10])
# Out:
# Number of results: 45762
# ObjID                 DatasetName                  MatchID  ... PropID HSCMatch
# ----- -------------------------------------------- -------- ... ------ --------
# 20010 HAG_J072655.67+691648.9_J8HPAXAEQ_V01.SPEC1D 19657846 ...   9482        Y
# 20011 HAG_J072655.69+691648.9_J8HPAOZMQ_V01.SPEC1D 19657846 ...   9482        Y
# 20012 HAG_J072655.76+691729.7_J8HPAOZMQ_V01.SPEC1D 19659745 ...   9482        Y
# 20013 HAG_J072655.82+691620.0_J8HPAOZMQ_V01.SPEC1D 19659417 ...   9482        Y
# 20014 HAG_J072656.34+691704.7_J8HPAXAEQ_V01.SPEC1D 19660230 ...   9482        Y
# 20015 HAG_J072656.36+691704.7_J8HPAOZMQ_V01.SPEC1D 19660230 ...   9482        Y
# 20016 HAG_J072656.36+691744.9_J8HPAOZMQ_V01.SPEC1D 19658847 ...   9482        Y
# 20017 HAG_J072656.37+691630.2_J8HPAXAEQ_V01.SPEC1D 19660827 ...   9482        Y
# 20018 HAG_J072656.39+691630.2_J8HPAOZMQ_V01.SPEC1D 19660827 ...   9482        Y
# 20019 HAG_J072656.41+691734.9_J8HPAOZMQ_V01.SPEC1D 19656620 ...   9482        Y

# %%
manifest = Catalogs.download_hsc_spectra(allSpectra[100:104], cache=False)
print(manifest)
# Out:
# Downloading URL https://hla.stsci.edu/cgi-bin/ecfproxy?file_id=HAG_J072704.61+691530.3_J8HPAOZMQ_V01.SPEC1D.fits to ./mastDownload/HSC/HAG_J072704.61+691530.3_J8HPAOZMQ_V01.SPEC1D.fits ... [Done]
# Downloading URL https://hla.stsci.edu/cgi-bin/ecfproxy?file_id=HAG_J072704.68+691535.9_J8HPAOZMQ_V01.SPEC1D.fits to ./mastDownload/HSC/HAG_J072704.68+691535.9_J8HPAOZMQ_V01.SPEC1D.fits ... [Done]
# Downloading URL https://hla.stsci.edu/cgi-bin/ecfproxy?file_id=HAG_J072704.70+691530.2_J8HPAOZMQ_V01.SPEC1D.fits to ./mastDownload/HSC/HAG_J072704.70+691530.2_J8HPAOZMQ_V01.SPEC1D.fits ... [Done]
# Downloading URL https://hla.stsci.edu/cgi-bin/ecfproxy?file_id=HAG_J072704.73+691808.0_J8HPAOZMQ_V01.SPEC1D.fits to ./mastDownload/HSC/HAG_J072704.73+691808.0_J8HPAOZMQ_V01.SPEC1D.fits ... [Done]
#                              Local Path                              ... URL
# -------------------------------------------------------------------- ... ----
# ./mastDownload/HSC/HAG_J072704.61+691530.3_J8HPAOZMQ_V01.SPEC1D.fits ... None
# ./mastDownload/HSC/HAG_J072704.68+691535.9_J8HPAOZMQ_V01.SPEC1D.fits ... None
# ./mastDownload/HSC/HAG_J072704.70+691530.2_J8HPAOZMQ_V01.SPEC1D.fits ... None
# ./mastDownload/HSC/HAG_J072704.73+691808.0_J8HPAOZMQ_V01.SPEC1D.fits ... None

# %% [markdown]
# ## Proprietary Data Access
# <div style="text-align: right">[(top)](#MAST-Astroquery-API)</div>

# %%
# This will prompt for valid MyST account credentials
# not all accounts will have access to the particular proprietary data used in the below example
Observations.login()

# %%
propDat = Observations.query_criteria(dataRights="Proprietary",objectname="M101",radius=2)
propProds = Observations.get_product_list(propDat[0:2])

# %%
propProds
# Out:
# <Table masked=True length=6>
#   obsID    obs_collection dataproduct_type ...    size   parent_obsid
#   str10         str3            str5       ...   int64      str10
# ---------- -------------- ---------------- ... --------- ------------
# 2007668055            HST            image ...     11520   2007668055
# 2007668055            HST            image ... 214911360   2007668055
# 2007668055            HST            image ... 214911360   2007668055
# 2007673939            HST            image ...     11520   2007673939
# 2007673939            HST            image ... 214963200   2007673939
# 2007673939            HST            image ... 214963200   2007673939

# %%
Observations.download_products(propProds,cache=False)
# Out:
# <Table length=6>
#                    Local Path                   ...
#                      str47                      ...
# ----------------------------------------------- ...
# ./mastDownload/HST/JD7E05020/jd7e05020_asn.fits ...
# ./mastDownload/HST/JD7E05020/jd7e05020_drc.fits ...
# ./mastDownload/HST/JD7E05020/jd7e05020_drz.fits ...
# ./mastDownload/HST/JD7E54020/jd7e54020_asn.fits ...
# ./mastDownload/HST/JD7E54020/jd7e54020_drc.fits ...
# ./mastDownload/HST/JD7E54020/jd7e54020_drz.fits ...

# %%
my_token = Observations.get_token()

# %%
myObs = Observations(session_token=my_token)
# Out:
# INFO: Authentication successful!
# Session Expiration: 599 minute(s) [astroquery.mast.core]

# %%
_ = myObs.session_info()
# Out:
# Session Expiration: 599.0 min
# Username: asbtest-super@stsci.edu
# First Name: asbtest-super
# Last Name: asbtest-super

# %%
myObs.download_products(propProds,cache=False)
# Out:
# <Table length=6>
#                    Local Path                   ...
#                      str47                      ...
# ----------------------------------------------- ...
# ./mastDownload/HST/JD7E10010/jd7e10010_asn.fits ...
# ./mastDownload/HST/JD7E10010/jd7e10010_drc.fits ...
# ./mastDownload/HST/JD7E10010/jd7e10010_drz.fits ...
# ./mastDownload/HST/JD7E54010/jd7e54010_asn.fits ...
# ./mastDownload/HST/JD7E54010/jd7e54010_drc.fits ...
# ./mastDownload/HST/JD7E54010/jd7e54010_drz.fits ...

# %%
myObs.logout()

# %%
myObs.session_info(True)

# %% [markdown]
# ## Mast Class
# <div style="text-align: right">[(top)](#MAST-Astroquery-API)</div>

# %%
service = 'Mast.Caom.Cone'
params = {'ra':184.3,
          'dec':54.5,
          'radius':0.2}
        
observations = Mast.service_request(service, params, clearchache=True)
print(observations[:10])
# Out:
# dataproduct_type obs_collection instrument_name ...   objID       distance
# ---------------- -------------- --------------- ... ---------- -------------
#            image          GALEX           GALEX ... 1000007104           0.0
#            image          GALEX           GALEX ... 1000016543           0.0
#            image          GALEX           GALEX ... 1000054946           0.0
#            image          GALEX           GALEX ... 1000016544           0.0
#            image          GALEX           GALEX ... 1000054947           0.0
#            image          GALEX           GALEX ... 1000016537 302.405835798
#            image          GALEX           GALEX ... 1000054940 302.405835798

# %%
service = 'Mast.Name.Lookup'
params ={'input':"M8",
         'format':'json'}
        
response = Mast.service_request_async(service,params)        
result = response[0].json()
result
# Out:
# {'resolvedCoordinate': [{'cacheDate': 'Nov 3, 2017 10:54:26 AM',
#    'cached': True,
#    'canonicalName': 'MESSIER 008',
#    'decl': -24.38017,
#    'objectType': 'Neb',
#    'ra': 270.92194,
#    'resolver': 'NED',
#    'resolverTime': 209,
#    'searchRadius': -1.0,
#    'searchString': 'm8'}],
#  'status': ''}

# %%
service = "Mast.Jwst.Filtered.Miri"
params = {"columns":"*",
                    "filters":[],
                    "position":"undefined, undefined, undefined"}

# %%
response = Mast.service_request_async(service,params)

# %%
result = response[0].json()
result
# Out:
# {'data': [{'ArchiveFileID': 5748878,
#    'FileSetId': 153974,
#    'FileTypeID': 37,
#    'act_id': '01',
#    'apername': 'MIRIM_SUB128',
#    'asnpool': 'jw80600_20180114T194836_pool',
#    'asntable': '/ifs/int/jwst/info/jwowlmgr/build7.1/paths/sdp/asn_creation/cal/lev&',
#    'band': None,
#    'bartdelt': 71.76122688688338,
#    'bendtime': 57404.04973102663,
#    'bkgdtarg': 'F',
#    'bkglevel': None,
#    'bkgsub': None,
#    'bmidtime': 57404.04766435722,
#    'bstrtime': 57404.04559768781,
#    'category': 'ENG',
#    'cccstate': 'OPEN',
#    'channel': None,
#    'checksum': 547966661,
#    'comprssd': 'F',
#    'cont_id': 0,
#    'coronmsk': None,
#    'dataURI': 'mast:JWST/product/jw80600003001_02101_00001_mirimage_cal.fits',
#    'datamode': 1,
#    'dataprob': 'F',
#    'date': '/Date(1515978335783)/',
#    'date_obs': '/Date(1453010667879)/',
#    'detector': 'MIRIMAGE',
#    'drpfrms1': 0,
#    'drpfrms3': 0,
#    'duration': 357.12,
#    'dva_dec': -4.9378219551081e-08,
#    'dva_ra': -3.3386530418269e-07,
#    'effexptm': 333,
#    'effinttm': 11.904,
#    'eng_qual': 'SUSPECT',
#    'eph_time': 57404.0465278,
#    'eph_type': 'Predicted',
#    'exp_type': 'MIR_IMAGE',
#    'expcount': 1,
#    'expend': 57404.04890045139,
#    'expmid': 57404.04683378472,
#    'exposure': 1,
#    'expripar': 'PRIME',
#    'expstart': 57404.04476711806,
#    'fastaxis': 1,
#    'fileSetName': 'jw80600003001_02101_00001',
#    'fileSize': 4631040,
#    'filename': 'jw80600003001_02101_00001_mirimage_cal.fits',
#    'filetype': 'uncalibrated',
#    'filter': 'F770W',
#    'frmdivsr': 1,
#    'gdstarid': '',
#    'groupgap': 0,
#    'gs_dec': 0,
#    'gs_mag': 0,
#    'gs_order': 0,
#    'gs_ra': 0,
#    'gs_udec': 0,
#    'gs_umag': 0,
#    'gs_ura': 0,
#    'gsendtim': '/Date(915166800000)/',
#    'gsstrttm': '/Date(915166800000)/',
#    'helidelt': 71.70613766647875,
#    'hendtime': 57404.04973038902,
#    'hga_move': 'F',
#    'hmidtime': 57404.04766371961,
#    'hstrtime': 57404.04559705021,
#    'ingestCompletionDate': '/Date(1515978359190)/',
#    'ingestStartDate': '/Date(1515978356732)/',
#    'instrume': 'MIRI',
#    'intarget': 'F',
#    'isItar': False,
#    'isRestricted': False,
#    'isStale': True,
#    'jwst_dx': 0.00728750510755888,
#    'jwst_dy': -0.0391999272912571,
#    'jwst_dz': -0.0443440173424347,
#    'jwst_x': -1475428.26063091,
#    'jwst_y': -631640.257854662,
#    'jwst_z': -580333.26152848,
#    'lamp': '',
#    'mu_dec': 0,
#    'mu_epoch': '/Date(946702800000)/',
#    'mu_ra': 0,
#    'nexposur': 1,
#    'nextend': 3,
#    'nframes': 1,
#    'ngroups': 100,
#    'nints': 30,
#    'nresets': 0,
#    'nrststrt': 0,
#    'nsamples': 1,
#    'numdthpt': 0,
#    'nwfsest': None,
#    'obs_id': 'V80600003001P0000000002101',
#    'observtn': 3,
#    'obslabel': 'MIRI Imaging 003',
#    'origin': 'STSCI',
#    'patt_num': 0,
#    'pattsize': None,
#    'pattstrt': 0,
#    'patttype': 'NONE',
#    'pcs_mode': 'COARSE',
#    'pi_name': 'N/A',
#    'pntg_seq': 1,
#    'pps_aper': 'MIRIM_SUB128',
#    'prd_ver': 'PRDOPSSOC-G-010',
#    'productLevel': '2b',
#    'program': 80600,
#    'prop_dec': -66.59798333333333,
#    'prop_ra': 6.128166666666667,
#    'psfref': None,
#    'publicReleaseDate': '/Date(2114398800000)/',
#    'pwfseet': None,
#    'readpatt': 'FAST',
#    'refframe': 'EME2000',
#    's_region': 'POLYGON ICRS  6.132710535673128 -66.60009847976983 6.133470446822996 -66.59616850659755 6.123830117973689 -66.59584688772405 6.123032736320151 -66.59977887069617',
#    'sca_num': 493,
#    'scicat': '',
#    'sdp_ver': '2017_1',
#    'selfref': None,
#    'seq_id': '1',
#    'slowaxis': 2,
#    'spat_num': None,
#    'spatnstp': None,
#    'spatstep': None,
#    'spcoffst': None,
#    'spec_num': None,
#    'specnstp': None,
#    'specstep': None,
#    'sptoffst': None,
#    'srctype': None,
#    'subarray': 'SUB128',
#    'subcat': '',
#    'subpxnum': 0,
#    'subsize1': 136,
#    'subsize2': 128,
#    'substrt1': 1,
#    'substrt2': 889,
#    'targ_dec': -66.59798333333333,
#    'targ_ra': 6.128166666666667,
#    'targname': '',
#    'targoopp': 'F',
#    'targprop': '2MASS-J00243075-6635527',
#    'targtype': 'FIXED',
#    'targudec': 0.1,
#    'targura': 0.1,
#    'telescop': 'JWST',
#    'template': 'MIRI Imaging',
#    'tframe': 0.11904,
#    'tgroup': 0.11904,
#    'timesys': 'UTC',
#    'title': 'MIRI Cryo3 SIC',
#    'tsample': 10,
#    'tsovisit': 'F',
#    'visit': 1,
#    'visit_id': '80600003001',
#    'visitend': '/Date(1453011064168)/',
#    'visitgrp': '02',
#    'visitsta': 'SUCCESSFUL',
#    'visitype': 'PRIME_TARGETED_FIXED',
#    'vststart': '/Date(1453010523496)/',
#    'xoffset': 8.79754151696902e-12,
#    'yoffset': 9.95998062451668e-11,
#    'zerofram': 'F'},
#   {'ArchiveFileID': 5748884,
#    'FileSetId': 153974,
#    'FileTypeID': 37,
#    'act_id': '01',
#    'apername': 'MIRIM_SUB128',
#    'asnpool': None,
#    'asntable': None,
#    'band': None,
#    'bartdelt': 71.76122688688338,
#    'bendtime': 57404.04973102663,
#    'bkgdtarg': 'F',
#    'bkglevel': None,
#    'bkgsub': None,
#    'bmidtime': 57404.04766435722,
#    'bstrtime': 57404.04559768781,
#    'category': 'ENG',
#    'cccstate': 'OPEN',
#    'channel': None,
#    'checksum': 1883650899,
#    'comprssd': 'F',
#    'cont_id': 0,
#    'coronmsk': None,
#    'dataURI': 'mast:JWST/product/jw80600003001_02101_00001_mirimage_i2d.fits',
#    'datamode': 1,
#    'dataprob': 'F',
#    'date': '/Date(1515978335591)/',
#    'date_obs': '/Date(1453010667879)/',
#    'detector': 'MIRIMAGE',
#    'drpfrms1': 0,
#    'drpfrms3': 0,
#    'duration': 357.12,
#    'dva_dec': -4.9378219551081e-08,
#    'dva_ra': -3.3386530418269e-07,
#    'effexptm': 333,
#    'effinttm': 11.904,
#    'eng_qual': 'SUSPECT',
#    'eph_time': 57404.0465278,
#    'eph_type': 'Predicted',
#    'exp_type': 'MIR_IMAGE',
#    'expcount': 1,
#    'expend': 57404.04890045139,
#    'expmid': 57404.04683378472,
#    'exposure': 1,
#    'expripar': 'PRIME',
#    'expstart': 57404.04476711806,
#    'fastaxis': 1,
#    'fileSetName': 'jw80600003001_02101_00001',
#    'fileSize': 285120,
#    'filename': 'jw80600003001_02101_00001_mirimage_i2d.fits',
#    'filetype': 'uncalibrated',
#    'filter': 'F770W',
#    'frmdivsr': 1,
#    'gdstarid': '',
#    'groupgap': 0,
#    'gs_dec': 0,
#    'gs_mag': 0,
#    'gs_order': 0,
#    'gs_ra': 0,
#    'gs_udec': 0,
#    'gs_umag': 0,
#    'gs_ura': 0,
#    'gsendtim': '/Date(915166800000)/',
#    'gsstrttm': '/Date(915166800000)/',
#    'helidelt': 71.70613766647875,
#    'hendtime': 57404.04973038902,
#    'hga_move': 'F',
#    'hmidtime': 57404.04766371961,
#    'hstrtime': 57404.04559705021,
#    'ingestCompletionDate': '/Date(1515978359725)/',
#    'ingestStartDate': '/Date(1515978356732)/',
#    'instrume': 'MIRI',
#    'intarget': 'F',
#    'isItar': False,
#    'isRestricted': False,
#    'isStale': True,
#    'jwst_dx': 0.00728750510755888,
#    'jwst_dy': -0.0391999272912571,
#    'jwst_dz': -0.0443440173424347,
#    'jwst_x': -1475428.26063091,
#    'jwst_y': -631640.257854662,
#    'jwst_z': -580333.26152848,
#    'lamp': '',
#    'mu_dec': 0,
#    'mu_epoch': '/Date(946702800000)/',
#    'mu_ra': 0,
#    'nexposur': 1,
#    'nextend': 3,
#    'nframes': 1,
#    'ngroups': 100,
#    'nints': 30,
#    'nresets': 0,
#    'nrststrt': 0,
#    'nsamples': 1,
#    'numdthpt': 0,
#    'nwfsest': None,
#    'obs_id': 'V80600003001P0000000002101',
#    'observtn': 3,
#    'obslabel': 'MIRI Imaging 003',
#    'origin': 'STSCI',
#    'patt_num': 0,
#    'pattsize': None,
#    'pattstrt': 0,
#    'patttype': 'NONE',
#    'pcs_mode': 'COARSE',
#    'pi_name': 'N/A',
#    'pntg_seq': 1,
#    'pps_aper': 'MIRIM_SUB128',
#    'prd_ver': 'PRDOPSSOC-G-010',
#    'productLevel': '2b',
#    'program': 80600,
#    'prop_dec': -66.59798333333333,
#    'prop_ra': 6.128166666666667,
#    'psfref': None,
#    'publicReleaseDate': '/Date(2114398800000)/',
#    'pwfseet': None,
#    'readpatt': 'FAST',
#    'refframe': 'EME2000',
#    's_region': 'POLYGON ICRS  6.133514644765367 -66.60011559324138 6.133513747605262 -66.59585265632708 6.123088295862451 -66.59585265668474 6.123087400556553 -66.60011559359911',
#    'sca_num': 493,
#    'scicat': '',
#    'sdp_ver': '2017_1',
#    'selfref': None,
#    'seq_id': '1',
#    'slowaxis': 2,
#    'spat_num': None,
#    'spatnstp': None,
#    'spatstep': None,
#    'spcoffst': None,
#    'spec_num': None,
#    'specnstp': None,
#    'specstep': None,
#    'sptoffst': None,
#    'srctype': None,
#    'subarray': 'SUB128',
#    'subcat': '',
#    'subpxnum': 0,
#    'subsize1': 136,
#    'subsize2': 128,
#    'substrt1': 1,
#    'substrt2': 889,
#    'targ_dec': -66.59798333333333,
#    'targ_ra': 6.128166666666667,
#    'targname': '',
#    'targoopp': 'F',
#    'targprop': '2MASS-J00243075-6635527',
#    'targtype': 'FIXED',
#    'targudec': 0.1,
#    'targura': 0.1,
#    'telescop': 'JWST',
#    'template': 'MIRI Imaging',
#    'tframe': 0.11904,
#    'tgroup': 0.11904,
#    'timesys': 'UTC',
#    'title': 'MIRI Cryo3 SIC',
#    'tsample': 10,
#    'tsovisit': 'F',
#    'visit': 1,
#    'visit_id': '80600003001',
#    'visitend': '/Date(1453011064168)/',
#    'visitgrp': '02',
#    'visitsta': 'SUCCESSFUL',
#    'visitype': 'PRIME_TARGETED_FIXED',
#    'vststart': '/Date(1453010523496)/',
#    'xoffset': 8.79754151696902e-12,
#    'yoffset': 9.95998062451668e-11,
#    'zerofram': 'F'},
#   {'ArchiveFileID': 5749463,
#    'FileSetId': 153921,
#    'FileTypeID': 37,
#    'act_id': '01',
#    'apername': 'MIRIM_FULL',
#    'asnpool': 'jw80600_20180114T194836_pool',
#    'asntable': '/ifs/int/jwst/info/jwowlmgr/build7.1/paths/sdp/asn_creation/cal/lev&',
#    'band': None,
#    'bartdelt': 71.76436067093164,
#    'bendtime': 57404.07346365069,
#    'bkgdtarg': 'F',
#    'bkglevel': None,
#    'bkgsub': None,
#    'bmidtime': 57404.07320670221,
#    'bstrtime': 57404.0729497537,
#    'category': 'ENG',
#    'cccstate': 'OPEN',
#    'channel': None,
#    'checksum': 485127584,
#    'comprssd': 'F',
#    'cont_id': 0,
#    'coronmsk': None,
#    'dataURI': 'mast:JWST/product/jw80600006001_02101_00001_mirimage_cal.fits',
#    'datamode': 2,
#    'dataprob': 'F',
#    'date': '/Date(1515978416855)/',
#    'date_obs': '/Date(1453013031094)/',
#    'detector': 'MIRIMAGE',
#    'drpfrms1': 0,
#    'drpfrms3': 0,
#    'duration': 44.40064,
#    'dva_dec': -4.9390665905198e-08,
#    'dva_ra': -3.3410173835358e-07,
#    'effexptm': 44.56,
#    'effinttm': 11.10016,
#    'eng_qual': 'SUSPECT',
#    'eph_time': 57404.0722222,
#    'eph_type': 'Predicted',
#    'exp_type': 'MIR_IMAGE',
#    'expcount': 1,
#    'expend': 57404.07263304398,
#    'expmid': 57404.07237609584,
#    'exposure': 1,
#    'expripar': 'PRIME',
#    'expstart': 57404.07211914768,
#    'fastaxis': 1,
#    'fileSetName': 'jw80600006001_02101_00001',
#    'fileSize': 25410240,
#    'filename': 'jw80600006001_02101_00001_mirimage_cal.fits',
#    'filetype': 'uncalibrated',
#    'filter': 'F2100W',
#    'frmdivsr': 4,
#    'gdstarid': '',
#    'groupgap': 0,
#    'gs_dec': 0,
#    'gs_mag': 0,
#    'gs_order': 0,
#    'gs_ra': 0,
#    'gs_udec': 0,
#    'gs_umag': 0,
#    'gs_ura': 0,
#    'gsendtim': '/Date(915166800000)/',
#    'gsstrttm': '/Date(915166800000)/',
#    'helidelt': 71.70927145052701,
#    'hendtime': 57404.07346301308,
#    'hga_move': 'F',
#    'hmidtime': 57404.0732060646,
#    'hstrtime': 57404.0729491161,
#    'ingestCompletionDate': '/Date(1515978454575)/',
#    'ingestStartDate': '/Date(1515978446000)/',
#    'instrume': 'MIRI',
#    'intarget': 'F',
#    'isItar': False,
#    'isRestricted': False,
#    'isStale': True,
#    'jwst_dx': 0.00725572051567036,
#    'jwst_dy': -0.0392316542903626,
#    'jwst_dz': -0.0442725627735492,
#    'jwst_x': -1475412.05752601,
#    'jwst_y': -631727.209446395,
#    'jwst_z': -580431.590177708,
#    'lamp': '',
#    'mu_dec': 0,
#    'mu_epoch': '/Date(946702800000)/',
#    'mu_ra': 0,
#    'nexposur': 4,
#    'nextend': 3,
#    'nframes': 1,
#    'ngroups': 1,
#    'nints': 4,
#    'nresets': 0,
#    'nrststrt': 0,
#    'nsamples': 1,
#    'numdthpt': 0,
#    'nwfsest': None,
#    'obs_id': 'V80600006001P0000000002101',
#    'observtn': 6,
#    'obslabel': 'MIRI Imaging 006',
#    'origin': 'STSCI',
#    'patt_num': 0,
#    'pattsize': None,
#    'pattstrt': 0,
#    'patttype': 'NONE',
#    'pcs_mode': 'COARSE',
#    'pi_name': 'N/A',
#    'pntg_seq': 1,
#    'pps_aper': 'MIRIM_ILLUM',
#    'prd_ver': 'PRDOPSSOC-G-010',
#    'productLevel': '2b',
#    'program': 80600,
#    'prop_dec': -66.59798333333333,
#    'prop_ra': 6.128166666666667,
#    'psfref': None,
#    'publicReleaseDate': '/Date(2114398800000)/',
#    'pwfseet': None,
#    'readpatt': 'FASTGRPAVG',
#    'refframe': 'EME2000',
#    's_region': 'POLYGON ICRS  6.177969888833616 -66.61546357077478 6.184462279495496 -66.58397889876007 6.105686171809398 -66.58152977717666 6.09913196364043 -66.61272265045194',
#    'sca_num': 493,
#    'scicat': '',
#    'sdp_ver': '2017_1',
#    'selfref': None,
#    'seq_id': '1',
#    'slowaxis': 2,
#    'spat_num': None,
#    'spatnstp': None,
#    'spatstep': None,
#    'spcoffst': None,
#    'spec_num': None,
#    'specnstp': None,
#    'specstep': None,
#    'sptoffst': None,
#    'srctype': None,
#    'subarray': 'FULL',
#    'subcat': '',
#    'subpxnum': 0,
#    'subsize1': 1032,
#    'subsize2': 1024,
#    'substrt1': 1,
#    'substrt2': 1,
#    'targ_dec': -66.59798333333333,
#    'targ_ra': 6.128166666666667,
#    'targname': '',
#    'targoopp': 'F',
#    'targprop': '2MASS-J00243075-6635527',
#    'targtype': 'FIXED',
#    'targudec': 0.1,
#    'targura': 0.1,
#    'telescop': 'JWST',
#    'template': 'MIRI Imaging',
#    'tframe': 2.77504,
#    'tgroup': 2.77504,
#    'timesys': 'UTC',
#    'title': 'MIRI Cryo3 SIC',
#    'tsample': 10,
#    'tsovisit': 'F',
#    'visit': 1,
#    'visit_id': '80600006001',
#    'visitend': '/Date(1453013512552)/',
#    'visitgrp': '02',
#    'visitsta': 'SUCCESSFUL',
#    'visitype': 'PRIME_TARGETED_FIXED',
#    'vststart': '/Date(1453012879720)/',
#    'xoffset': -9.2231701051478e-13,
#    'yoffset': -1.1160251102231e-11,
#    'zerofram': 'F'},
#   {'ArchiveFileID': 5749469,
#    'FileSetId': 153921,
#    'FileTypeID': 37,
#    'act_id': '01',
#    'apername': 'MIRIM_FULL',
#    'asnpool': None,
#    'asntable': None,
#    'band': None,
#    'bartdelt': 71.76436067093164,
#    'bendtime': 57404.07346365069,
#    'bkgdtarg': 'F',
#    'bkglevel': None,
#    'bkgsub': None,
#    'bmidtime': 57404.07320670221,
#    'bstrtime': 57404.0729497537,
#    'category': 'ENG',
#    'cccstate': 'OPEN',
#    'channel': None,
#    'checksum': 2817074843,
#    'comprssd': 'F',
#    'cont_id': 0,
#    'coronmsk': None,
#    'dataURI': 'mast:JWST/product/jw80600006001_02101_00001_mirimage_i2d.fits',
#    'datamode': 2,
#    'dataprob': 'F',
#    'date': '/Date(1515978416582)/',
#    'date_obs': '/Date(1453013031094)/',
#    'detector': 'MIRIMAGE',
#    'drpfrms1': 0,
#    'drpfrms3': 0,
#    'duration': 44.40064,
#    'dva_dec': -4.9390665905198e-08,
#    'dva_ra': -3.3410173835358e-07,
#    'effexptm': 44.56,
#    'effinttm': 11.10016,
#    'eng_qual': 'SUSPECT',
#    'eph_time': 57404.0722222,
#    'eph_type': 'Predicted',
#    'exp_type': 'MIR_IMAGE',
#    'expcount': 1,
#    'expend': 57404.07263304398,
#    'expmid': 57404.07237609584,
#    'exposure': 1,
#    'expripar': 'PRIME',
#    'expstart': 57404.07211914768,
#    'fastaxis': 1,
#    'fileSetName': 'jw80600006001_02101_00001',
#    'fileSize': 14592960,
#    'filename': 'jw80600006001_02101_00001_mirimage_i2d.fits',
#    'filetype': 'uncalibrated',
#    'filter': 'F2100W',
#    'frmdivsr': 4,
#    'gdstarid': '',
#    'groupgap': 0,
#    'gs_dec': 0,
#    'gs_mag': 0,
#    'gs_order': 0,
#    'gs_ra': 0,
#    'gs_udec': 0,
#    'gs_umag': 0,
#    'gs_ura': 0,
#    'gsendtim': '/Date(915166800000)/',
#    'gsstrttm': '/Date(915166800000)/',
#    'helidelt': 71.70927145052701,
#    'hendtime': 57404.07346301308,
#    'hga_move': 'F',
#    'hmidtime': 57404.0732060646,
#    'hstrtime': 57404.0729491161,
#    'ingestCompletionDate': '/Date(1515978455123)/',
#    'ingestStartDate': '/Date(1515978446000)/',
#    'instrume': 'MIRI',
#    'intarget': 'F',
#    'isItar': False,
#    'isRestricted': False,
#    'isStale': True,
#    'jwst_dx': 0.00725572051567036,
#    'jwst_dy': -0.0392316542903626,
#    'jwst_dz': -0.0442725627735492,
#    'jwst_x': -1475412.05752601,
#    'jwst_y': -631727.209446395,
#    'jwst_z': -580431.590177708,
#    'lamp': '',
#    'mu_dec': 0,
#    'mu_epoch': '/Date(946702800000)/',
#    'mu_ra': 0,
#    'nexposur': 4,
#    'nextend': 3,
#    'nframes': 1,
#    'ngroups': 1,
#    'nints': 4,
#    'nresets': 0,
#    'nrststrt': 0,
#    'nsamples': 1,
#    'numdthpt': 0,
#    'nwfsest': None,
#    'obs_id': 'V80600006001P0000000002101',
#    'observtn': 6,
#    'obslabel': 'MIRI Imaging 006',
#    'origin': 'STSCI',
#    'patt_num': 0,
#    'pattsize': None,
#    'pattstrt': 0,
#    'patttype': 'NONE',
#    'pcs_mode': 'COARSE',
#    'pi_name': 'N/A',
#    'pntg_seq': 1,
#    'pps_aper': 'MIRIM_ILLUM',
#    'prd_ver': 'PRDOPSSOC-G-010',
#    'productLevel': '2b',
#    'program': 80600,
#    'prop_dec': -66.59798333333333,
#    'prop_ra': 6.128166666666667,
#    'psfref': None,
#    'publicReleaseDate': '/Date(2114398800000)/',
#    'pwfseet': None,
#    'readpatt': 'FASTGRPAVG',
#    'refframe': 'EME2000',
#    's_region': 'POLYGON ICRS  6.1845411482371695 -66.61540639523375 6.184482777370162 -66.5814822592075 6.099204616980658 -66.58148225723129 6.099146236145126 -66.6154063932543',
#    'sca_num': 493,
#    'scicat': '',
#    'sdp_ver': '2017_1',
#    'selfref': None,
#    'seq_id': '1',
#    'slowaxis': 2,
#    'spat_num': None,
#    'spatnstp': None,
#    'spatstep': None,
#    'spcoffst': None,
#    'spec_num': None,
#    'specnstp': None,
#    'specstep': None,
#    'sptoffst': None,
#    'srctype': None,
#    'subarray': 'FULL',
#    'subcat': '',
#    'subpxnum': 0,
#    'subsize1': 1032,
#    'subsize2': 1024,
#    'substrt1': 1,
#    'substrt2': 1,
#    'targ_dec': -66.59798333333333,
#    'targ_ra': 6.128166666666667,
#    'targname': '',
#    'targoopp': 'F',
#    'targprop': '2MASS-J00243075-6635527',
#    'targtype': 'FIXED',
#    'targudec': 0.1,
#    'targura': 0.1,
#    'telescop': 'JWST',
#    'template': 'MIRI Imaging',
#    'tframe': 2.77504,
#    'tgroup': 2.77504,
#    'timesys': 'UTC',
#    'title': 'MIRI Cryo3 SIC',
#    'tsample': 10,
#    'tsovisit': 'F',
#    'visit': 1,
#    'visit_id': '80600006001',
#    'visitend': '/Date(1453013512552)/',
#    'visitgrp': '02',
#    'visitsta': 'SUCCESSFUL',
#    'visitype': 'PRIME_TARGETED_FIXED',
#    'vststart': '/Date(1453012879720)/',
#    'xoffset': -9.2231701051478e-13,
#    'yoffset': -1.1160251102231e-11,
#    'zerofram': 'F'},
#   {'ArchiveFileID': 5749470,
#    'FileSetId': 153955,
#    'FileTypeID': 37,
#    'act_id': '04',
#    'apername': 'MIRIM_FULL',
#    'asnpool': 'jw80600_20180114T194836_pool',
#    'asntable': '/ifs/int/jwst/info/jwowlmgr/build7.1/paths/sdp/asn_creation/cal/lev&',
#    'band': None,
#    'bartdelt': 71.76482398062944,
#    'bendtime': 57404.07802439747,
#    'bkgdtarg': 'F',
#    'bkglevel': None,
#    'bkgsub': None,
#    'bmidtime': 57404.0775105005,
#    'bstrtime': 57404.07699660352,
#    'category': 'ENG',
#    'cccstate': 'OPEN',
#    'channel': None,
#    'checksum': 2752995139,
#    'comprssd': 'F',
#    'cont_id': 0,
#    'coronmsk': None,
#    'dataURI': 'mast:JWST/product/jw80600006001_02104_00001_mirimage_cal.fits',
#    'datamode': 2,
#    'dataprob': 'F',
#    'date': '/Date(1515978393287)/',
#    'date_obs': '/Date(1453013380742)/',
#    'detector': 'MIRIMAGE',
#    'drpfrms1': 0,
#    'drpfrms3': 0,
#    'duration': 88.80128,
#    'dva_dec': -4.9392588794756e-08,
#    'dva_ra': -3.3414033333341e-07,
#    'effexptm': 89.12,
#    'effinttm': 22.20032,
#    'eng_qual': 'SUSPECT',
#    'eph_time': 57404.0763889,
#    'eph_type': 'Predicted',
#    'exp_type': 'MIR_IMAGE',
#    'expcount': 4,
#    'expend': 57404.07719378472,
#    'expmid': 57404.07667988843,
#    'exposure': 1,
#    'expripar': 'PRIME',
#    'expstart': 57404.07616599213,
#    'fastaxis': 1,
#    'fileSetName': 'jw80600006001_02104_00001',
#    'fileSize': 25410240,
#    'filename': 'jw80600006001_02104_00001_mirimage_cal.fits',
#    'filetype': 'uncalibrated',
#    'filter': 'F2100W',
#    'frmdivsr': 4,
#    'gdstarid': '',
#    'groupgap': 0,
#    'gs_dec': 0,
#    'gs_mag': 0,
#    'gs_order': 0,
#    'gs_ra': 0,
#    'gs_udec': 0,
#    'gs_umag': 0,
#    'gs_ura': 0,
#    'gsendtim': '/Date(915166800000)/',
#    'gsstrttm': '/Date(915166800000)/',
#    'helidelt': 71.70973476022482,
#    'hendtime': 57404.07802375986,
#    'hga_move': 'F',
#    'hmidtime': 57404.07750986289,
#    'hstrtime': 57404.07699596592,
#    'ingestCompletionDate': '/Date(1515978455460)/',
#    'ingestStartDate': '/Date(1515978445184)/',
#    'instrume': 'MIRI',
#    'intarget': 'F',
#    'isItar': False,
#    'isRestricted': False,
#    'isStale': True,
#    'jwst_dx': 0.00725060618900875,
#    'jwst_dy': -0.0392368253761936,
#    'jwst_dz': -0.0442609887947373,
#    'jwst_x': -1475409.4364743,
#    'jwst_y': -631741.316258069,
#    'jwst_z': -580447.520401273,
#    'lamp': '',
#    'mu_dec': 0,
#    'mu_epoch': '/Date(946702800000)/',
#    'mu_ra': 0,
#    'nexposur': 4,
#    'nextend': 3,
#    'nframes': 1,
#    'ngroups': 2,
#    'nints': 4,
#    'nresets': 0,
#    'nrststrt': 0,
#    'nsamples': 1,
#    'numdthpt': 0,
#    'nwfsest': None,
#    'obs_id': 'V80600006001P0000000002104',
#    'observtn': 6,
#    'obslabel': 'MIRI Imaging 006',
#    'origin': 'STSCI',
#    'patt_num': 0,
#    'pattsize': None,
#    'pattstrt': 0,
#    'patttype': 'NONE',
#    'pcs_mode': 'COARSE',
#    'pi_name': 'N/A',
#    'pntg_seq': 4,
#    'pps_aper': 'MIRIM_ILLUM',
#    'prd_ver': 'PRDOPSSOC-G-010',
#    'productLevel': '2b',
#    'program': 80600,
#    'prop_dec': -66.59798333333333,
#    'prop_ra': 6.128166666666667,
#    'psfref': None,
#    'publicReleaseDate': '/Date(2114398800000)/',
#    'pwfseet': None,
#    'readpatt': 'FASTGRPAVG',
#    'refframe': 'EME2000',
#    's_region': 'POLYGON ICRS  6.177969888833616 -66.61546357077478 6.184462279495496 -66.58397889876007 6.105686171809398 -66.58152977717666 6.09913196364043 -66.61272265045194',
#    'sca_num': 493,
#    'scicat': '',
#    'sdp_ver': '2017_1',
#    'selfref': None,
#    'seq_id': '1',
#    'slowaxis': 2,
#    'spat_num': None,
#    'spatnstp': None,
#    'spatstep': None,
#    'spcoffst': None,
#    'spec_num': None,
#    'specnstp': None,
#    'specstep': None,
#    'sptoffst': None,
#    'srctype': None,
#    'subarray': 'FULL',
#    'subcat': '',
#    'subpxnum': 0,
#    'subsize1': 1032,
#    'subsize2': 1024,
#    'substrt1': 1,
#    'substrt2': 1,
#    'targ_dec': -66.59798333333333,
#    'targ_ra': 6.128166666666667,
#    'targname': '',
#    'targoopp': 'F',
#    'targprop': '2MASS-J00243075-6635527',
#    'targtype': 'FIXED',
#    'targudec': 0.1,
#    'targura': 0.1,
#    'telescop': 'JWST',
#    'template': 'MIRI Imaging',
#    'tframe': 2.77504,
#    'tgroup': 2.77504,
#    'timesys': 'UTC',
#    'title': 'MIRI Cryo3 SIC',
#    'tsample': 10,
#    'tsovisit': 'F',
#    'visit': 1,
#    'visit_id': '80600006001',
#    'visitend': '/Date(1453013512552)/',
#    'visitgrp': '02',
#    'visitsta': 'SUCCESSFUL',
#    'visitype': 'PRIME_TARGETED_FIXED',
#    'vststart': '/Date(1453012879720)/',
#    'xoffset': -9.2231701051478e-13,
#    'yoffset': -1.1160251102231e-11,
#    'zerofram': 'F'},
#   {'ArchiveFileID': 5749476,
#    'FileSetId': 153955,
#    'FileTypeID': 37,
#    'act_id': '04',
#    'apername': 'MIRIM_FULL',
#    'asnpool': None,
#    'asntable': None,
#    'band': None,
#    'bartdelt': 71.76482398062944,
#    'bendtime': 57404.07802439747,
#    'bkgdtarg': 'F',
#    'bkglevel': None,
#    'bkgsub': None,
#    'bmidtime': 57404.0775105005,
#    'bstrtime': 57404.07699660352,
#    'category': 'ENG',
#    'cccstate': 'OPEN',
#    'channel': None,
#    'checksum': 992095619,
#    'comprssd': 'F',
#    'cont_id': 0,
#    'coronmsk': None,
#    'dataURI': 'mast:JWST/product/jw80600006001_02104_00001_mirimage_i2d.fits',
#    'datamode': 2,
#    'dataprob': 'F',
#    'date': '/Date(1515978393014)/',
#    'date_obs': '/Date(1453013380742)/',
#    'detector': 'MIRIMAGE',
#    'drpfrms1': 0,
#    'drpfrms3': 0,
#    'duration': 88.80128,
#    'dva_dec': -4.9392588794756e-08,
#    'dva_ra': -3.3414033333341e-07,
#    'effexptm': 89.12,
#    'effinttm': 22.20032,
#    'eng_qual': 'SUSPECT',
#    'eph_time': 57404.0763889,
#    'eph_type': 'Predicted',
#    'exp_type': 'MIR_IMAGE',
#    'expcount': 4,
#    'expend': 57404.07719378472,
#    'expmid': 57404.07667988843,
#    'exposure': 1,
#    'expripar': 'PRIME',
#    'expstart': 57404.07616599213,
#    'fastaxis': 1,
#    'fileSetName': 'jw80600006001_02104_00001',
#    'fileSize': 14592960,
#    'filename': 'jw80600006001_02104_00001_mirimage_i2d.fits',
#    'filetype': 'uncalibrated',
#    'filter': 'F2100W',
#    'frmdivsr': 4,
#    'gdstarid': '',
#    'groupgap': 0,
#    'gs_dec': 0,
#    'gs_mag': 0,
#    'gs_order': 0,
#    'gs_ra': 0,
#    'gs_udec': 0,
#    'gs_umag': 0,
#    'gs_ura': 0,
#    'gsendtim': '/Date(915166800000)/',
#    'gsstrttm': '/Date(915166800000)/',
#    'helidelt': 71.70973476022482,
#    'hendtime': 57404.07802375986,
#    'hga_move': 'F',
#    'hmidtime': 57404.07750986289,
#    'hstrtime': 57404.07699596592,
#    'ingestCompletionDate': '/Date(1515978455994)/',
#    'ingestStartDate': '/Date(1515978445184)/',
#    'instrume': 'MIRI',
#    'intarget': 'F',
#    'isItar': False,
#    'isRestricted': False,
#    'isStale': True,
#    'jwst_dx': 0.00725060618900875,
#    'jwst_dy': -0.0392368253761936,
#    'jwst_dz': -0.0442609887947373,
#    'jwst_x': -1475409.4364743,
#    'jwst_y': -631741.316258069,
#    'jwst_z': -580447.520401273,
#    'lamp': '',
#    'mu_dec': 0,
#    'mu_epoch': '/Date(946702800000)/',
#    'mu_ra': 0,
#    'nexposur': 4,
#    'nextend': 3,
#    'nframes': 1,
#    'ngroups': 2,
#    'nints': 4,
#    'nresets': 0,
#    'nrststrt': 0,
#    'nsamples': 1,
#    'numdthpt': 0,
#    'nwfsest': None,
#    'obs_id': 'V80600006001P0000000002104',
#    'observtn': 6,
#    'obslabel': 'MIRI Imaging 006',
#    'origin': 'STSCI',
#    'patt_num': 0,
#    'pattsize': None,
#    'pattstrt': 0,
#    'patttype': 'NONE',
#    'pcs_mode': 'COARSE',
#    'pi_name': 'N/A',
#    'pntg_seq': 4,
#    'pps_aper': 'MIRIM_ILLUM',
#    'prd_ver': 'PRDOPSSOC-G-010',
#    'productLevel': '2b',
#    'program': 80600,
#    'prop_dec': -66.59798333333333,
#    'prop_ra': 6.128166666666667,
#    'psfref': None,
#    'publicReleaseDate': '/Date(2114398800000)/',
#    'pwfseet': None,
#    'readpatt': 'FASTGRPAVG',
#    'refframe': 'EME2000',
#    's_region': 'POLYGON ICRS  6.1845411482371695 -66.61540639523375 6.184482777370162 -66.5814822592075 6.099204616980658 -66.58148225723129 6.099146236145126 -66.6154063932543',
#    'sca_num': 493,
#    'scicat': '',
#    'sdp_ver': '2017_1',
#    'selfref': None,
#    'seq_id': '1',
#    'slowaxis': 2,
#    'spat_num': None,
#    'spatnstp': None,
#    'spatstep': None,
#    'spcoffst': None,
#    'spec_num': None,
#    'specnstp': None,
#    'specstep': None,
#    'sptoffst': None,
#    'srctype': None,
#    'subarray': 'FULL',
#    'subcat': '',
#    'subpxnum': 0,
#    'subsize1': 1032,
#    'subsize2': 1024,
#    'substrt1': 1,
#    'substrt2': 1,
#    'targ_dec': -66.59798333333333,
#    'targ_ra': 6.128166666666667,
#    'targname': '',
#    'targoopp': 'F',
#    'targprop': '2MASS-J00243075-6635527',
#    'targtype': 'FIXED',
#    'targudec': 0.1,
#    'targura': 0.1,
#    'telescop': 'JWST',
#    'template': 'MIRI Imaging',
#    'tframe': 2.77504,
#    'tgroup': 2.77504,
#    'timesys': 'UTC',
#    'title': 'MIRI Cryo3 SIC',
#    'tsample': 10,
#    'tsovisit': 'F',
#    'visit': 1,
#    'visit_id': '80600006001',
#    'visitend': '/Date(1453013512552)/',
#    'visitgrp': '02',
#    'visitsta': 'SUCCESSFUL',
#    'visitype': 'PRIME_TARGETED_FIXED',
#    'vststart': '/Date(1453012879720)/',
#    'xoffset': -9.2231701051478e-13,
#    'yoffset': -1.1160251102231e-11,
#    'zerofram': 'F'},
#   {'ArchiveFileID': 5749512,
#    'FileSetId': 153916,
#    'FileTypeID': 37,
#    'act_id': '03',
#    'apername': 'MIRIM_FULL',
#    'asnpool': 'jw80600_20180114T194836_pool',
#    'asntable': '/ifs/int/jwst/info/jwowlmgr/build7.1/paths/sdp/asn_creation/cal/lev&',
#    'band': None,
#    'bartdelt': 71.76465110387653,
#    'bendtime': 57404.07625772848,
#    'bkgdtarg': 'F',
#    'bkglevel': None,
#    'bkgsub': None,
#    'bmidtime': 57404.07587230574,
#    'bstrtime': 57404.075486883,
#    'category': 'ENG',
#    'cccstate': 'OPEN',
#    'channel': None,
#    'checksum': 3560315397,
#    'comprssd': 'F',
#    'cont_id': 0,
#    'coronmsk': None,
#    'dataURI': 'mast:JWST/product/jw80600006001_02103_00001_mirimage_cal.fits',
#    'datamode': 2,
#    'dataprob': 'F',
#    'date': '/Date(1515978408761)/',
#    'date_obs': '/Date(1453013250302)/',
#    'detector': 'MIRIMAGE',
#    'drpfrms1': 0,
#    'drpfrms3': 0,
#    'duration': 66.60096,
#    'dva_dec': -4.9391950798096e-08,
#    'dva_ra': -3.3412746047095e-07,
#    'effexptm': 66.84,
#    'effinttm': 11.10016,
#    'eng_qual': 'SUSPECT',
#    'eph_time': 57404.075,
#    'eph_type': 'Predicted',
#    'exp_type': 'MIR_IMAGE',
#    'expcount': 3,
#    'expend': 57404.07542711806,
#    'expmid': 57404.07504169583,
#    'exposure': 1,
#    'expripar': 'PRIME',
#    'expstart': 57404.07465627361,
#    'fastaxis': 1,
#    'fileSetName': 'jw80600006001_02103_00001',
#    'fileSize': 25410240,
#    'filename': 'jw80600006001_02103_00001_mirimage_cal.fits',
#    'filetype': 'uncalibrated',
#    'filter': 'F2100W',
#    'frmdivsr': 4,
#    'gdstarid': '',
#    'groupgap': 0,
#    'gs_dec': 0,
#    'gs_mag': 0,
#    'gs_order': 0,
#    'gs_ra': 0,
#    'gs_udec': 0,
#    'gs_umag': 0,
#    'gs_ura': 0,
#    'gsendtim': '/Date(915166800000)/',
#    'gsstrttm': '/Date(915166800000)/',
#    'helidelt': 71.7095618834719,
#    'hendtime': 57404.07625709086,
#    'hga_move': 'F',
#    'hmidtime': 57404.07587166812,
#    'hstrtime': 57404.07548624539,
#    'ingestCompletionDate': '/Date(1515978462120)/',
#    'ingestStartDate': '/Date(1515978446934)/',
#    'instrume': 'MIRI',
#    'intarget': 'F',
#    'isItar': False,
#    'isRestricted': False,
#    'isStale': True,
#    'jwst_dx': 0.00725230972452099,
#    'jwst_dy': -0.0392351008716741,
#    'jwst_dz': -0.0442648463775117,
#    'jwst_x': -1475410.30995823,
#    'jwst_y': -631736.613783476,
#    'jwst_z': -580442.210790321,
#    'lamp': '',
#    'mu_dec': 0,
#    'mu_epoch': '/Date(946702800000)/',
#    'mu_ra': 0,
#    'nexposur': 4,
#    'nextend': 3,
#    'nframes': 1,
#    'ngroups': 1,
#    'nints': 6,
#    'nresets': 0,
#    'nrststrt': 0,
#    'nsamples': 1,
#    'numdthpt': 0,
#    'nwfsest': None,
#    'obs_id': 'V80600006001P0000000002103',
#    'observtn': 6,
#    'obslabel': 'MIRI Imaging 006',
#    'origin': 'STSCI',
#    'patt_num': 0,
#    'pattsize': None,
#    'pattstrt': 0,
#    'patttype': 'NONE',
#    'pcs_mode': 'COARSE',
#    'pi_name': 'N/A',
#    'pntg_seq': 3,
#    'pps_aper': 'MIRIM_ILLUM',
#    'prd_ver': 'PRDOPSSOC-G-010',
#    'productLevel': '2b',
#    'program': 80600,
#    'prop_dec': -66.59798333333333,
#    'prop_ra': 6.128166666666667,
#    'psfref': None,
#    'publicReleaseDate': '/Date(2114398800000)/',
#    'pwfseet': None,
#    'readpatt': 'FASTGRPAVG',
#    'refframe': 'EME2000',
#    's_region': 'POLYGON ICRS  6.177969888833616 -66.61546357077478 6.184462279495496 -66.58397889876007 6.105686171809398 -66.58152977717666 6.09913196364043 -66.61272265045194',
#    'sca_num': 493,
#    'scicat': '',
#    'sdp_ver': '2017_1',
#    'selfref': None,
#    'seq_id': '1',
#    'slowaxis': 2,
#    'spat_num': None,
#    'spatnstp': None,
#    'spatstep': None,
#    'spcoffst': None,
#    'spec_num': None,
#    'specnstp': None,
#    'specstep': None,
#    'sptoffst': None,
#    'srctype': None,
#    'subarray': 'FULL',
#    'subcat': '',
#    'subpxnum': 0,
#    'subsize1': 1032,
#    'subsize2': 1024,
#    'substrt1': 1,
#    'substrt2': 1,
#    'targ_dec': -66.59798333333333,
#    'targ_ra': 6.128166666666667,
#    'targname': '',
#    'targoopp': 'F',
#    'targprop': '2MASS-J00243075-6635527',
#    'targtype': 'FIXED',
#    'targudec': 0.1,
#    'targura': 0.1,
#    'telescop': 'JWST',
#    'template': 'MIRI Imaging',
#    'tframe': 2.77504,
#    'tgroup': 2.77504,
#    'timesys': 'UTC',
#    'title': 'MIRI Cryo3 SIC',
#    'tsample': 10,
#    'tsovisit': 'F',
#    'visit': 1,
#    'visit_id': '80600006001',
#    'visitend': '/Date(1453013512552)/',
#    'visitgrp': '02',
#    'visitsta': 'SUCCESSFUL',
#    'visitype': 'PRIME_TARGETED_FIXED',
#    'vststart': '/Date(1453012879720)/',
#    'xoffset': -9.2231701051478e-13,
#    'yoffset': -1.1160251102231e-11,
#    'zerofram': 'F'},
#   {'ArchiveFileID': 5749518,
#    'FileSetId': 153916,
#    'FileTypeID': 37,
#    'act_id': '03',
#    'apername': 'MIRIM_FULL',
#    'asnpool': None,
#    'asntable': None,
#    'band': None,
#    'bartdelt': 71.76465110387653,
#    'bendtime': 57404.07625772848,
#    'bkgdtarg': 'F',
#    'bkglevel': None,
#    'bkgsub': None,
#    'bmidtime': 57404.07587230574,
#    'bstrtime': 57404.075486883,
#    'category': 'ENG',
#    'cccstate': 'OPEN',
#    'channel': None,
#    'checksum': 2338585038,
#    'comprssd': 'F',
#    'cont_id': 0,
#    'coronmsk': None,
#    'dataURI': 'mast:JWST/product/jw80600006001_02103_00001_mirimage_i2d.fits',
#    'datamode': 2,
#    'dataprob': 'F',
#    'date': '/Date(1515978408481)/',
#    'date_obs': '/Date(1453013250302)/',
#    'detector': 'MIRIMAGE',
#    'drpfrms1': 0,
#    'drpfrms3': 0,
#    'duration': 66.60096,
#    'dva_dec': -4.9391950798096e-08,
#    'dva_ra': -3.3412746047095e-07,
#    'effexptm': 66.84,
#    'effinttm': 11.10016,
#    'eng_qual': 'SUSPECT',
#    'eph_time': 57404.075,
#    'eph_type': 'Predicted',
#    'exp_type': 'MIR_IMAGE',
#    'expcount': 3,
#    'expend': 57404.07542711806,
#    'expmid': 57404.07504169583,
#    'exposure': 1,
#    'expripar': 'PRIME',
#    'expstart': 57404.07465627361,
#    'fastaxis': 1,
#    'fileSetName': 'jw80600006001_02103_00001',
#    'fileSize': 14592960,
#    'filename': 'jw80600006001_02103_00001_mirimage_i2d.fits',
#    'filetype': 'uncalibrated',
#    'filter': 'F2100W',
#    'frmdivsr': 4,
#    'gdstarid': '',
#    'groupgap': 0,
#    'gs_dec': 0,
#    'gs_mag': 0,
#    'gs_order': 0,
#    'gs_ra': 0,
#    'gs_udec': 0,
#    'gs_umag': 0,
#    'gs_ura': 0,
#    'gsendtim': '/Date(915166800000)/',
#    'gsstrttm': '/Date(915166800000)/',
#    'helidelt': 71.7095618834719,
#    'hendtime': 57404.07625709086,
#    'hga_move': 'F',
#    'hmidtime': 57404.07587166812,
#    'hstrtime': 57404.07548624539,
#    'ingestCompletionDate': '/Date(1515978462719)/',
#    'ingestStartDate': '/Date(1515978446934)/',
#    'instrume': 'MIRI',
#    'intarget': 'F',
#    'isItar': False,
#    'isRestricted': False,
#    'isStale': True,
#    'jwst_dx': 0.00725230972452099,
#    'jwst_dy': -0.0392351008716741,
#    'jwst_dz': -0.0442648463775117,
#    'jwst_x': -1475410.30995823,
#    'jwst_y': -631736.613783476,
#    'jwst_z': -580442.210790321,
#    'lamp': '',
#    'mu_dec': 0,
#    'mu_epoch': '/Date(946702800000)/',
#    'mu_ra': 0,
#    'nexposur': 4,
#    'nextend': 3,
#    'nframes': 1,
#    'ngroups': 1,
#    'nints': 6,
#    'nresets': 0,
#    'nrststrt': 0,
#    'nsamples': 1,
#    'numdthpt': 0,
#    'nwfsest': None,
#    'obs_id': 'V80600006001P0000000002103',
#    'observtn': 6,
#    'obslabel': 'MIRI Imaging 006',
#    'origin': 'STSCI',
#    'patt_num': 0,
#    'pattsize': None,
#    'pattstrt': 0,
#    'patttype': 'NONE',
#    'pcs_mode': 'COARSE',
#    'pi_name': 'N/A',
#    'pntg_seq': 3,
#    'pps_aper': 'MIRIM_ILLUM',
#    'prd_ver': 'PRDOPSSOC-G-010',
#    'productLevel': '2b',
#    'program': 80600,
#    'prop_dec': -66.59798333333333,
#    'prop_ra': 6.128166666666667,
#    'psfref': None,
#    'publicReleaseDate': '/Date(2114398800000)/',
#    'pwfseet': None,
#    'readpatt': 'FASTGRPAVG',
#    'refframe': 'EME2000',
#    's_region': 'POLYGON ICRS  6.1845411482371695 -66.61540639523375 6.184482777370162 -66.5814822592075 6.099204616980658 -66.58148225723129 6.099146236145126 -66.6154063932543',
#    'sca_num': 493,
#    'scicat': '',
#    'sdp_ver': '2017_1',
#    'selfref': None,
#    'seq_id': '1',
#    'slowaxis': 2,
#    'spat_num': None,
#    'spatnstp': None,
#    'spatstep': None,
#    'spcoffst': None,
#    'spec_num': None,
#    'specnstp': None,
#    'specstep': None,
#    'sptoffst': None,
#    'srctype': None,
#    'subarray': 'FULL',
#    'subcat': '',
#    'subpxnum': 0,
#    'subsize1': 1032,
#    'subsize2': 1024,
#    'substrt1': 1,
#    'substrt2': 1,
#    'targ_dec': -66.59798333333333,
#    'targ_ra': 6.128166666666667,
#    'targname': '',
#    'targoopp': 'F',
#    'targprop': '2MASS-J00243075-6635527',
#    'targtype': 'FIXED',
#    'targudec': 0.1,
#    'targura': 0.1,
#    'telescop': 'JWST',
#    'template': 'MIRI Imaging',
#    'tframe': 2.77504,
#    'tgroup': 2.77504,
#    'timesys': 'UTC',
#    'title': 'MIRI Cryo3 SIC',
#    'tsample': 10,
#    'tsovisit': 'F',
#    'visit': 1,
#    'visit_id': '80600006001',
#    'visitend': '/Date(1453013512552)/',
#    'visitgrp': '02',
#    'visitsta': 'SUCCESSFUL',
#    'visitype': 'PRIME_TARGETED_FIXED',
#    'vststart': '/Date(1453012879720)/',
#    'xoffset': -9.2231701051478e-13,
#    'yoffset': -1.1160251102231e-11,
#    'zerofram': 'F'},
#   {'ArchiveFileID': 5749519,
#    'FileSetId': 153966,
#    'FileTypeID': 37,
#    'act_id': '02',
#    'apername': 'MIRIM_FULL',
#    'asnpool': 'jw80600_20180114T194836_pool',
#    'asntable': '/ifs/int/jwst/info/jwowlmgr/build7.1/paths/sdp/asn_creation/cal/lev&',
#    'band': None,
#    'bartdelt': 71.7645077733323,
#    'bendtime': 57404.07474809684,
#    'bkgdtarg': 'F',
#    'bkglevel': None,
#    'bkgsub': None,
#    'bmidtime': 57404.07449114835,
#    'bstrtime': 57404.07423419986,
#    'category': 'ENG',
#    'cccstate': 'OPEN',
#    'channel': None,
#    'checksum': 602167224,
#    'comprssd': 'F',
#    'cont_id': 0,
#    'coronmsk': None,
#    'dataURI': 'mast:JWST/product/jw80600006001_02102_00001_mirimage_cal.fits',
#    'datamode': 2,
#    'dataprob': 'F',
#    'date': '/Date(1515978401088)/',
#    'date_obs': '/Date(1453013142070)/',
#    'detector': 'MIRIMAGE',
#    'drpfrms1': 0,
#    'drpfrms3': 0,
#    'duration': 44.40064,
#    'dva_dec': -4.9391309834558e-08,
#    'dva_ra': -3.3411459547687e-07,
#    'effexptm': 44.56,
#    'effinttm': 22.20032,
#    'eng_qual': 'SUSPECT',
#    'eph_time': 57404.0736111,
#    'eph_type': 'Predicted',
#    'exp_type': 'MIR_IMAGE',
#    'expcount': 2,
#    'expend': 57404.07391748843,
#    'expmid': 57404.07366054028,
#    'exposure': 1,
#    'expripar': 'PRIME',
#    'expstart': 57404.07340359213,
#    'fastaxis': 1,
#    'fileSetName': 'jw80600006001_02102_00001',
#    'fileSize': 25410240,
#    'filename': 'jw80600006001_02102_00001_mirimage_cal.fits',
#    'filetype': 'uncalibrated',
#    'filter': 'F2100W',
#    'frmdivsr': 4,
#    'gdstarid': '',
#    'groupgap': 0,
#    'gs_dec': 0,
#    'gs_mag': 0,
#    'gs_order': 0,
#    'gs_ra': 0,
#    'gs_udec': 0,
#    'gs_umag': 0,
#    'gs_ura': 0,
#    'gsendtim': '/Date(915166800000)/',
#    'gsstrttm': '/Date(915166800000)/',
#    'helidelt': 71.70941855292767,
#    'hendtime': 57404.07474745923,
#    'hga_move': 'F',
#    'hmidtime': 57404.07449051074,
#    'hstrtime': 57404.07423356225,
#    'ingestCompletionDate': '/Date(1515978463012)/',
#    'ingestStartDate': '/Date(1515978446480)/',
#    'instrume': 'MIRI',
#    'intarget': 'F',
#    'isItar': False,
#    'isRestricted': False,
#    'isStale': True,
#    'jwst_dx': 0.00725401450016697,
#    'jwst_dy': -0.0392333771762912,
#    'jwst_dz': -0.0442687043704211,
#    'jwst_x': -1475411.18364209,
#    'jwst_y': -631731.911512954,
#    'jwst_z': -580436.900715814,
#    'lamp': '',
#    'mu_dec': 0,
#    'mu_epoch': '/Date(946702800000)/',
#    'mu_ra': 0,
#    'nexposur': 4,
#    'nextend': 3,
#    'nframes': 1,
#    'ngroups': 2,
#    'nints': 2,
#    'nresets': 0,
#    'nrststrt': 0,
#    'nsamples': 1,
#    'numdthpt': 0,
#    'nwfsest': None,
#    'obs_id': 'V80600006001P0000000002102',
#    'observtn': 6,
#    'obslabel': 'MIRI Imaging 006',
#    'origin': 'STSCI',
#    'patt_num': 0,
#    'pattsize': None,
#    'pattstrt': 0,
#    'patttype': 'NONE',
#    'pcs_mode': 'COARSE',
#    'pi_name': 'N/A',
#    'pntg_seq': 2,
#    'pps_aper': 'MIRIM_ILLUM',
#    'prd_ver': 'PRDOPSSOC-G-010',
#    'productLevel': '2b',
#    'program': 80600,
#    'prop_dec': -66.59798333333333,
#    'prop_ra': 6.128166666666667,
#    'psfref': None,
#    'publicReleaseDate': '/Date(2114398800000)/',
#    'pwfseet': None,
#    'readpatt': 'FASTGRPAVG',
#    'refframe': 'EME2000',
#    's_region': 'POLYGON ICRS  6.177969888833616 -66.61546357077478 6.184462279495496 -66.58397889876007 6.105686171809398 -66.58152977717666 6.09913196364043 -66.61272265045194',
#    'sca_num': 493,
#    'scicat': '',
#    'sdp_ver': '2017_1',
#    'selfref': None,
#    'seq_id': '1',
#    'slowaxis': 2,
#    'spat_num': None,
#    'spatnstp': None,
#    'spatstep': None,
#    'spcoffst': None,
#    'spec_num': None,
#    'specnstp': None,
#    'specstep': None,
#    'sptoffst': None,
#    'srctype': None,
#    'subarray': 'FULL',
#    'subcat': '',
#    'subpxnum': 0,
#    'subsize1': 1032,
#    'subsize2': 1024,
#    'substrt1': 1,
#    'substrt2': 1,
#    'targ_dec': -66.59798333333333,
#    'targ_ra': 6.128166666666667,
#    'targname': '',
#    'targoopp': 'F',
#    'targprop': '2MASS-J00243075-6635527',
#    'targtype': 'FIXED',
#    'targudec': 0.1,
#    'targura': 0.1,
#    'telescop': 'JWST',
#    'template': 'MIRI Imaging',
#    'tframe': 2.77504,
#    'tgroup': 2.77504,
#    'timesys': 'UTC',
#    'title': 'MIRI Cryo3 SIC',
#    'tsample': 10,
#    'tsovisit': 'F',
#    'visit': 1,
#    'visit_id': '80600006001',
#    'visitend': '/Date(1453013512552)/',
#    'visitgrp': '02',
#    'visitsta': 'SUCCESSFUL',
#    'visitype': 'PRIME_TARGETED_FIXED',
#    'vststart': '/Date(1453012879720)/',
#    'xoffset': -9.2231701051478e-13,
#    'yoffset': -1.1160251102231e-11,
#    'zerofram': 'F'},
#   {'ArchiveFileID': 5749525,
#    'FileSetId': 153966,
#    'FileTypeID': 37,
#    'act_id': '02',
#    'apername': 'MIRIM_FULL',
#    'asnpool': None,
#    'asntable': None,
#    'band': None,
#    'bartdelt': 71.7645077733323,
#    'bendtime': 57404.07474809684,
#    'bkgdtarg': 'F',
#    'bkglevel': None,
#    'bkgsub': None,
#    'bmidtime': 57404.07449114835,
#    'bstrtime': 57404.07423419986,
#    'category': 'ENG',
#    'cccstate': 'OPEN',
#    'channel': None,
#    'checksum': 3091545834,
#    'comprssd': 'F',
#    'cont_id': 0,
#    'coronmsk': None,
#    'dataURI': 'mast:JWST/product/jw80600006001_02102_00001_mirimage_i2d.fits',
#    'datamode': 2,
#    'dataprob': 'F',
#    'date': '/Date(1515978400540)/',
#    'date_obs': '/Date(1453013142070)/',
#    'detector': 'MIRIMAGE',
#    'drpfrms1': 0,
#    'drpfrms3': 0,
#    'duration': 44.40064,
#    'dva_dec': -4.9391309834558e-08,
#    'dva_ra': -3.3411459547687e-07,
#    'effexptm': 44.56,
#    'effinttm': 22.20032,
#    'eng_qual': 'SUSPECT',
#    'eph_time': 57404.0736111,
#    'eph_type': 'Predicted',
#    'exp_type': 'MIR_IMAGE',
#    'expcount': 2,
#    'expend': 57404.07391748843,
#    'expmid': 57404.07366054028,
#    'exposure': 1,
#    'expripar': 'PRIME',
#    'expstart': 57404.07340359213,
#    'fastaxis': 1,
#    'fileSetName': 'jw80600006001_02102_00001',
#    'fileSize': 14592960,
#    'filename': 'jw80600006001_02102_00001_mirimage_i2d.fits',
#    'filetype': 'uncalibrated',
#    'filter': 'F2100W',
#    'frmdivsr': 4,
#    'gdstarid': '',
#    'groupgap': 0,
#    'gs_dec': 0,
#    'gs_mag': 0,
#    'gs_order': 0,
#    'gs_ra': 0,
#    'gs_udec': 0,
#    'gs_umag': 0,
#    'gs_ura': 0,
#    'gsendtim': '/Date(915166800000)/',
#    'gsstrttm': '/Date(915166800000)/',
#    'helidelt': 71.70941855292767,
#    'hendtime': 57404.07474745923,
#    'hga_move': 'F',
#    'hmidtime': 57404.07449051074,
#    'hstrtime': 57404.07423356225,
#    'ingestCompletionDate': '/Date(1515978463538)/',
#    'ingestStartDate': '/Date(1515978446480)/',
#    'instrume': 'MIRI',
#    'intarget': 'F',
#    'isItar': False,
#    'isRestricted': False,
#    'isStale': True,
#    'jwst_dx': 0.00725401450016697,
#    'jwst_dy': -0.0392333771762912,
#    'jwst_dz': -0.0442687043704211,
#    'jwst_x': -1475411.18364209,
#    'jwst_y': -631731.911512954,
#    'jwst_z': -580436.900715814,
#    'lamp': '',
#    'mu_dec': 0,
#    'mu_epoch': '/Date(946702800000)/',
#    'mu_ra': 0,
#    'nexposur': 4,
#    'nextend': 3,
#    'nframes': 1,
#    'ngroups': 2,
#    'nints': 2,
#    'nresets': 0,
#    'nrststrt': 0,
#    'nsamples': 1,
#    'numdthpt': 0,
#    'nwfsest': None,
#    'obs_id': 'V80600006001P0000000002102',
#    'observtn': 6,
#    'obslabel': 'MIRI Imaging 006',
#    'origin': 'STSCI',
#    'patt_num': 0,
#    'pattsize': None,
#    'pattstrt': 0,
#    'patttype': 'NONE',
#    'pcs_mode': 'COARSE',
#    'pi_name': 'N/A',
#    'pntg_seq': 2,
#    'pps_aper': 'MIRIM_ILLUM',
#    'prd_ver': 'PRDOPSSOC-G-010',
#    'productLevel': '2b',
#    'program': 80600,
#    'prop_dec': -66.59798333333333,
#    'prop_ra': 6.128166666666667,
#    'psfref': None,
#    'publicReleaseDate': '/Date(2114398800000)/',
#    'pwfseet': None,
#    'readpatt': 'FASTGRPAVG',
#    'refframe': 'EME2000',
#    's_region': 'POLYGON ICRS  6.1845411482371695 -66.61540639523375 6.184482777370162 -66.5814822592075 6.099204616980658 -66.58148225723129 6.099146236145126 -66.6154063932543',
#    'sca_num': 493,
#    'scicat': '',
#    'sdp_ver': '2017_1',
#    'selfref': None,
#    'seq_id': '1',
#    'slowaxis': 2,
#    'spat_num': None,
#    'spatnstp': None,
#    'spatstep': None,
#    'spcoffst': None,
#    'spec_num': None,
#    'specnstp': None,
#    'specstep': None,
#    'sptoffst': None,
#    'srctype': None,
#    'subarray': 'FULL',
#    'subcat': '',
#    'subpxnum': 0,
#    'subsize1': 1032,
#    'subsize2': 1024,
#    'substrt1': 1,
#    'substrt2': 1,
#    'targ_dec': -66.59798333333333,
#    'targ_ra': 6.128166666666667,
#    'targname': '',
#    'targoopp': 'F',
#    'targprop': '2MASS-J00243075-6635527',
#    'targtype': 'FIXED',
#    'targudec': 0.1,
#    'targura': 0.1,
#    'telescop': 'JWST',
#    'template': 'MIRI Imaging',
#    'tframe': 2.77504,
#    'tgroup': 2.77504,
#    'timesys': 'UTC',
#    'title': 'MIRI Cryo3 SIC',
#    'tsample': 10,
#    'tsovisit': 'F',
#    'visit': 1,
#    'visit_id': '80600006001',
#    'visitend': '/Date(1453013512552)/',
#    'visitgrp': '02',
#    'visitsta': 'SUCCESSFUL',
#    'visitype': 'PRIME_TARGETED_FIXED',
#    'vststart': '/Date(1453012879720)/',
#    'xoffset': -9.2231701051478e-13,
#    'yoffset': -1.1160251102231e-11,
#    'zerofram': 'F'},
#   {'ArchiveFileID': 5749961,
#    'FileSetId': 153919,
#    'FileTypeID': 37,
#    'act_id': '01',
#    'apername': 'MIRIM_FULL',
#    'asnpool': 'jw80600_20180114T194836_pool',
#    'asntable': '/ifs/int/jwst/info/jwowlmgr/build7.1/paths/sdp/asn_creation/cal/lev&',
#    'band': None,
#    'bartdelt': 71.79637933149934,
#    'bendtime': 57404.35884180604,
#    'bkgdtarg': 'F',
#    'bkglevel': None,
#    'bkgsub': None,
#    'bmidtime': 57404.35593851332,
#    'bstrtime': 57404.35303522059,
#    'category': 'ENG',
#    'cccstate': 'OPEN',
#    'channel': None,
#    'checksum': 386326941,
#    'comprssd': 'F',
#    'cont_id': 0,
#    'coronmsk': None,
#    'dataURI': 'mast:JWST/product/jw80600009001_02101_00001_mirimage_cal.fits',
#    'datamode': 0,
#    'dataprob': 'F',
#    'date': '/Date(1515978475667)/',
#    'date_obs': '/Date(1453037230447)/',
#    'detector': 'MIRIMAGE',
#    'drpfrms1': 0,
#    'drpfrms3': 0,
#    'duration': 501.68832,
#    'dva_dec': -4.9451368393218e-08,
#    'dva_ra': -3.3689315253621e-07,
#    'effexptm': 569.436,
#    'effinttm': 167.22944,
#    'eng_qual': 'SUSPECT',
#    'eph_time': 57404.3548611,
#    'eph_type': 'Predicted',
#    'exp_type': 'MIR_IMAGE',
#    'expcount': 1,
#    'expend': 57404.35801082176,
#    'expmid': 57404.35510753287,
#    'exposure': 1,
#    'expripar': 'PRIME',
#    'expstart': 57404.35220424398,
#    'fastaxis': 1,
#    'fileSetName': 'jw80600009001_02101_00001',
#    'fileSize': 25410240,
#    'filename': 'jw80600009001_02101_00001_mirimage_cal.fits',
#    'filetype': 'uncalibrated',
#    'filter': 'F1130W',
#    'frmdivsr': 1,
#    'gdstarid': '',
#    'groupgap': 0,
#    'gs_dec': 0,
#    'gs_mag': 0,
#    'gs_order': 0,
#    'gs_ra': 0,
#    'gs_udec': 0,
#    'gs_umag': 0,
#    'gs_ura': 0,
#    'gsendtim': '/Date(915166800000)/',
#    'gsstrttm': '/Date(915166800000)/',
#    'helidelt': 71.74128885380924,
#    'hendtime': 57404.35884116842,
#    'hga_move': 'F',
#    'hmidtime': 57404.3559378757,
#    'hstrtime': 57404.35303458297,
#    'ingestCompletionDate': '/Date(1515978544765)/',
#    'ingestStartDate': '/Date(1515978536617)/',
#    'instrume': 'MIRI',
#    'intarget': 'F',
#    'isItar': False,
#    'isRestricted': False,
#    'isStale': True,
#    'jwst_dx': 0.00693760679442762,
#    'jwst_dy': -0.0396000975091917,
#    'jwst_dz': -0.043496652073439,
#    'jwst_x': -1475238.50515492,
#    'jwst_y': -632689.656635263,
#    'jwst_z': -581503.247446088,
#    'lamp': '',
#    'mu_dec': 0,
#    'mu_epoch': '/Date(946702800000)/',
#    'mu_ra': 0,
#    'nexposur': 1,
#    'nextend': 3,
#    'nframes': 1,
#    'ngroups': 7,
#    'nints': 3,
#    'nresets': 0,
#    'nrststrt': 0,
#    'nsamples': 10,
#    'numdthpt': 0,
#    'nwfsest': None,
#    'obs_id': 'V80600009001P0000000002101',
#    'observtn': 9,
#    'obslabel': 'MIRI Imaging 009',
#    'origin': 'STSCI',
#    'patt_num': 0,
#    'pattsize': None,
#    'pattstrt': 0,
#    'patttype': 'NONE',
#    'pcs_mode': 'COARSE',
#    'pi_name': 'N/A',
#    'pntg_seq': 1,
#    'pps_aper': 'MIRIM_ILLUM',
#    'prd_ver': 'PRDOPSSOC-G-010',
#    'productLevel': '2b',
#    'program': 80600,
#    'prop_dec': -66.59798333333333,
#    'prop_ra': 6.128166666666667,
#    'psfref': None,
#    'publicReleaseDate': '/Date(2114398800000)/',
#    'pwfseet': None,
#    'readpatt': 'SLOW',
#    'refframe': 'EME2000',
#    's_region': 'POLYGON ICRS  6.177954980088111 -66.61547297629151 6.184447731506927 -66.58398828260854 6.105670806355699 -66.5815391434515 6.099117015886037 -66.61273197435935',
#    'sca_num': 493,
#    'scicat': '',
#    'sdp_ver': '2017_1',
#    'selfref': None,
#    'seq_id': '1',
#    'slowaxis': 2,
#    'spat_num': None,
#    'spatnstp': None,
#    'spatstep': None,
#    'spcoffst': None,
#    'spec_num': None,
#    'specnstp': None,
#    'specstep': None,
#    'sptoffst': None,
#    'srctype': None,
#    'subarray': 'FULL',
#    'subcat': '',
#    'subpxnum': 0,
#    'subsize1': 1032,
#    'subsize2': 1024,
#    'substrt1': 1,
#    'substrt2': 1,
# ...
#    'targprop': '',
#    'targtype': 'FIXED',
#    'targudec': 0,
#    'targura': 0,
#    'telescop': 'JWST',
#    'template': 'MIRI Dark',
#    'tframe': 2.77504,
#    'tgroup': 2.77504,
#    'timesys': 'UTC',
#    'title': 'MIRI IMG_RAD-01 Dark Behavior',
#    'tsample': 10,
#    'tsovisit': 'F',
#    'visit': 1,
#    'visit_id': '98011001001',
#    'visitend': '/Date(1453636779990)/',
#    'visitgrp': '02',
#    'visitsta': 'SUCCESSFUL',
#    'visitype': 'PRIME_UNTARGETED',
#    'vststart': '/Date(1453632253910)/',
#    'xoffset': 0,
#    'yoffset': 0,
#    'zerofram': 'F'},
#   {'ArchiveFileID': 5945466,
#    'FileSetId': 155587,
#    'FileTypeID': 36,
#    'act_id': '01',
#    'apername': 'MIRIM_FULL',
#    'asnpool': None,
#    'asntable': None,
#    'band': None,
#    'bartdelt': -205.6708329822868,
#    'bendtime': 57411.26570824867,
#    'bkgdtarg': 'F',
#    'bkglevel': None,
#    'bkgsub': None,
#    'bmidtime': 57411.26313898409,
#    'bstrtime': 57411.26056971952,
#    'category': 'ENG',
#    'cccstate': 'OPEN',
#    'channel': None,
#    'checksum': 2632985758,
#    'comprssd': 'F',
#    'cont_id': 0,
#    'coronmsk': None,
#    'dataURI': 'mast:JWST/product/jw98011001001_02101_00005_mirimage_dark.fits',
#    'datamode': 1,
#    'dataprob': 'F',
#    'date': '/Date(1519785601224)/',
#    'date_obs': '/Date(1453634318895)/',
#    'detector': 'MIRIMAGE',
#    'drpfrms1': 0,
#    'drpfrms3': 0,
#    'duration': 444.0064,
#    'dva_dec': -8.7243037341898e-08,
#    'dva_ra': -1.647947547658e-07,
#    'effexptm': 445.6,
#    'effinttm': 111.0016,
#    'eng_qual': 'SUSPECT',
#    'eph_time': 57411.2652778,
#    'eph_type': 'Predicted',
#    'exp_type': 'MIR_DARK',
#    'expcount': 1,
#    'expend': 57411.26808913195,
#    'expmid': 57411.26551965046,
#    'exposure': 5,
#    'expripar': 'PRIME',
#    'expstart': 57411.26295016898,
#    'fastaxis': 1,
#    'fileSetName': 'jw98011001001_02101_00005',
#    'fileSize': 1695133440,
#    'filename': 'jw98011001001_02101_00005_mirimage_dark.fits',
#    'filetype': 'uncalibrated',
#    'filter': 'OPAQUE',
#    'frmdivsr': 1,
#    'gdstarid': '',
#    'groupgap': 0,
#    'gs_dec': 0,
#    'gs_mag': 0,
#    'gs_order': 0,
#    'gs_ra': 0,
#    'gs_udec': 0,
#    'gs_umag': 0,
#    'gs_ura': 0,
#    'gsendtim': '/Date(915166800000)/',
#    'gsstrttm': '/Date(915166800000)/',
#    'helidelt': -207.5445724418387,
#    'hendtime': 57411.26568656186,
#    'hga_move': 'F',
#    'hmidtime': 57411.26311729728,
#    'hstrtime': 57411.26054803273,
#    'ingestCompletionDate': '/Date(1519785722897)/',
#    'ingestStartDate': '/Date(1519785650135)/',
#    'instrume': 'MIRI',
#    'intarget': 'T',
#    'isItar': False,
#    'isRestricted': False,
#    'isStale': False,
#    'jwst_dx': 0.0160949166499416,
#    'jwst_dy': -0.0494042245967471,
#    'jwst_dz': -0.0261548046081135,
#    'jwst_x': -1469866.59356675,
#    'jwst_y': -659663.321927138,
#    'jwst_z': -602338.734740686,
#    'lamp': '',
#    'mu_dec': 0,
#    'mu_epoch': '/Date(946702800000)/',
#    'mu_ra': 0,
#    'nexposur': 6,
#    'nextend': 3,
#    'nframes': 1,
#    'ngroups': 40,
#    'nints': 4,
#    'nresets': 0,
#    'nrststrt': 0,
#    'nsamples': 1,
#    'numdthpt': 0,
#    'nwfsest': None,
#    'obs_id': 'V98011001001P0000000002101',
#    'observtn': 1,
#    'obslabel': 'MIRI IMG-RAD-01 Dark Behavior',
#    'origin': 'STSCI',
#    'patt_num': 0,
#    'pattsize': None,
#    'pattstrt': 0,
#    'patttype': 'NONE',
#    'pcs_mode': 'NONE',
#    'pi_name': '',
#    'pntg_seq': 1,
#    'pps_aper': '',
#    'prd_ver': 'PRDOPSSOC-G-013',
#    'productLevel': '2a',
#    'program': 98011,
#    'prop_dec': 0,
#    'prop_ra': 0,
#    'psfref': None,
#    'publicReleaseDate': '/Date(2114398800000)/',
#    'pwfseet': None,
#    'readpatt': 'FAST',
#    'refframe': 'EME2000',
#    's_region': 'POLYGON ICRS  0.019988230399368877 -0.03943060701110157 359.9884418571164 -0.036825027398398526 359.99087303350353 -0.005619366485258326 0.022432703733912894 -0.007935967820728964',
#    'sca_num': 493,
#    'scicat': '',
#    'sdp_ver': '2017_1b',
#    'selfref': None,
#    'seq_id': '1',
#    'slowaxis': 2,
#    'spat_num': None,
#    'spatnstp': None,
#    'spatstep': None,
#    'spcoffst': None,
#    'spec_num': None,
#    'specnstp': None,
#    'specstep': None,
#    'sptoffst': None,
#    'srctype': None,
#    'subarray': 'FULL',
#    'subcat': '',
#    'subpxnum': 0,
#    'subsize1': 1032,
#    'subsize2': 1024,
#    'substrt1': 1,
#    'substrt2': 1,
#    'targ_dec': 0,
#    'targ_ra': 0,
#    'targname': '',
#    'targoopp': 'F',
#    'targprop': '',
#    'targtype': 'FIXED',
#    'targudec': 0,
#    'targura': 0,
#    'telescop': 'JWST',
#    'template': 'MIRI Dark',
#    'tframe': 2.77504,
#    'tgroup': 2.77504,
#    'timesys': 'UTC',
#    'title': 'MIRI IMG_RAD-01 Dark Behavior',
#    'tsample': 10,
#    'tsovisit': 'F',
#    'visit': 1,
#    'visit_id': '98011001001',
#    'visitend': '/Date(1453636779990)/',
#    'visitgrp': '02',
#    'visitsta': 'SUCCESSFUL',
#    'visitype': 'PRIME_UNTARGETED',
#    'vststart': '/Date(1453632253910)/',
#    'xoffset': 0,
#    'yoffset': 0,
#    'zerofram': 'F'},
#   {'ArchiveFileID': 5946533,
#    'FileSetId': 155609,
#    'FileTypeID': 36,
#    'act_id': '01',
#    'apername': 'MIRIM_FULL',
#    'asnpool': None,
#    'asntable': None,
#    'band': None,
#    'bartdelt': -206.1846654396504,
#    'bendtime': 57411.33264482212,
#    'bkgdtarg': 'F',
#    'bkglevel': None,
#    'bkgsub': None,
#    'bmidtime': 57411.33184192689,
#    'bstrtime': 57411.33103903165,
#    'category': 'ENG',
#    'cccstate': 'OPEN',
#    'channel': None,
#    'checksum': 3832115346,
#    'comprssd': 'F',
#    'cont_id': 0,
#    'coronmsk': None,
#    'dataURI': 'mast:JWST/product/jw98012002001_02101_00001_mirimage_dark.fits',
#    'datamode': 1,
#    'dataprob': 'F',
#    'date': '/Date(1519785833795)/',
#    'date_obs': '/Date(1453640407957)/',
#    'detector': 'MIRIMAGE',
#    'drpfrms1': 0,
#    'drpfrms3': 0,
#    'duration': 138.752,
#    'dva_dec': -8.6593255942979e-08,
#    'dva_ra': -1.6485614603551e-07,
#    'effexptm': 139.25,
#    'effinttm': 27.7504,
#    'eng_qual': 'SUSPECT',
#    'eph_time': 57411.3340278,
#    'eph_type': 'Predicted',
#    'exp_type': 'MIR_DARK',
#    'expcount': 1,
#    'expend': 57411.33503135417,
#    'expmid': 57411.33422839121,
#    'exposure': 1,
#    'expripar': 'PRIME',
#    'expstart': 57411.33342542824,
#    'fastaxis': 1,
#    'fileSetName': 'jw98012002001_02101_00001',
#    'fileSize': 532676160,
#    'filename': 'jw98012002001_02101_00001_mirimage_dark.fits',
#    'filetype': 'uncalibrated',
#    'filter': 'OPAQUE',
#    'frmdivsr': 1,
#    'gdstarid': '',
#    'groupgap': 0,
#    'gs_dec': 0,
#    'gs_mag': 0,
#    'gs_order': 0,
#    'gs_ra': 0,
#    'gs_udec': 0,
#    'gs_umag': 0,
#    'gs_ura': 0,
#    'gsendtim': '/Date(915166800000)/',
#    'gsstrttm': '/Date(915166800000)/',
#    'helidelt': -208.0584256444126,
#    'hendtime': 57411.33262313507,
#    'hga_move': 'F',
#    'hmidtime': 57411.33182023984,
#    'hstrtime': 57411.33101734461,
#    'ingestCompletionDate': '/Date(1519785911471)/',
#    'ingestStartDate': '/Date(1519785865308)/',
#    'instrume': 'MIRI',
#    'intarget': 'T',
#    'isItar': False,
#    'isRestricted': False,
#    'isStale': False,
#    'jwst_dx': 0.0163060205760049,
#    'jwst_dy': -0.0494226292363929,
#    'jwst_dz': -0.0259600050453689,
#    'jwst_x': -1469770.36027802,
#    'jwst_y': -659956.853153144,
#    'jwst_z': -602493.522362055,
#    'lamp': '',
#    'mu_dec': 0,
#    'mu_epoch': '/Date(946702800000)/',
#    'mu_ra': 0,
#    'nexposur': 1,
#    'nextend': 3,
#    'nframes': 1,
#    'ngroups': 10,
#    'nints': 5,
#    'nresets': 0,
#    'nrststrt': 0,
#    'nsamples': 1,
#    'numdthpt': 0,
#    'nwfsest': None,
#    'obs_id': 'V98012002001P0000000002101',
#    'observtn': 2,
#    'obslabel': 'MIRI Imager DARK after the Flats',
#    'origin': 'STSCI',
#    'patt_num': 0,
#    'pattsize': None,
#    'pattstrt': 0,
#    'patttype': 'NONE',
#    'pcs_mode': 'NONE',
#    'pi_name': '',
#    'pntg_seq': 1,
#    'pps_aper': '',
#    'prd_ver': 'PRDOPSSOC-G-013',
#    'productLevel': '2a',
#    'program': 98012,
#    'prop_dec': 0,
#    'prop_ra': 0,
#    'psfref': None,
#    'publicReleaseDate': '/Date(2114398800000)/',
#    'pwfseet': None,
#    'readpatt': 'FAST',
#    'refframe': 'EME2000',
#    's_region': 'POLYGON ICRS  0.019988230399368877 -0.03943060701110157 359.9884418571164 -0.036825027398398526 359.99087303350353 -0.005619366485258326 0.022432703733912894 -0.007935967820728964',
#    'sca_num': 493,
#    'scicat': '',
#    'sdp_ver': '2017_1b',
#    'selfref': None,
#    'seq_id': '1',
#    'slowaxis': 2,
#    'spat_num': None,
#    'spatnstp': None,
#    'spatstep': None,
#    'spcoffst': None,
#    'spec_num': None,
#    'specnstp': None,
#    'specstep': None,
#    'sptoffst': None,
#    'srctype': None,
#    'subarray': 'FULL',
#    'subcat': '',
#    'subpxnum': 0,
#    'subsize1': 1032,
#    'subsize2': 1024,
#    'substrt1': 1,
#    'substrt2': 1,
#    'targ_dec': 0,
#    'targ_ra': 0,
#    'targname': '',
#    'targoopp': 'F',
#    'targprop': '',
#    'targtype': 'FIXED',
#    'targudec': 0,
#    'targura': 0,
#    'telescop': 'JWST',
#    'template': 'MIRI Dark',
#    'tframe': 2.77504,
#    'tgroup': 2.77504,
#    'timesys': 'UTC',
#    'title': 'MIRI IMG-RAD-11B',
#    'tsample': 10,
#    'tsovisit': 'F',
#    'visit': 1,
#    'visit_id': '98012002001',
#    'visitend': '/Date(1453640585174)/',
#    'visitgrp': '02',
#    'visitsta': 'SUCCESSFUL',
#    'visitype': 'PRIME_UNTARGETED',
#    'vststart': '/Date(1453640288214)/',
#    'xoffset': 0,
#    'yoffset': 0,
#    'zerofram': 'F'}],
#  'fields': [{'name': 'ArchiveFileID', 'type': 'string'},
#   {'name': 'filename', 'type': 'string'},
#   {'name': 'fileSetName', 'type': 'string'},
#   {'name': 'productLevel', 'type': 'string'},
#   {'name': 'act_id', 'type': 'string'},
#   {'name': 'apername', 'type': 'string'},
#   {'name': 'asnpool', 'type': 'string'},
#   {'name': 'asntable', 'type': 'string'},
#   {'name': 'bartdelt', 'type': 'float'},
#   {'name': 'bendtime', 'type': 'float'},
#   {'name': 'bkgdtarg', 'type': 'string'},
#   {'name': 'bkglevel', 'type': 'float'},
#   {'name': 'bkgsub', 'type': 'string'},
#   {'name': 'bmidtime', 'type': 'float'},
#   {'name': 'bstrtime', 'type': 'float'},
#   {'name': 'category', 'type': 'string'},
#   {'name': 'comprssd', 'type': 'string'},
#   {'name': 'cont_id', 'type': 'int'},
#   {'name': 'refframe', 'type': 'string'},
#   {'name': 'datamode', 'type': 'int'},
#   {'name': 'dataprob', 'type': 'string'},
#   {'name': 'date', 'type': 'date'},
#   {'name': 'date_obs', 'type': 'date'},
#   {'name': 'detector', 'type': 'string'},
#   {'name': 'drpfrms1', 'type': 'int'},
#   {'name': 'drpfrms3', 'type': 'int'},
#   {'name': 'duration', 'type': 'float'},
#   {'name': 'dva_dec', 'type': 'float'},
#   {'name': 'dva_ra', 'type': 'float'},
#   {'name': 'effexptm', 'type': 'float'},
#   {'name': 'effinttm', 'type': 'float'},
#   {'name': 'eng_qual', 'type': 'string'},
#   {'name': 'eph_time', 'type': 'float'},
#   {'name': 'eph_type', 'type': 'string'},
#   {'name': 'exp_type', 'type': 'string'},
#   {'name': 'expcount', 'type': 'int'},
#   {'name': 'expend', 'type': 'float'},
#   {'name': 'expmid', 'type': 'float'},
#   {'name': 'exposure', 'type': 'int'},
#   {'name': 'expripar', 'type': 'string'},
#   {'name': 'expstart', 'type': 'float'},
#   {'name': 'fastaxis', 'type': 'int'},
#   {'name': 'filetype', 'type': 'string'},
#   {'name': 'filter', 'type': 'string'},
#   {'name': 'frmdivsr', 'type': 'int'},
#   {'name': 'gdstarid', 'type': 'string'},
#   {'name': 'groupgap', 'type': 'int'},
#   {'name': 'gs_dec', 'type': 'float'},
#   {'name': 'gs_mag', 'type': 'float'},
#   {'name': 'gs_order', 'type': 'int'},
#   {'name': 'gs_ra', 'type': 'float'},
#   {'name': 'gsendtim', 'type': 'date'},
#   {'name': 'gsstrttm', 'type': 'date'},
#   {'name': 'gs_udec', 'type': 'float'},
#   {'name': 'gs_umag', 'type': 'float'},
#   {'name': 'gs_ura', 'type': 'float'},
#   {'name': 'helidelt', 'type': 'float'},
#   {'name': 'hendtime', 'type': 'float'},
#   {'name': 'hga_move', 'type': 'string'},
#   {'name': 'hmidtime', 'type': 'float'},
#   {'name': 'hstrtime', 'type': 'float'},
#   {'name': 'instrume', 'type': 'string'},
#   {'name': 'intarget', 'type': 'string'},
#   {'name': 'jwst_dx', 'type': 'float'},
#   {'name': 'jwst_dy', 'type': 'float'},
#   {'name': 'jwst_dz', 'type': 'float'},
#   {'name': 'jwst_x', 'type': 'float'},
#   {'name': 'jwst_y', 'type': 'float'},
#   {'name': 'jwst_z', 'type': 'float'},
#   {'name': 'lamp', 'type': 'string'},
#   {'name': 'mu_dec', 'type': 'float'},
#   {'name': 'mu_epoch', 'type': 'date'},
#   {'name': 'mu_ra', 'type': 'float'},
#   {'name': 'nexposur', 'type': 'int'},
#   {'name': 'nextend', 'type': 'int'},
#   {'name': 'nframes', 'type': 'int'},
#   {'name': 'ngroups', 'type': 'int'},
#   {'name': 'nints', 'type': 'int'},
#   {'name': 'nresets', 'type': 'int'},
#   {'name': 'nrststrt', 'type': 'int'},
#   {'name': 'nsamples', 'type': 'int'},
#   {'name': 'numdthpt', 'type': 'int'},
#   {'name': 'nwfsest', 'type': 'float'},
#   {'name': 'obs_id', 'type': 'string'},
#   {'name': 'observtn', 'type': 'int'},
#   {'name': 'obslabel', 'type': 'string'},
#   {'name': 'origin', 'type': 'string'},
#   {'name': 'pcs_mode', 'type': 'string'},
#   {'name': 'pi_name', 'type': 'string'},
#   {'name': 'pntg_seq', 'type': 'int'},
#   {'name': 'pps_aper', 'type': 'string'},
#   {'name': 'prd_ver', 'type': 'string'},
#   {'name': 'program', 'type': 'int'},
#   {'name': 'prop_dec', 'type': 'float'},
#   {'name': 'prop_ra', 'type': 'float'},
#   {'name': 'psfref', 'type': 'string'},
#   {'name': 'pwfseet', 'type': 'float'},
#   {'name': 'readpatt', 'type': 'string'},
#   {'name': 'sca_num', 'type': 'int'},
#   {'name': 'scicat', 'type': 'string'},
#   {'name': 'sdp_ver', 'type': 'string'},
#   {'name': 'selfref', 'type': 'string'},
#   {'name': 'seq_id', 'type': 'string'},
#   {'name': 'slowaxis', 'type': 'int'},
#   {'name': 'srctype', 'type': 'string'},
#   {'name': 'subarray', 'type': 'string'},
#   {'name': 'subcat', 'type': 'string'},
#   {'name': 'subsize1', 'type': 'int'},
#   {'name': 'subsize2', 'type': 'int'},
#   {'name': 'substrt1', 'type': 'int'},
#   {'name': 'substrt2', 'type': 'int'},
#   {'name': 'targ_dec', 'type': 'float'},
#   {'name': 'targ_ra', 'type': 'float'},
#   {'name': 'targname', 'type': 'string'},
#   {'name': 'targoopp', 'type': 'string'},
#   {'name': 'targprop', 'type': 'string'},
#   {'name': 'targtype', 'type': 'string'},
#   {'name': 'targudec', 'type': 'float'},
#   {'name': 'targura', 'type': 'float'},
#   {'name': 'telescop', 'type': 'string'},
#   {'name': 'template', 'type': 'string'},
#   {'name': 'tframe', 'type': 'float'},
#   {'name': 'tgroup', 'type': 'float'},
#   {'name': 'timesys', 'type': 'string'},
#   {'name': 'title', 'type': 'string'},
#   {'name': 'tsample', 'type': 'float'},
#   {'name': 'tsovisit', 'type': 'string'},
#   {'name': 'visit', 'type': 'int'},
#   {'name': 'visit_id', 'type': 'string'},
#   {'name': 'visitend', 'type': 'date'},
#   {'name': 'visitgrp', 'type': 'string'},
#   {'name': 'visitsta', 'type': 'string'},
#   {'name': 'visitype', 'type': 'string'},
#   {'name': 'vststart', 'type': 'date'},
#   {'name': 'xoffset', 'type': 'float'},
#   {'name': 'yoffset', 'type': 'float'},
#   {'name': 'zerofram', 'type': 'string'},
#   {'name': 's_region', 'type': 'string'},
#   {'name': 'band', 'type': 'string'},
#   {'name': 'cccstate', 'type': 'string'},
#   {'name': 'coronmsk', 'type': 'string'},
#   {'name': 'channel', 'type': 'string'},
#   {'name': 'patt_num', 'type': 'int'},
#   {'name': 'pattsize', 'type': 'string'},
#   {'name': 'pattstrt', 'type': 'int'},
#   {'name': 'patttype', 'type': 'string'},
#   {'name': 'spat_num', 'type': 'int'},
#   {'name': 'spatnstp', 'type': 'int'},
#   {'name': 'spatstep', 'type': 'float'},
#   {'name': 'spcoffst', 'type': 'float'},
#   {'name': 'spec_num', 'type': 'int'},
#   {'name': 'specnstp', 'type': 'int'},
#   {'name': 'specstep', 'type': 'float'},
#   {'name': 'sptoffst', 'type': 'float'},
#   {'name': 'subpxnum', 'type': 'int'},
#   {'name': 'fileSize', 'type': 'string'},
#   {'name': 'checksum', 'type': 'string'},
#   {'name': 'ingestStartDate', 'type': 'date'},
#   {'name': 'ingestCompletionDate', 'type': 'date'},
#   {'name': 'FileTypeID', 'type': 'int'},
#   {'name': 'publicReleaseDate', 'type': 'date'},
#   {'name': 'isRestricted', 'type': 'boolean'},
#   {'name': 'isItar', 'type': 'boolean'},
#   {'name': 'isStale', 'type': 'boolean'},
#   {'name': 'FileSetId', 'type': 'string'},
#   {'name': 'dataURI', 'type': 'string'}],
#  'msg': '',
#  'paging': {'page': 1,
#   'pageSize': 50000,
#   'pagesFiltered': 1,
#   'rows': 493,
#   'rowsFiltered': 493,
#   'rowsTotal': 493},
#  'status': 'COMPLETE'}
