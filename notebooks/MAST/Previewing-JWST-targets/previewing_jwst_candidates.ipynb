# %% [markdown]
# <a id="top"></a>
# # Tutorial Title

# %% [markdown]
# ***

# %% [markdown]
# ## Learning Goals
#
# By the end of this tutorial, you will:
#
# - Use astroquery to access archived HST images
# - Understand the need for image alignment
# - Learn how to download calibration files with CRDS
# - Use DrizzlePac and the calibration files to align your collected images
# - Combine images to create your very own previews of targets for future proposals, including for JWST!

# %% [markdown]
# ## Introduction
#
# Whether you want to re-explore existing data to learn something or discover something new, or you want to make the case for a new observation with Hubble or another telescope, you will want to download and combine all the existing data. These are all meticulously stored in the Mikulski Archive for Space Telescopes ([MAST](https://science.nasa.gov/astrophysics/astrophysics-data-centers/multimission-archive-at-stsci-mast/)). You can interactively search for and view individual images on the website.
#
# This tutorial allows you to make the most of existing observations by combining, or stacking, them. Several different observations of the same source may have been approved over Hubble's 30 year history, from a variety of PIs (principal investigators) and for a variety of science goals. Three things will almost certainly vary between visits, however:
# - the instrument ([ACS](https://www.stsci.edu/hst/instrumentation/acs) or [WFC3](https://www.stsci.edu/hst/instrumentation/wfc3) for imaging) and the [filters](https://hubblesite.org/mission-and-telescope/instruments)
# - the pointing direction of the instrument
# - because the images were taken at different times, they will have different pixels affected by cosmic rays, high-energy particles that interact with the instrument to produce a shower of pixels unrelated to the sources of interest.
#
# [`Drizzlepac`](https://www.stsci.edu/scientific-community/software/drizzlepac.html) is a Python module that performs all the necessary image cleaning and combining. This tutorial will guide you through it to create a stacked image of the Orion Nebula, a beautiful extended source that is rich with science in multiple wavelengths.
#
# Before starting, [set up AstroConda](https://astroconda.readthedocs.io/en/latest/installation.html). Then, follow [this tutorial](https://github.com/spacetelescope/notebooks/blob/master/notebooks/DrizzlePac/Initialization/Initialization.ipynb) to set up DrizzlePac on your computer.

# %% [markdown]
# ## Imports
#
# - *numpy* to handle array functions
# - *astropy.io fits* for accessing FITS files
# - *astropy.table Table* for creating tidy tables of the data
# - *matplotlib.pyplot* for plotting data
# - *astroquery* for pulling data from the Mikulski Archive at Space Telescope (MAST)
# - *stwcs* for tracking the World Coordinate System (WCS) data in the image files
# - *subprocess* to parallelize tasks
# - *shutil*, *glob*, *os* for accessing and manipulating files in the local system

# %% [markdown]
# The easiest way to make sure you have all the relevant modules is to download the Astroconda environment. Due to a known error, for Drizzlepac to work, you need to specify older versions for a couple packages:
#
# ```
# conda deactivate
# conda update --all
# conda create -n astroconda -c http://ssb.stsci.edu/astroconda stsci python=3.7 photutils=1.0.2 markupsafe=2.0.1 astroquery drizzlepac stwcs
# conda activate astroconda
# ```

# %%
# %matplotlib inline
import numpy as np
from astropy.io import fits
from astropy.table import vstack, Table
import matplotlib.pyplot as plt
from astroquery.mast import Mast
from astroquery.mast import Observations
import shutil, stwcs, subprocess, glob, os 

from stwcs.updatewcs import updatewcs
from drizzlepac import tweakreg, astrodrizzle, photeq
from stsci.skypac import skymatch
# Out:
# The following task in the stsci.skypac package can be run with TEAL:
#                                     skymatch
# The following tasks in the drizzlepac package can be run with TEAL:
#     astrodrizzle       config_testbed      imagefindpars           mapreg
#        photeq            pixreplace           pixtopix            pixtosky
#   refimagefindpars       resetbits          runastrodriz          skytopix
#      tweakback            tweakreg           updatenpol

# %% [markdown]
# ## Downloading Existing Images with astroquery.Observations
#
# Let's start by retrieving images of the Orion Nebula, our object of interest, from the HST Archive. Astroquery.Observations allows you to query targets by name, and it is helpful to additionally specify a search radius.
#
# More famous objects have been observed by Hubble many times, so the download may be prohibitively large. You may want to select only images in a certain band, or apply filters on any of the [fields listed here.]( https://mast.stsci.edu/api/v0/_c_a_o_mfields.html). Here, we require `calib_level = 3` to ensure that the image is science quality.

# %%
obs_table = Observations.query_criteria(target_name=["Orion","OrionNebula"],intentType='science',
                                        dataproduct_type='image', calib_level=3)
obs_table
# Out:
# <Table masked=True length=13>
# dataproduct_type calib_level obs_collection   obs_id  target_name   s_ra    s_dec   ...               dataURL               dataRights mtFlag  srcDen intentType  obsid     objID
#       str5          int64         str3         str9      str11    float64  float64  ...                str35                   str6     bool  float64    str7      str8      str9
# ---------------- ----------- -------------- --------- ----------- -------- -------- ... ----------------------------------- ---------- ------ ------- ---------- -------- ---------
#            image           3            HST j8up02usq ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02usq_drz.fits     PUBLIC  False     nan    science 24016393 121741157
#            image           3            HST j8up02utq ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02utq_drz.fits     PUBLIC  False     nan    science 24016394 121741219
#            image           3            HST j8up02uuq ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02uuq_drz.fits     PUBLIC  False     nan    science 24016395 121741204
#            image           3            HST j8up02uvq ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02uvq_drz.fits     PUBLIC  False     nan    science 24016396 121741214
#            image           3            HST j8up02uwq ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02uwq_drz.fits     PUBLIC  False     nan    science 24016397 121741185
#            image           3            HST j8up02uyq ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02uyq_drz.fits     PUBLIC  False     nan    science 24016398 121741174
#            image           3            HST j8up02v0q ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02v0q_drz.fits     PUBLIC  False     nan    science 24016399 121741211
#            image           3            HST j8up02v5q ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02v5q_drz.fits     PUBLIC  False     nan    science 24016400 121741178
#            image           3            HST j8up02v7q ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02v7q_drz.fits     PUBLIC  False     nan    science 24016401 121741200
#            image           3            HST j8up02v9q ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02v9q_drz.fits     PUBLIC  False     nan    science 24016402 121741150
#            image           3            HST j8up02vbq ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02vbq_drz.fits     PUBLIC  False     nan    science 24016403 121741155
#            image           3            HST j8up02vcq ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02vcq_drz.fits     PUBLIC  False     nan    science 24016404 121741190
#            image           3            HST j8up02vdq ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02vdq_drz.fits     PUBLIC  False     nan    science 24016405 121741168

# %%
optical = obs_table[obs_table['wavelength_region']=='Optical']
infrared = obs_table[(obs_table['wavelength_region'] == 'Infrared')] 
optical
# Out:
# <Table masked=True length=10>
# dataproduct_type calib_level obs_collection   obs_id  target_name   s_ra    s_dec   ...               dataURL               dataRights mtFlag  srcDen intentType  obsid     objID
#       str5          int64         str3         str9      str11    float64  float64  ...                str35                   str6     bool  float64    str7      str8      str9
# ---------------- ----------- -------------- --------- ----------- -------- -------- ... ----------------------------------- ---------- ------ ------- ---------- -------- ---------
#            image           3            HST j8up02usq ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02usq_drz.fits     PUBLIC  False     nan    science 24016393 121741157
#            image           3            HST j8up02utq ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02utq_drz.fits     PUBLIC  False     nan    science 24016394 121741219
#            image           3            HST j8up02uuq ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02uuq_drz.fits     PUBLIC  False     nan    science 24016395 121741204
#            image           3            HST j8up02uvq ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02uvq_drz.fits     PUBLIC  False     nan    science 24016396 121741214
#            image           3            HST j8up02uwq ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02uwq_drz.fits     PUBLIC  False     nan    science 24016397 121741185
#            image           3            HST j8up02uyq ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02uyq_drz.fits     PUBLIC  False     nan    science 24016398 121741174
#            image           3            HST j8up02v0q ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02v0q_drz.fits     PUBLIC  False     nan    science 24016399 121741211
#            image           3            HST j8up02v5q ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02v5q_drz.fits     PUBLIC  False     nan    science 24016400 121741178
#            image           3            HST j8up02v7q ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02v7q_drz.fits     PUBLIC  False     nan    science 24016401 121741200
#            image           3            HST j8up02v9q ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02v9q_drz.fits     PUBLIC  False     nan    science 24016402 121741150

# %%
infrared
# Out:
# <Table masked=True length=3>
# dataproduct_type calib_level obs_collection   obs_id  target_name   s_ra    s_dec   ...               dataURL               dataRights mtFlag  srcDen intentType  obsid     objID
#       str5          int64         str3         str9      str11    float64  float64  ...                str35                   str6     bool  float64    str7      str8      str9
# ---------------- ----------- -------------- --------- ----------- -------- -------- ... ----------------------------------- ---------- ------ ------- ---------- -------- ---------
#            image           3            HST j8up02vbq ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02vbq_drz.fits     PUBLIC  False     nan    science 24016403 121741155
#            image           3            HST j8up02vcq ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02vcq_drz.fits     PUBLIC  False     nan    science 24016404 121741190
#            image           3            HST j8up02vdq ORIONNEBULA 83.81875 -5.38975 ... mast:HST/product/j8up02vdq_drz.fits     PUBLIC  False     nan    science 24016405 121741168

# %% [markdown]
# It looks like Hubble has 13 science quality observations of the Orion Nebula, of which 13 are at optical wavelengths and 3 in the infrared. Let us process these separately.

# %%
download_opt = Observations.download_products(optical['obsid'], extension='fits')
# Out:
# INFO: Found cached file ./mastDownload/HST/j8up02usq/j8up02usq_flt_hlet.fits with expected size 34560. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02usq/j8up02usj_jif.fits with expected size 34560. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02usq/j8up02usj_jit.fits with expected size 20160. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02usq/j8up02usq_spt.fits with expected size 57600. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02usq/j8up02usq_trl.fits with expected size 66240. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02usq/j8up02usq_raw.fits with expected size 8513280. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02usq/j8up02usq_drz.fits with expected size 52948800. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02usq/j8up02usq_flt.fits with expected size 41990400. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02utq/j8up02utq_flt_hlet.fits with expected size 34560. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02utq/j8up02utj_jif.fits with expected size 34560. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02utq/j8up02utj_jit.fits with expected size 20160. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02utq/j8up02utq_spt.fits with expected size 57600. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02utq/j8up02utq_trl.fits with expected size 66240. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02utq/j8up02utq_raw.fits with expected size 8513280. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02utq/j8up02utq_drz.fits with expected size 52948800. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02utq/j8up02utq_flt.fits with expected size 41990400. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uuq/j8up02uuq_flt_hlet.fits with expected size 34560. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uuq/j8up02uuj_jif.fits with expected size 34560. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uuq/j8up02uuj_jit.fits with expected size 20160. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uuq/j8up02uuq_spt.fits with expected size 57600. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uuq/j8up02uuq_trl.fits with expected size 66240. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uuq/j8up02uuq_raw.fits with expected size 8513280. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uuq/j8up02uuq_drz.fits with expected size 52948800. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uuq/j8up02uuq_flt.fits with expected size 41990400. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uvq/j8up02uvq_flt_hlet.fits with expected size 34560. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uvq/j8up02uvj_jif.fits with expected size 34560. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uvq/j8up02uvj_jit.fits with expected size 20160. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uvq/j8up02uvq_spt.fits with expected size 57600. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uvq/j8up02uvq_trl.fits with expected size 66240. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uvq/j8up02uvq_raw.fits with expected size 8513280. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uvq/j8up02uvq_drz.fits with expected size 52948800. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uvq/j8up02uvq_flt.fits with expected size 41990400. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uwq/j8up02uwq_flt_hlet.fits with expected size 34560. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uwq/j8up02uwj_jif.fits with expected size 34560. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uwq/j8up02uwj_jit.fits with expected size 28800. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uwq/j8up02uwq_spt.fits with expected size 57600. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uwq/j8up02uwq_trl.fits with expected size 66240. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uwq/j8up02uwq_raw.fits with expected size 8513280. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uwq/j8up02uwq_drz.fits with expected size 52948800. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uwq/j8up02uwq_flt.fits with expected size 41990400. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uyq/j8up02uyq_flt_hlet.fits with expected size 34560. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uyq/j8up02uyj_jif.fits with expected size 34560. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uyq/j8up02uyj_jit.fits with expected size 20160. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uyq/j8up02uyq_spt.fits with expected size 57600. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uyq/j8up02uyq_trl.fits with expected size 66240. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uyq/j8up02uyq_raw.fits with expected size 8513280. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uyq/j8up02uyq_drz.fits with expected size 52948800. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02uyq/j8up02uyq_flt.fits with expected size 41990400. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02v0q/j8up02v0q_flt_hlet.fits with expected size 34560. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02v0q/j8up02v0j_jif.fits with expected size 34560. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/j8up02v0q/j8up02v0j_jit.fits with expected size 20160. [astroquery.query]
#  [Done]
# WARNING: Found cached file ./mastDownload/HST/j8up02v0q/j8up02v0q_spt.fits with size 0 that is different from expected size 57600 [astroquery.query]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v0q_trl.fits to ./mastDownload/HST/j8up02v0q/j8up02v0q_trl.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v0q_raw.fits to ./mastDownload/HST/j8up02v0q/j8up02v0q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v0q_drz.fits to ./mastDownload/HST/j8up02v0q/j8up02v0q_drz.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v0q_flt.fits to ./mastDownload/HST/j8up02v0q/j8up02v0q_flt.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v5q_flt_hlet.fits to ./mastDownload/HST/j8up02v5q/j8up02v5q_flt_hlet.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v5j_jif.fits to ./mastDownload/HST/j8up02v5q/j8up02v5j_jif.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v5j_jit.fits to ./mastDownload/HST/j8up02v5q/j8up02v5j_jit.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v5q_spt.fits to ./mastDownload/HST/j8up02v5q/j8up02v5q_spt.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v5q_trl.fits to ./mastDownload/HST/j8up02v5q/j8up02v5q_trl.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v5q_raw.fits to ./mastDownload/HST/j8up02v5q/j8up02v5q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v5q_drz.fits to ./mastDownload/HST/j8up02v5q/j8up02v5q_drz.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v5q_flt.fits to ./mastDownload/HST/j8up02v5q/j8up02v5q_flt.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v7q_flt_hlet.fits to ./mastDownload/HST/j8up02v7q/j8up02v7q_flt_hlet.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v7j_jif.fits to ./mastDownload/HST/j8up02v7q/j8up02v7j_jif.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v7j_jit.fits to ./mastDownload/HST/j8up02v7q/j8up02v7j_jit.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v7q_spt.fits to ./mastDownload/HST/j8up02v7q/j8up02v7q_spt.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v7q_trl.fits to ./mastDownload/HST/j8up02v7q/j8up02v7q_trl.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v7q_raw.fits to ./mastDownload/HST/j8up02v7q/j8up02v7q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v7q_drz.fits to ./mastDownload/HST/j8up02v7q/j8up02v7q_drz.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v7q_flt.fits to ./mastDownload/HST/j8up02v7q/j8up02v7q_flt.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v9q_flt_hlet.fits to ./mastDownload/HST/j8up02v9q/j8up02v9q_flt_hlet.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v9j_jif.fits to ./mastDownload/HST/j8up02v9q/j8up02v9j_jif.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v9j_jit.fits to ./mastDownload/HST/j8up02v9q/j8up02v9j_jit.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v9q_spt.fits to ./mastDownload/HST/j8up02v9q/j8up02v9q_spt.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v9q_trl.fits to ./mastDownload/HST/j8up02v9q/j8up02v9q_trl.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v9q_raw.fits to ./mastDownload/HST/j8up02v9q/j8up02v9q_raw.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v9q_drz.fits to ./mastDownload/HST/j8up02v9q/j8up02v9q_drz.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HST/product/j8up02v9q_flt.fits to ./mastDownload/HST/j8up02v9q/j8up02v9q_flt.fits ... [Done]
# <Table length=80>
#                      Local Path                       Status  Message  URL
#                        str52                           str8    object object
# ---------------------------------------------------- -------- ------- ------
# ./mastDownload/HST/j8up02usq/j8up02usq_flt_hlet.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02usq/j8up02usj_jif.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02usq/j8up02usj_jit.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02usq/j8up02usq_spt.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02usq/j8up02usq_trl.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02usq/j8up02usq_raw.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02usq/j8up02usq_drz.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02usq/j8up02usq_flt.fits COMPLETE    None   None
# ./mastDownload/HST/j8up02utq/j8up02utq_flt_hlet.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02utq/j8up02utj_jif.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02utq/j8up02utj_jit.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02utq/j8up02utq_spt.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02utq/j8up02utq_trl.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02utq/j8up02utq_raw.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02utq/j8up02utq_drz.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02utq/j8up02utq_flt.fits COMPLETE    None   None
# ./mastDownload/HST/j8up02uuq/j8up02uuq_flt_hlet.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02uuq/j8up02uuj_jif.fits COMPLETE    None   None
#                                                  ...      ...     ...    ...
#      ./mastDownload/HST/j8up02v5q/j8up02v5q_raw.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v5q/j8up02v5q_drz.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v5q/j8up02v5q_flt.fits COMPLETE    None   None
# ./mastDownload/HST/j8up02v7q/j8up02v7q_flt_hlet.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v7q/j8up02v7j_jif.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v7q/j8up02v7j_jit.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v7q/j8up02v7q_spt.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v7q/j8up02v7q_trl.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v7q/j8up02v7q_raw.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v7q/j8up02v7q_drz.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v7q/j8up02v7q_flt.fits COMPLETE    None   None
# ./mastDownload/HST/j8up02v9q/j8up02v9q_flt_hlet.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v9q/j8up02v9j_jif.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v9q/j8up02v9j_jit.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v9q/j8up02v9q_spt.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v9q/j8up02v9q_trl.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v9q/j8up02v9q_raw.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v9q/j8up02v9q_drz.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v9q/j8up02v9q_flt.fits COMPLETE    None   None

# %%
download_opt
# Out:
# <Table length=80>
#                      Local Path                       Status  Message  URL
#                        str52                           str8    object object
# ---------------------------------------------------- -------- ------- ------
# ./mastDownload/HST/j8up02usq/j8up02usq_flt_hlet.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02usq/j8up02usj_jif.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02usq/j8up02usj_jit.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02usq/j8up02usq_spt.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02usq/j8up02usq_trl.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02usq/j8up02usq_raw.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02usq/j8up02usq_drz.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02usq/j8up02usq_flt.fits COMPLETE    None   None
# ./mastDownload/HST/j8up02utq/j8up02utq_flt_hlet.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02utq/j8up02utj_jif.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02utq/j8up02utj_jit.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02utq/j8up02utq_spt.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02utq/j8up02utq_trl.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02utq/j8up02utq_raw.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02utq/j8up02utq_drz.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02utq/j8up02utq_flt.fits COMPLETE    None   None
# ./mastDownload/HST/j8up02uuq/j8up02uuq_flt_hlet.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02uuq/j8up02uuj_jif.fits COMPLETE    None   None
#                                                  ...      ...     ...    ...
#      ./mastDownload/HST/j8up02v5q/j8up02v5q_raw.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v5q/j8up02v5q_drz.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v5q/j8up02v5q_flt.fits COMPLETE    None   None
# ./mastDownload/HST/j8up02v7q/j8up02v7q_flt_hlet.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v7q/j8up02v7j_jif.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v7q/j8up02v7j_jit.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v7q/j8up02v7q_spt.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v7q/j8up02v7q_trl.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v7q/j8up02v7q_raw.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v7q/j8up02v7q_drz.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v7q/j8up02v7q_flt.fits COMPLETE    None   None
# ./mastDownload/HST/j8up02v9q/j8up02v9q_flt_hlet.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v9q/j8up02v9j_jif.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v9q/j8up02v9j_jit.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v9q/j8up02v9q_spt.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v9q/j8up02v9q_trl.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v9q/j8up02v9q_raw.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v9q/j8up02v9q_drz.fits COMPLETE    None   None
#      ./mastDownload/HST/j8up02v9q/j8up02v9q_flt.fits COMPLETE    None   None

# %%
for file in download_opt['Local Path']:
    os.rename(file, os.path.basename(file))
shutil.rmtree('mastDownload')
os.makedirs('OrionNebulaHST')
os.makedirs('OrionNebulaHST/FITS')

# !mv *fits OrionNebulaHST/FITS/
# Out:
# zsh:1: no matches found: *jpg
# zsh:1: no matches found: *txt

# %% [markdown]
# At this point, all the FITS files live in the FITS directory. Take a moment to look through them in [ds9](https://sites.google.com/cfa.harvard.edu/saoimageds9/download).

# %% [markdown]
# ## Assignment 1:
# Pull all available observations for the galaxy cluster Abell 2744, also known as Pandora's Cluster. Try your favourite object. If you query only by target name, do you get too many results? What filters might help you narrow down to the data most useful to your proposal? Besides images, what data types might serve you?

# %%
obs_table = Observations.query_object( `Fill out your query here` )

# %% [markdown]
# ## Inspecting the observations
#
# You will notice that the number of downloaded files far exceeds the number of observations collected in `obs_table`. To understand them, let us look into some of their headers.

# %%
files = glob.glob('j*.fits'); files.sort()
files
subtypes = []
for file in files:
    subtypes.append(file.split('_')[1].split('.')[0])
subtypes = np.unique(np.array(subtypes))
subtypes.sort()
subtypes
# Out:
# array(['drz', 'flt', 'jif', 'jit', 'raw', 'sci1', 'single', 'skymatch',
#        'spt', 'trl'], dtype='<U8')

# %% [markdown]
# These file types are documented [here](https://hst-docs.stsci.edu/wfc3dhb/chapter-2-wfc3-data-structure/2-1-types-of-wfc3-files), but in summary:
# - `drz` and `flt` track the image exposure,
# - `jif` and `jit` files contain information about the instrument [jitter](https://www.stsci.edu/hst/instrumentation/focus-and-pointing/pointing/jitter-file-format-definition#section-c750a83b-3641-449d-924d-9a42882c35c0)
# - `raw` is the raw image,
# - `spt` is telescope telemetry data, and
# - `trl` is the "trailer file", storing the processing history of the image.
#
# We will we working primarily with the `raw` files.
#
# Next, we align the images. To do this, we first need to find all the point sources in them, and feed this point source lists, along with the WCS coordinate information, to `drizzlepac`.

# %% [markdown]
# ## Setting up DrizzlePac

# %% [markdown]
# A helpful schematic of AstroDrizzle lives [here](https://www.stsci.edu/files/live/sites/www/files/home/scientific-community/software/drizzlepac/_documents/AAS_AstroDrizzle_mack.pdf). AstroDrizzle was installed with `astroconda` at the beginning of this tutorial, but you need to [set it up.](https://github.com/spacetelescope/notebooks/blob/master/notebooks/DrizzlePac/Initialization/Initialization.ipynb) **Skip the conda install step, as this will overwrite the version-controlled load we did above.**
#
# Then, follow [these instructions](https://hst-crds.stsci.edu/docs/cmdline_bestrefs/) to set up the appropriate environment variables for CRDS. If you use a `bash` rather than `csh` shell, use the following commands instead of `setenv`:
#
# ```
# export CRDS_PATH=$HOME/crds_cache
# export CRDS_SERVER_URL="https://hst-crds.stsci.edu"
# export iref="${CRDS_PATH}/references/hst/iref/"
# export jref="${CRDS_PATH}/references/hst/jref/"
# export oref="${CRDS_PATH}/references/hst/oref/"
# export lref="${CRDS_PATH}/references/hst/lref/"
# export nref="${CRDS_PATH}/references/hst/nref/"
# export uref="${CRDS_PATH}/references/hst/uref/"
# ```
# Be careful to use double (") rather than single (') quotation marks, as `bash` cares about this.

# %% [markdown]
# CRDS updates the header of each FITS file with the best reference file available in its catalog. This should be done for all the `_flt` and `_raw` files::

# %%
for id in optical['obs_id']:
    command = 'crds bestrefs --files %s*flt.fits --sync-references=1 --update-bestrefs' % id
    print(command)
    try:
        subprocess.check_output(command, shell=True)
    except:
        print('No ref files for this ID')
# Out:
# crds bestrefs --files j8up02usq*flt.fits --sync-references=1 --update-bestrefs
# CRDS - INFO -  No comparison context or source comparison requested.
# CRDS - INFO -  ===> Processing j8up02usq_flt.fits
# CRDS - INFO -  0 errors
# CRDS - INFO -  0 warnings
# CRDS - INFO -  2 infos
# crds bestrefs --files j8up02utq*flt.fits --sync-references=1 --update-bestrefs
# CRDS - INFO -  No comparison context or source comparison requested.
# CRDS - INFO -  ===> Processing j8up02utq_flt.fits
# CRDS - INFO -  0 errors
# CRDS - INFO -  0 warnings
# CRDS - INFO -  2 infos
# crds bestrefs --files j8up02uuq*flt.fits --sync-references=1 --update-bestrefs
# CRDS - INFO -  No comparison context or source comparison requested.
# CRDS - INFO -  ===> Processing j8up02uuq_flt.fits
# CRDS - INFO -  0 errors
# CRDS - INFO -  0 warnings
# CRDS - INFO -  2 infos
# crds bestrefs --files j8up02uvq*flt.fits --sync-references=1 --update-bestrefs
# CRDS - INFO -  No comparison context or source comparison requested.
# CRDS - INFO -  ===> Processing j8up02uvq_flt.fits
# CRDS - INFO -  0 errors
# CRDS - INFO -  0 warnings
# CRDS - INFO -  2 infos
# crds bestrefs --files j8up02uwq*flt.fits --sync-references=1 --update-bestrefs
# CRDS - INFO -  No comparison context or source comparison requested.
# CRDS - INFO -  ===> Processing j8up02uwq_flt.fits
# CRDS - INFO -  0 errors
# CRDS - INFO -  0 warnings
# CRDS - INFO -  2 infos
# crds bestrefs --files j8up02uyq*flt.fits --sync-references=1 --update-bestrefs
# CRDS - INFO -  No comparison context or source comparison requested.
# CRDS - INFO -  ===> Processing j8up02uyq_flt.fits
# CRDS - INFO -  0 errors
# CRDS - INFO -  0 warnings
# CRDS - INFO -  2 infos
# crds bestrefs --files j8up02v0q*flt.fits --sync-references=1 --update-bestrefs
# CRDS - INFO -  No comparison context or source comparison requested.
# CRDS - INFO -  ===> Processing j8up02v0q_flt.fits
# CRDS - INFO -  0 errors
# CRDS - INFO -  0 warnings
# CRDS - INFO -  2 infos
# crds bestrefs --files j8up02v5q*flt.fits --sync-references=1 --update-bestrefs
# CRDS - INFO -  No comparison context or source comparison requested.
# CRDS - INFO -  ===> Processing j8up02v5q_flt.fits
# CRDS - INFO -  0 errors
# CRDS - INFO -  0 warnings
# CRDS - INFO -  2 infos
# crds bestrefs --files j8up02v7q*flt.fits --sync-references=1 --update-bestrefs
# CRDS - INFO -  No comparison context or source comparison requested.
# CRDS - INFO -  ===> Processing j8up02v7q_flt.fits
# CRDS - INFO -  0 errors
# CRDS - INFO -  0 warnings
# CRDS - INFO -  2 infos
# crds bestrefs --files j8up02v9q*flt.fits --sync-references=1 --update-bestrefs
# CRDS - INFO -  No comparison context or source comparison requested.
# CRDS - INFO -  ===> Processing j8up02v9q_flt.fits
# CRDS - INFO -  0 errors
# CRDS - INFO -  0 warnings
# CRDS - INFO -  2 infos

# %%
for id in optical['obs_id']:
    command = 'crds bestrefs --files %s*raw.fits --sync-references=1 --update-bestrefs' % id
    print(command)
    try:
        subprocess.check_output(command, shell=True)
    except:
        print('No ref files for this ID')
# Out:
# crds bestrefs --files j8up02usq*raw.fits --sync-references=1 --update-bestrefs
# CRDS - INFO -  No comparison context or source comparison requested.
# CRDS - INFO -  ===> Processing j8up02usq_raw.fits
# CRDS - INFO -  0 errors
# CRDS - INFO -  0 warnings
# CRDS - INFO -  2 infos
# crds bestrefs --files j8up02utq*raw.fits --sync-references=1 --update-bestrefs
# CRDS - INFO -  No comparison context or source comparison requested.
# CRDS - INFO -  ===> Processing j8up02utq_raw.fits
# CRDS - INFO -  0 errors
# CRDS - INFO -  0 warnings
# CRDS - INFO -  2 infos
# crds bestrefs --files j8up02uuq*raw.fits --sync-references=1 --update-bestrefs
# CRDS - INFO -  No comparison context or source comparison requested.
# CRDS - INFO -  ===> Processing j8up02uuq_raw.fits
# CRDS - INFO -  0 errors
# CRDS - INFO -  0 warnings
# CRDS - INFO -  2 infos
# crds bestrefs --files j8up02uvq*raw.fits --sync-references=1 --update-bestrefs
# CRDS - INFO -  No comparison context or source comparison requested.
# CRDS - INFO -  ===> Processing j8up02uvq_raw.fits
# CRDS - INFO -  0 errors
# CRDS - INFO -  0 warnings
# CRDS - INFO -  2 infos
# crds bestrefs --files j8up02uwq*raw.fits --sync-references=1 --update-bestrefs
# CRDS - INFO -  No comparison context or source comparison requested.
# CRDS - INFO -  ===> Processing j8up02uwq_raw.fits
# CRDS - INFO -  0 errors
# CRDS - INFO -  0 warnings
# CRDS - INFO -  2 infos
# crds bestrefs --files j8up02uyq*raw.fits --sync-references=1 --update-bestrefs
# CRDS - INFO -  No comparison context or source comparison requested.
# CRDS - INFO -  ===> Processing j8up02uyq_raw.fits
# CRDS - INFO -  0 errors
# CRDS - INFO -  0 warnings
# CRDS - INFO -  2 infos
# crds bestrefs --files j8up02v0q*raw.fits --sync-references=1 --update-bestrefs
# CRDS - INFO -  No comparison context or source comparison requested.
# CRDS - INFO -  ===> Processing j8up02v0q_raw.fits
# CRDS - INFO -  0 errors
# CRDS - INFO -  0 warnings
# CRDS - INFO -  2 infos
# crds bestrefs --files j8up02v5q*raw.fits --sync-references=1 --update-bestrefs
# CRDS - INFO -  No comparison context or source comparison requested.
# CRDS - INFO -  ===> Processing j8up02v5q_raw.fits
# CRDS - INFO -  0 errors
# CRDS - INFO -  0 warnings
# CRDS - INFO -  2 infos
# crds bestrefs --files j8up02v7q*raw.fits --sync-references=1 --update-bestrefs
# CRDS - INFO -  No comparison context or source comparison requested.
# CRDS - INFO -  ===> Processing j8up02v7q_raw.fits
# CRDS - INFO -  0 errors
# CRDS - INFO -  0 warnings
# CRDS - INFO -  2 infos
# crds bestrefs --files j8up02v9q*raw.fits --sync-references=1 --update-bestrefs
# CRDS - INFO -  No comparison context or source comparison requested.
# CRDS - INFO -  ===> Processing j8up02v9q_raw.fits
# CRDS - INFO -  0 errors
# CRDS - INFO -  0 warnings
# CRDS - INFO -  2 infos

# %%
#ensure we're in the correct directory
os.chdir('/Users/mila/Documents/Research/StScI-Notebook-Project/notebooks/MAST/Previewing-JWST-targets/OrionNebulaHST/FITS') 
stwcs.updatewcs.updatewcs('*flt.fits', use_db=True)
# Out:
# AstrometryDB service available...
# Wcskey 'O' is reserved for the original WCS and should not be deleted.
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 15 for chip 1 : FR656N
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 15 for chip 1 : FR656N
# Updating astrometry for j8up02utq
# Accessing AstrometryDB service :
# 	https://mast.stsci.edu/portal/astrometryDB/observation/read/j8up02utq
# AstrometryDB service call succeeded
# Retrieving astrometrically-updated WCS "OPUS" for observation "j8up02utq"
# Retrieving astrometrically-updated WCS "IDC_0461802ej" for observation "j8up02utq"
# Retrieving astrometrically-updated WCS "OPUS-GSC240" for observation "j8up02utq"
# Retrieving astrometrically-updated WCS "IDC_0461802ej-GSC240" for observation "j8up02utq"
# Updating j8up02utq with:
# 	Headerlet with WCSNAME=OPUS
# 	Headerlet with WCSNAME=IDC_0461802ej
# 	Headerlet with WCSNAME=OPUS-GSC240
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Deleted all instances of WCS with key   in extensions [('SCI', 1)]
# Replacing primary WCS with
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Wcskey 'O' is reserved for the original WCS and should not be deleted.
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 35 for chip 1 : FR459M
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 35 for chip 1 : FR459M
# Updating astrometry for j8up02v5q
# Accessing AstrometryDB service :
# 	https://mast.stsci.edu/portal/astrometryDB/observation/read/j8up02v5q
# AstrometryDB service call succeeded
# Retrieving astrometrically-updated WCS "OPUS" for observation "j8up02v5q"
# Retrieving astrometrically-updated WCS "IDC_0461802ej" for observation "j8up02v5q"
# Retrieving astrometrically-updated WCS "OPUS-GSC240" for observation "j8up02v5q"
# Retrieving astrometrically-updated WCS "IDC_0461802ej-GSC240" for observation "j8up02v5q"
# Updating j8up02v5q with:
# 	Headerlet with WCSNAME=OPUS
# 	Headerlet with WCSNAME=IDC_0461802ej
# 	Headerlet with WCSNAME=OPUS-GSC240
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Deleted all instances of WCS with key   in extensions [('SCI', 1)]
# Replacing primary WCS with
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Wcskey 'O' is reserved for the original WCS and should not be deleted.
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 41 for chip 1 : FR505N
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 41 for chip 1 : FR505N
# Updating astrometry for j8up02uyq
# Accessing AstrometryDB service :
# 	https://mast.stsci.edu/portal/astrometryDB/observation/read/j8up02uyq
# AstrometryDB service call succeeded
# Retrieving astrometrically-updated WCS "OPUS" for observation "j8up02uyq"
# Retrieving astrometrically-updated WCS "IDC_0461802ej" for observation "j8up02uyq"
# Retrieving astrometrically-updated WCS "OPUS-GSC240" for observation "j8up02uyq"
# Retrieving astrometrically-updated WCS "IDC_0461802ej-GSC240" for observation "j8up02uyq"
# Updating j8up02uyq with:
# 	Headerlet with WCSNAME=OPUS
# 	Headerlet with WCSNAME=IDC_0461802ej
# 	Headerlet with WCSNAME=OPUS-GSC240
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Deleted all instances of WCS with key   in extensions [('SCI', 1)]
# Replacing primary WCS with
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Wcskey 'O' is reserved for the original WCS and should not be deleted.
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 35 for chip 1 : FR459M
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 35 for chip 1 : FR459M
# Updating astrometry for j8up02v9q
# Accessing AstrometryDB service :
# 	https://mast.stsci.edu/portal/astrometryDB/observation/read/j8up02v9q
# AstrometryDB service call succeeded
# Retrieving astrometrically-updated WCS "OPUS" for observation "j8up02v9q"
# Retrieving astrometrically-updated WCS "IDC_0461802ej" for observation "j8up02v9q"
# Retrieving astrometrically-updated WCS "OPUS-GSC240" for observation "j8up02v9q"
# Retrieving astrometrically-updated WCS "IDC_0461802ej-GSC240" for observation "j8up02v9q"
# Updating j8up02v9q with:
# 	Headerlet with WCSNAME=OPUS
# 	Headerlet with WCSNAME=IDC_0461802ej
# 	Headerlet with WCSNAME=OPUS-GSC240
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Deleted all instances of WCS with key   in extensions [('SCI', 1)]
# Replacing primary WCS with
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Wcskey 'O' is reserved for the original WCS and should not be deleted.
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 15 for chip 1 : FR656N
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 15 for chip 1 : FR656N
# Updating astrometry for j8up02uuq
# Accessing AstrometryDB service :
# 	https://mast.stsci.edu/portal/astrometryDB/observation/read/j8up02uuq
# AstrometryDB service call succeeded
# Retrieving astrometrically-updated WCS "OPUS" for observation "j8up02uuq"
# Retrieving astrometrically-updated WCS "IDC_0461802ej" for observation "j8up02uuq"
# Retrieving astrometrically-updated WCS "OPUS-GSC240" for observation "j8up02uuq"
# Retrieving astrometrically-updated WCS "IDC_0461802ej-GSC240" for observation "j8up02uuq"
# Updating j8up02uuq with:
# 	Headerlet with WCSNAME=OPUS
# 	Headerlet with WCSNAME=IDC_0461802ej
# 	Headerlet with WCSNAME=OPUS-GSC240
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Deleted all instances of WCS with key   in extensions [('SCI', 1)]
# Replacing primary WCS with
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Wcskey 'O' is reserved for the original WCS and should not be deleted.
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 15 for chip 1 : FR656N
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 15 for chip 1 : FR656N
# Updating astrometry for j8up02usq
# Accessing AstrometryDB service :
# 	https://mast.stsci.edu/portal/astrometryDB/observation/read/j8up02usq
# AstrometryDB service call succeeded
# Retrieving astrometrically-updated WCS "OPUS" for observation "j8up02usq"
# Retrieving astrometrically-updated WCS "IDC_0461802ej" for observation "j8up02usq"
# Retrieving astrometrically-updated WCS "OPUS-GSC240" for observation "j8up02usq"
# Retrieving astrometrically-updated WCS "IDC_0461802ej-GSC240" for observation "j8up02usq"
# Updating j8up02usq with:
# 	Headerlet with WCSNAME=OPUS
# 	Headerlet with WCSNAME=IDC_0461802ej
# 	Headerlet with WCSNAME=OPUS-GSC240
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Deleted all instances of WCS with key   in extensions [('SCI', 1)]
# Replacing primary WCS with
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Wcskey 'O' is reserved for the original WCS and should not be deleted.
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 7 for chip 1 : FR388N
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 7 for chip 1 : FR388N
# Updating astrometry for j8up02uvq
# Accessing AstrometryDB service :
# 	https://mast.stsci.edu/portal/astrometryDB/observation/read/j8up02uvq
# AstrometryDB service call succeeded
# Retrieving astrometrically-updated WCS "OPUS" for observation "j8up02uvq"
# Retrieving astrometrically-updated WCS "IDC_0461802ej" for observation "j8up02uvq"
# Retrieving astrometrically-updated WCS "OPUS-GSC240" for observation "j8up02uvq"
# Retrieving astrometrically-updated WCS "IDC_0461802ej-GSC240" for observation "j8up02uvq"
# Updating j8up02uvq with:
# 	Headerlet with WCSNAME=OPUS
# 	Headerlet with WCSNAME=IDC_0461802ej
# 	Headerlet with WCSNAME=OPUS-GSC240
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Deleted all instances of WCS with key   in extensions [('SCI', 1)]
# Replacing primary WCS with
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Wcskey 'O' is reserved for the original WCS and should not be deleted.
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 35 for chip 1 : FR459M
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 35 for chip 1 : FR459M
# Updating astrometry for j8up02v7q
# Accessing AstrometryDB service :
# 	https://mast.stsci.edu/portal/astrometryDB/observation/read/j8up02v7q
# AstrometryDB service call succeeded
# Retrieving astrometrically-updated WCS "OPUS" for observation "j8up02v7q"
# Retrieving astrometrically-updated WCS "IDC_0461802ej" for observation "j8up02v7q"
# Retrieving astrometrically-updated WCS "OPUS-GSC240" for observation "j8up02v7q"
# Retrieving astrometrically-updated WCS "IDC_0461802ej-GSC240" for observation "j8up02v7q"
# Updating j8up02v7q with:
# 	Headerlet with WCSNAME=OPUS
# 	Headerlet with WCSNAME=IDC_0461802ej
# 	Headerlet with WCSNAME=OPUS-GSC240
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Deleted all instances of WCS with key   in extensions [('SCI', 1)]
# Replacing primary WCS with
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Wcskey 'O' is reserved for the original WCS and should not be deleted.
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 7 for chip 1 : FR388N
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 7 for chip 1 : FR388N
# Updating astrometry for j8up02uwq
# Accessing AstrometryDB service :
# 	https://mast.stsci.edu/portal/astrometryDB/observation/read/j8up02uwq
# AstrometryDB service call succeeded
# Retrieving astrometrically-updated WCS "OPUS" for observation "j8up02uwq"
# Retrieving astrometrically-updated WCS "IDC_0461802ej" for observation "j8up02uwq"
# Retrieving astrometrically-updated WCS "OPUS-GSC240" for observation "j8up02uwq"
# Retrieving astrometrically-updated WCS "IDC_0461802ej-GSC240" for observation "j8up02uwq"
# Updating j8up02uwq with:
# 	Headerlet with WCSNAME=OPUS
# 	Headerlet with WCSNAME=IDC_0461802ej
# 	Headerlet with WCSNAME=OPUS-GSC240
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Deleted all instances of WCS with key   in extensions [('SCI', 1)]
# Replacing primary WCS with
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Wcskey 'O' is reserved for the original WCS and should not be deleted.
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 41 for chip 1 : FR505N
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 41 for chip 1 : FR505N
# Updating astrometry for j8up02v0q
# Accessing AstrometryDB service :
# 	https://mast.stsci.edu/portal/astrometryDB/observation/read/j8up02v0q
# AstrometryDB service call succeeded
# Retrieving astrometrically-updated WCS "OPUS" for observation "j8up02v0q"
# Retrieving astrometrically-updated WCS "IDC_0461802ej" for observation "j8up02v0q"
# Retrieving astrometrically-updated WCS "OPUS-GSC240" for observation "j8up02v0q"
# Retrieving astrometrically-updated WCS "IDC_0461802ej-GSC240" for observation "j8up02v0q"
# Updating j8up02v0q with:
# 	Headerlet with WCSNAME=OPUS
# 	Headerlet with WCSNAME=IDC_0461802ej
# 	Headerlet with WCSNAME=OPUS-GSC240
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Deleted all instances of WCS with key   in extensions [('SCI', 1)]
# Replacing primary WCS with
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# ['j8up02utq_flt.fits',
#  'j8up02v5q_flt.fits',
#  'j8up02uyq_flt.fits',
#  'j8up02v9q_flt.fits',
#  'j8up02uuq_flt.fits',
#  'j8up02usq_flt.fits',
#  'j8up02uvq_flt.fits',
#  'j8up02v7q_flt.fits',
#  'j8up02uwq_flt.fits',
#  'j8up02v0q_flt.fits']

# %%
stwcs.updatewcs.updatewcs('*raw.fits', use_db=True)
# Out:
# AstrometryDB service available...
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 35 for chip 1 : FR459M
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 35 for chip 1 : FR459M
# Updating astrometry for j8up02v9q
# Accessing AstrometryDB service :
# 	https://mast.stsci.edu/portal/astrometryDB/observation/read/j8up02v9q
# AstrometryDB service call succeeded
# Retrieving astrometrically-updated WCS "OPUS" for observation "j8up02v9q"
# Retrieving astrometrically-updated WCS "IDC_0461802ej" for observation "j8up02v9q"
# Retrieving astrometrically-updated WCS "OPUS-GSC240" for observation "j8up02v9q"
# Retrieving astrometrically-updated WCS "IDC_0461802ej-GSC240" for observation "j8up02v9q"
# Updating j8up02v9q with:
# 	Headerlet with WCSNAME=OPUS
# 	Headerlet with WCSNAME=IDC_0461802ej
# 	Headerlet with WCSNAME=OPUS-GSC240
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Initializing new WCSCORR table for  j8up02v9q_raw.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Deleted all instances of WCS with key   in extensions [('SCI', 1)]
# Replacing primary WCS with
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 15 for chip 1 : FR656N
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 15 for chip 1 : FR656N
# Updating astrometry for j8up02uuq
# Accessing AstrometryDB service :
# 	https://mast.stsci.edu/portal/astrometryDB/observation/read/j8up02uuq
# AstrometryDB service call succeeded
# Retrieving astrometrically-updated WCS "OPUS" for observation "j8up02uuq"
# Retrieving astrometrically-updated WCS "IDC_0461802ej" for observation "j8up02uuq"
# Retrieving astrometrically-updated WCS "OPUS-GSC240" for observation "j8up02uuq"
# Retrieving astrometrically-updated WCS "IDC_0461802ej-GSC240" for observation "j8up02uuq"
# Updating j8up02uuq with:
# 	Headerlet with WCSNAME=OPUS
# 	Headerlet with WCSNAME=IDC_0461802ej
# 	Headerlet with WCSNAME=OPUS-GSC240
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Initializing new WCSCORR table for  j8up02uuq_raw.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Deleted all instances of WCS with key   in extensions [('SCI', 1)]
# Replacing primary WCS with
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 15 for chip 1 : FR656N
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 15 for chip 1 : FR656N
# Updating astrometry for j8up02usq
# Accessing AstrometryDB service :
# 	https://mast.stsci.edu/portal/astrometryDB/observation/read/j8up02usq
# AstrometryDB service call succeeded
# Retrieving astrometrically-updated WCS "OPUS" for observation "j8up02usq"
# Retrieving astrometrically-updated WCS "IDC_0461802ej" for observation "j8up02usq"
# Retrieving astrometrically-updated WCS "OPUS-GSC240" for observation "j8up02usq"
# Retrieving astrometrically-updated WCS "IDC_0461802ej-GSC240" for observation "j8up02usq"
# Updating j8up02usq with:
# 	Headerlet with WCSNAME=OPUS
# 	Headerlet with WCSNAME=IDC_0461802ej
# 	Headerlet with WCSNAME=OPUS-GSC240
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Initializing new WCSCORR table for  j8up02usq_raw.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Deleted all instances of WCS with key   in extensions [('SCI', 1)]
# Replacing primary WCS with
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 35 for chip 1 : FR459M
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 35 for chip 1 : FR459M
# Updating astrometry for j8up02v5q
# Accessing AstrometryDB service :
# 	https://mast.stsci.edu/portal/astrometryDB/observation/read/j8up02v5q
# AstrometryDB service call succeeded
# Retrieving astrometrically-updated WCS "OPUS" for observation "j8up02v5q"
# Retrieving astrometrically-updated WCS "IDC_0461802ej" for observation "j8up02v5q"
# Retrieving astrometrically-updated WCS "OPUS-GSC240" for observation "j8up02v5q"
# Retrieving astrometrically-updated WCS "IDC_0461802ej-GSC240" for observation "j8up02v5q"
# Updating j8up02v5q with:
# 	Headerlet with WCSNAME=OPUS
# 	Headerlet with WCSNAME=IDC_0461802ej
# 	Headerlet with WCSNAME=OPUS-GSC240
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Initializing new WCSCORR table for  j8up02v5q_raw.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Deleted all instances of WCS with key   in extensions [('SCI', 1)]
# Replacing primary WCS with
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 41 for chip 1 : FR505N
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 41 for chip 1 : FR505N
# Updating astrometry for j8up02uyq
# Accessing AstrometryDB service :
# 	https://mast.stsci.edu/portal/astrometryDB/observation/read/j8up02uyq
# AstrometryDB service call succeeded
# Retrieving astrometrically-updated WCS "OPUS" for observation "j8up02uyq"
# Retrieving astrometrically-updated WCS "IDC_0461802ej" for observation "j8up02uyq"
# Retrieving astrometrically-updated WCS "OPUS-GSC240" for observation "j8up02uyq"
# Retrieving astrometrically-updated WCS "IDC_0461802ej-GSC240" for observation "j8up02uyq"
# Updating j8up02uyq with:
# 	Headerlet with WCSNAME=OPUS
# 	Headerlet with WCSNAME=IDC_0461802ej
# 	Headerlet with WCSNAME=OPUS-GSC240
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Initializing new WCSCORR table for  j8up02uyq_raw.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Deleted all instances of WCS with key   in extensions [('SCI', 1)]
# Replacing primary WCS with
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 15 for chip 1 : FR656N
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 15 for chip 1 : FR656N
# Updating astrometry for j8up02utq
# Accessing AstrometryDB service :
# 	https://mast.stsci.edu/portal/astrometryDB/observation/read/j8up02utq
# AstrometryDB service call succeeded
# Retrieving astrometrically-updated WCS "OPUS" for observation "j8up02utq"
# Retrieving astrometrically-updated WCS "IDC_0461802ej" for observation "j8up02utq"
# Retrieving astrometrically-updated WCS "OPUS-GSC240" for observation "j8up02utq"
# Retrieving astrometrically-updated WCS "IDC_0461802ej-GSC240" for observation "j8up02utq"
# Updating j8up02utq with:
# 	Headerlet with WCSNAME=OPUS
# 	Headerlet with WCSNAME=IDC_0461802ej
# 	Headerlet with WCSNAME=OPUS-GSC240
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Initializing new WCSCORR table for  j8up02utq_raw.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Deleted all instances of WCS with key   in extensions [('SCI', 1)]
# Replacing primary WCS with
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 7 for chip 1 : FR388N
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 7 for chip 1 : FR388N
# Updating astrometry for j8up02uwq
# Accessing AstrometryDB service :
# 	https://mast.stsci.edu/portal/astrometryDB/observation/read/j8up02uwq
# AstrometryDB service call succeeded
# Retrieving astrometrically-updated WCS "OPUS" for observation "j8up02uwq"
# Retrieving astrometrically-updated WCS "IDC_0461802ej" for observation "j8up02uwq"
# Retrieving astrometrically-updated WCS "OPUS-GSC240" for observation "j8up02uwq"
# Retrieving astrometrically-updated WCS "IDC_0461802ej-GSC240" for observation "j8up02uwq"
# Updating j8up02uwq with:
# 	Headerlet with WCSNAME=OPUS
# 	Headerlet with WCSNAME=IDC_0461802ej
# 	Headerlet with WCSNAME=OPUS-GSC240
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Initializing new WCSCORR table for  j8up02uwq_raw.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Deleted all instances of WCS with key   in extensions [('SCI', 1)]
# Replacing primary WCS with
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 41 for chip 1 : FR505N
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 41 for chip 1 : FR505N
# Updating astrometry for j8up02v0q
# Accessing AstrometryDB service :
# 	https://mast.stsci.edu/portal/astrometryDB/observation/read/j8up02v0q
# AstrometryDB service call succeeded
# Retrieving astrometrically-updated WCS "OPUS" for observation "j8up02v0q"
# Retrieving astrometrically-updated WCS "IDC_0461802ej" for observation "j8up02v0q"
# Retrieving astrometrically-updated WCS "OPUS-GSC240" for observation "j8up02v0q"
# Retrieving astrometrically-updated WCS "IDC_0461802ej-GSC240" for observation "j8up02v0q"
# Updating j8up02v0q with:
# 	Headerlet with WCSNAME=OPUS
# 	Headerlet with WCSNAME=IDC_0461802ej
# 	Headerlet with WCSNAME=OPUS-GSC240
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Initializing new WCSCORR table for  j8up02v0q_raw.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Deleted all instances of WCS with key   in extensions [('SCI', 1)]
# Replacing primary WCS with
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 35 for chip 1 : FR459M
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 35 for chip 1 : FR459M
# Updating astrometry for j8up02v7q
# Accessing AstrometryDB service :
# 	https://mast.stsci.edu/portal/astrometryDB/observation/read/j8up02v7q
# AstrometryDB service call succeeded
# Retrieving astrometrically-updated WCS "OPUS" for observation "j8up02v7q"
# Retrieving astrometrically-updated WCS "IDC_0461802ej" for observation "j8up02v7q"
# Retrieving astrometrically-updated WCS "OPUS-GSC240" for observation "j8up02v7q"
# Retrieving astrometrically-updated WCS "IDC_0461802ej-GSC240" for observation "j8up02v7q"
# Updating j8up02v7q with:
# 	Headerlet with WCSNAME=OPUS
# 	Headerlet with WCSNAME=IDC_0461802ej
# 	Headerlet with WCSNAME=OPUS-GSC240
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Initializing new WCSCORR table for  j8up02v7q_raw.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Deleted all instances of WCS with key   in extensions [('SCI', 1)]
# Replacing primary WCS with
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 7 for chip 1 : FR388N
# Using 2015-calibrated VAFACTOR-corrected TDD correction...
# - IDCTAB: Distortion model from row 7 for chip 1 : FR388N
# Updating astrometry for j8up02uvq
# Accessing AstrometryDB service :
# 	https://mast.stsci.edu/portal/astrometryDB/observation/read/j8up02uvq
# AstrometryDB service call succeeded
# Retrieving astrometrically-updated WCS "OPUS" for observation "j8up02uvq"
# Retrieving astrometrically-updated WCS "IDC_0461802ej" for observation "j8up02uvq"
# Retrieving astrometrically-updated WCS "OPUS-GSC240" for observation "j8up02uvq"
# Retrieving astrometrically-updated WCS "IDC_0461802ej-GSC240" for observation "j8up02uvq"
# Updating j8up02uvq with:
# 	Headerlet with WCSNAME=OPUS
# 	Headerlet with WCSNAME=IDC_0461802ej
# 	Headerlet with WCSNAME=OPUS-GSC240
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# Initializing new WCSCORR table for  j8up02uvq_raw.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
#                  [astropy.wcs.wcs]
# Deleted all instances of WCS with key   in extensions [('SCI', 1)]
# Replacing primary WCS with
# 	Headerlet with WCSNAME=IDC_0461802ej-GSC240
# ['j8up02v9q_raw.fits',
#  'j8up02uuq_raw.fits',
#  'j8up02usq_raw.fits',
#  'j8up02v5q_raw.fits',
#  'j8up02uyq_raw.fits',
#  'j8up02utq_raw.fits',
#  'j8up02uwq_raw.fits',
#  'j8up02v0q_raw.fits',
#  'j8up02v7q_raw.fits',
#  'j8up02uvq_raw.fits']

# %% [markdown]
# Next, we use TweakReg to update the WCS metadata for the images using their updated reference files.

# %%
tweakreg.TweakReg('j8up02*raw.fits', updatehdr=True, reusename=True, interactive=False,
                  conv_width=3.0, threshold=300.0, peakmin=100, peakmax=10000)
# Out:
# Setting up logfile :  tweakreg.log
# TweakReg Version 1.4.7(18-April-2018) started at: 14:25:58.858 (29/08/2022)
#
# Version Information
# --------------------
# Python Version [Clang 12.0.0 ]
# 3.7.13 (default, Mar 28 2022, 07:24:34)
# numpy Version -> 1.21.5
# astropy Version -> 4.3.1
# stwcs Version -> 1.6.1
#
# Finding shifts for:
#     j8up02v9q_raw.fits
#     j8up02uuq_raw.fits
#     j8up02usq_raw.fits
#     j8up02v5q_raw.fits
#     j8up02uyq_raw.fits
#     j8up02utq_raw.fits
#     j8up02uwq_raw.fits
#     j8up02v0q_raw.fits
#     j8up02v7q_raw.fits
#     j8up02uvq_raw.fits
#
# ===  Source finding for image 'j8up02v9q_raw.fits':
#   #  Source finding for 'j8up02v9q_raw.fits', EXT=('SCI', 1) started at: 14:25:59.214 (29/08/2022)
#      Found 1382 objects.
# ===  FINAL number of objects in image 'j8up02v9q_raw.fits': 1382
#
# ===  Source finding for image 'j8up02uuq_raw.fits':
#   #  Source finding for 'j8up02uuq_raw.fits', EXT=('SCI', 1) started at: 14:25:59.629 (29/08/2022)
#      Found 1127 objects.
# ===  FINAL number of objects in image 'j8up02uuq_raw.fits': 1127
#
# ===  Source finding for image 'j8up02usq_raw.fits':
#   #  Source finding for 'j8up02usq_raw.fits', EXT=('SCI', 1) started at: 14:26:00.008 (29/08/2022)
#      Found 1269 objects.
# ===  FINAL number of objects in image 'j8up02usq_raw.fits': 1269
#
# ===  Source finding for image 'j8up02v5q_raw.fits':
#   #  Source finding for 'j8up02v5q_raw.fits', EXT=('SCI', 1) started at: 14:26:00.456 (29/08/2022)
#      Found 1138 objects.
# ===  FINAL number of objects in image 'j8up02v5q_raw.fits': 1138
#
# ===  Source finding for image 'j8up02uyq_raw.fits':
#   #  Source finding for 'j8up02uyq_raw.fits', EXT=('SCI', 1) started at: 14:26:00.834 (29/08/2022)
#      Found 1492 objects.
# ===  FINAL number of objects in image 'j8up02uyq_raw.fits': 1492
#
# ===  Source finding for image 'j8up02utq_raw.fits':
#   #  Source finding for 'j8up02utq_raw.fits', EXT=('SCI', 1) started at: 14:26:01.227 (29/08/2022)
#      Found 1285 objects.
# ===  FINAL number of objects in image 'j8up02utq_raw.fits': 1285
#
# ===  Source finding for image 'j8up02uwq_raw.fits':
#   #  Source finding for 'j8up02uwq_raw.fits', EXT=('SCI', 1) started at: 14:26:01.623 (29/08/2022)
#      Found 869 objects.
# ===  FINAL number of objects in image 'j8up02uwq_raw.fits': 869
#
# ===  Source finding for image 'j8up02v0q_raw.fits':
#   #  Source finding for 'j8up02v0q_raw.fits', EXT=('SCI', 1) started at: 14:26:01.986 (29/08/2022)
#      Found 1581 objects.
# ===  FINAL number of objects in image 'j8up02v0q_raw.fits': 1581
#
# ===  Source finding for image 'j8up02v7q_raw.fits':
#   #  Source finding for 'j8up02v7q_raw.fits', EXT=('SCI', 1) started at: 14:26:02.427 (29/08/2022)
#      Found 1100 objects.
# ===  FINAL number of objects in image 'j8up02v7q_raw.fits': 1100
#
# ===  Source finding for image 'j8up02uvq_raw.fits':
#   #  Source finding for 'j8up02uvq_raw.fits', EXT=('SCI', 1) started at: 14:26:02.798 (29/08/2022)
#      Found 1008 objects.
# ===  FINAL number of objects in image 'j8up02uvq_raw.fits': 1008
#
#
# ===============================================================
# Performing alignment in the projection plane defined by the WCS
# derived from 'j8up02v9q_raw.fits'
# ===============================================================
#
#
# ====================
# Performing fit for: j8up02uuq_raw.fits
#
# Matching sources from 'j8up02uuq_raw.fits' with sources from reference image 'j8up02v9q_raw.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of 0.006925, 17.65 with significance of 4.544 and 17 matches
# ##############################################################################
# #                                                                            #
# # WARNING:                                                                   #
# # Not enough matches (< 15) found for input image: j8up02uuq_raw.fits        #
# #                                                                            #
# ##############################################################################
#
# ====================
# Performing fit for: j8up02usq_raw.fits
#
# Matching sources from 'j8up02usq_raw.fits' with sources from reference image 'j8up02v9q_raw.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of 8.264, -19.96 with significance of 3.542 and 14 matches
# ##############################################################################
# #                                                                            #
# # WARNING:                                                                   #
# # Not enough matches (< 15) found for input image: j8up02usq_raw.fits        #
# #                                                                            #
# ##############################################################################
#
# ====================
# Performing fit for: j8up02v5q_raw.fits
#
# Matching sources from 'j8up02v5q_raw.fits' with sources from reference image 'j8up02v9q_raw.fits'
# Computing initial guess for X and Y shifts...
# WARNING: Found peak in the 2D histogram lies at the edge of the histogram. Try increasing 'searchrad' for improved results.
# Found initial X and Y shifts of -20, 14 with significance of 3.588 and 11 matches
# ##############################################################################
# #                                                                            #
# # WARNING:                                                                   #
# # Not enough matches (< 15) found for input image: j8up02v5q_raw.fits        #
# #                                                                            #
# ##############################################################################
#
# ====================
# Performing fit for: j8up02uyq_raw.fits
#
# Matching sources from 'j8up02uyq_raw.fits' with sources from reference image 'j8up02v9q_raw.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of 20, 6 with significance of 5.201 and 14 matches
# ##############################################################################
# #                                                                            #
# # WARNING:                                                                   #
# # Not enough matches (< 15) found for input image: j8up02uyq_raw.fits        #
# #                                                                            #
# ##############################################################################
#
# ====================
# Performing fit for: j8up02utq_raw.fits
#
# Matching sources from 'j8up02utq_raw.fits' with sources from reference image 'j8up02v9q_raw.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of -1, -1 with significance of 4.205 and 49 matches
# ##############################################################################
# #                                                                            #
# # WARNING:                                                                   #
# # Not enough matches (< 15) found for input image: j8up02utq_raw.fits        #
# #                                                                            #
# ##############################################################################
#
# ====================
# Performing fit for: j8up02uwq_raw.fits
#
# Matching sources from 'j8up02uwq_raw.fits' with sources from reference image 'j8up02v9q_raw.fits'
# Computing initial guess for X and Y shifts...
# WARNING: Found peak in the 2D histogram lies at the edge of the histogram. Try increasing 'searchrad' for improved results.
# Found initial X and Y shifts of -20, -17 with significance of 2.811 and 18 matches
# ##############################################################################
# #                                                                            #
# # WARNING:                                                                   #
# # Not enough matches (< 15) found for input image: j8up02uwq_raw.fits        #
# #                                                                            #
# ##############################################################################
#
# ====================
# Performing fit for: j8up02v0q_raw.fits
#
# Matching sources from 'j8up02v0q_raw.fits' with sources from reference image 'j8up02v9q_raw.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of -0.9841, 1.472 with significance of 4.195 and 51 matches
# ##############################################################################
# #                                                                            #
# # WARNING:                                                                   #
# # Not enough matches (< 15) found for input image: j8up02v0q_raw.fits        #
# #                                                                            #
# ##############################################################################
#
# ====================
# Performing fit for: j8up02v7q_raw.fits
#
# Matching sources from 'j8up02v7q_raw.fits' with sources from reference image 'j8up02v9q_raw.fits'
# Computing initial guess for X and Y shifts...
# WARNING: Found peak in the 2D histogram lies at the edge of the histogram. Try increasing 'searchrad' for improved results.
# Found initial X and Y shifts of -14, -20 with significance of 2.801 and 13 matches
# ##############################################################################
# #                                                                            #
# # WARNING:                                                                   #
# # Not enough matches (< 15) found for input image: j8up02v7q_raw.fits        #
# #                                                                            #
# ##############################################################################
#
# ====================
# Performing fit for: j8up02uvq_raw.fits
#
# Matching sources from 'j8up02uvq_raw.fits' with sources from reference image 'j8up02v9q_raw.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of -3.702, -14.62 with significance of 2.817 and 10 matches
# ##############################################################################
# #                                                                            #
# # WARNING:                                                                   #
# # Not enough matches (< 15) found for input image: j8up02uvq_raw.fits        #
# #                                                                            #
# ##############################################################################
#
# Unable to match the following images:
# -------------------------------------
# j8up02uuq_raw.fits
# j8up02usq_raw.fits
# j8up02v5q_raw.fits
# j8up02uyq_raw.fits
# j8up02utq_raw.fits
# j8up02uwq_raw.fits
# j8up02v0q_raw.fits
# j8up02v7q_raw.fits
# j8up02uvq_raw.fits
#
#
# Processing j8up02v9q_raw.fits['SCI',1]
#
# Updating header for j8up02v9q_raw.fits[('SCI', 1)]
# WCS Keywords
#
# CD_11  CD_12: -8.9044215177583e-06 9.7313921978183e-06
# CD_21  CD_22: 1.0668536591516e-05 9.4705333313553e-06
# CRVAL    : 83.819129996224 -5.3898380400105
# CRPIX    : 1036.0 1023.0
# NAXIS    : 2070 2046
# Plate Scale : 0.050026581800007186
# ORIENTAT : 45.778317399727264
# WCSNAME  :  TWEAK
#
# Processing j8up02uuq_raw.fits['SCI',1]
#
# Updating header for j8up02uuq_raw.fits[('SCI', 1)]
# WCS Keywords
#
# CD_11  CD_12: -8.9043674180987e-06 9.7313330645123e-06
# CD_21  CD_22: 1.0668471776139e-05 9.47047577984909e-06
# CRVAL    : 83.819129996224 -5.3898380400105
# CRPIX    : 1036.0 1023.0
# NAXIS    : 2070 2046
# Plate Scale : 0.05002627786519648
# ORIENTAT : 45.77831740977417
# WCSNAME  :  TWEAK
#
# Processing j8up02usq_raw.fits['SCI',1]
#
# Updating header for j8up02usq_raw.fits[('SCI', 1)]
# WCS Keywords
#
# CD_11  CD_12: -8.9044854791723e-06 9.7314620891775e-06
# CD_21  CD_22: 1.0668613220504e-05 9.4706013433475e-06
# CRVAL    : 83.819129996224 -5.3898380400105
# CRPIX    : 1036.0 1023.0
# NAXIS    : 2070 2046
# Plate Scale : 0.050026941134549086
# ORIENTAT : 45.77831741746254
# WCSNAME  :  TWEAK
#
# Processing j8up02v5q_raw.fits['SCI',1]
#
# Updating header for j8up02v5q_raw.fits[('SCI', 1)]
# WCS Keywords
#
# CD_11  CD_12: -8.9045097663733e-06 9.73148863823179e-06
# CD_21  CD_22: 1.0668642328092e-05 9.4706271847141e-06
# CRVAL    : 83.819129996224 -5.3898380400105
# CRPIX    : 1036.0 1023.0
# NAXIS    : 2070 2046
# Plate Scale : 0.05002707760825482
# ORIENTAT : 45.7783174054157
# WCSNAME  :  TWEAK
#
# Processing j8up02uyq_raw.fits['SCI',1]
#
# Updating header for j8up02uyq_raw.fits[('SCI', 1)]
# WCS Keywords
#
# CD_11  CD_12: -8.904149163592e-06 9.7310945407674e-06
# CD_21  CD_22: 1.066821027995e-05 9.4702436508051e-06
# CRVAL    : 83.819129996224 -5.3898380400105
# CRPIX    : 1036.0 1023.0
# NAXIS    : 2070 2046
# Plate Scale : 0.05002505166859162
# ORIENTAT : 45.77831740719253
# WCSNAME  :  TWEAK
#
# Processing j8up02utq_raw.fits['SCI',1]
#
# Updating header for j8up02utq_raw.fits[('SCI', 1)]
# WCS Keywords
#
# CD_11  CD_12: -8.9044340956855e-06 9.7314059374642e-06
# CD_21  CD_22: 1.0668551664585e-05 9.4705466943594e-06
# CRVAL    : 83.819129996224 -5.3898380400105
# CRPIX    : 1036.0 1023.0
# NAXIS    : 2070 2046
# Plate Scale : 0.05002665247394496
# ORIENTAT : 45.77831742494004
# WCSNAME  :  TWEAK
#
# Processing j8up02uwq_raw.fits['SCI',1]
#
# Updating header for j8up02uwq_raw.fits[('SCI', 1)]
# WCS Keywords
#
# CD_11  CD_12: -8.9042054934243e-06 9.7311563069945e-06
# CD_21  CD_22: 1.066827797525e-05 9.4703035846493e-06
# CRVAL    : 83.819129996224 -5.3898380400105
# CRPIX    : 1036.0 1023.0
# NAXIS    : 2070 2046
# Plate Scale : 0.05002536870753937
# ORIENTAT : 45.77831794146454
# WCSNAME  :  TWEAK
#
# Processing j8up02v0q_raw.fits['SCI',1]
#
# Updating header for j8up02v0q_raw.fits[('SCI', 1)]
# WCS Keywords
#
# CD_11  CD_12: -8.9041394748897e-06 9.7310839576363e-06
# CD_21  CD_22: 1.0668198668502e-05 9.4702333520841e-06
# CRVAL    : 83.819129996224 -5.3898380400106
# CRPIX    : 1036.0 1023.0
# NAXIS    : 2070 2046
# Plate Scale : 0.050024997226798144
# ORIENTAT : 45.778317405016544
# WCSNAME  :  TWEAK
#
# Processing j8up02v7q_raw.fits['SCI',1]
#
# Updating header for j8up02v7q_raw.fits[('SCI', 1)]
# WCS Keywords
#
# CD_11  CD_12: -8.9044764229949e-06 9.7314522006957e-06
# CD_21  CD_22: 1.0668602375824e-05 9.4705917218551e-06
# CRVAL    : 83.819129996224 -5.3898380400105
# CRPIX    : 1036.0 1023.0
# NAXIS    : 2070 2046
# Plate Scale : 0.05002689027106901
# ORIENTAT : 45.77831741165804
# WCSNAME  :  TWEAK
#
# Processing j8up02uvq_raw.fits['SCI',1]
#
# Updating header for j8up02uvq_raw.fits[('SCI', 1)]
# WCS Keywords
#
# CD_11  CD_12: -8.9042929957546e-06 9.73125192072049e-06
# CD_21  CD_22: 1.0668382807211e-05 9.4703966376482e-06
# CRVAL    : 83.819129996224 -5.3898380400105
# CRPIX    : 1036.0 1023.0
# NAXIS    : 2070 2046
# Plate Scale : 0.050025860294068886
# ORIENTAT : 45.778317934545825
# WCSNAME  :  TWEAK
# Trailer file written to:  tweakreg.log

# %% [markdown]
# ### Edit this, currently copied.
# This step adjusts image data values so that all images and chips appear (to AstroDrizzle) to have a single inverse sensitivity (PHOTFLAM). This can be achieved using the photeq task in Drizzlepac. This task adjusts image data so that when these data are multiplied by the same single PHOTFLAM value, the correct flux is obtained.

# %%
photeq.photeq?

# %%
tofix = []
for file in files:
    try:
        h = fits.getheader(file)
    except OSError:
        continue
    if 'PHOTFLAM' in h:
        tofix.append(file)
        
for file in tofix:
    photeq.photeq(files=file, ref_phot_ext=None, readonly=False)
# Out:
# ***** drizzlepac.photeq started on 2022-08-29 14:46:47.380257
#       Version 0.2 (06-Nov-2015)
#
# PRIMARY PHOTOMETRIC KEYWORD: PHOTFLAM
# SECONDARY PHOTOMETRIC KEYWORD(S): PHOTFNU
# REFERENCE VALUE FROM FILE: 'j8up02usq_sci1_blt.fits[0]'
# REFERENCE 'PHOTFLAM' VALUE IS: 1.3162776e-18
#
# Processing file 'j8up02usq_sci1_blt.fits'
#    * Primary header:
#      - 'PHOTFLAM' = 1.3162776e-18 found in the primary header.
#      - Data conversion factor based on primary header: 1.0
#
# Done.
# ***** drizzlepac.photeq started on 2022-08-29 14:46:47.412837
#       Version 0.2 (06-Nov-2015)
#
# PRIMARY PHOTOMETRIC KEYWORD: PHOTFLAM
# SECONDARY PHOTOMETRIC KEYWORD(S): PHOTFNU
# REFERENCE VALUE FROM FILE: 'j8up02usq_single_sci.fits[0]'
# REFERENCE 'PHOTFLAM' VALUE IS: 1.3162776e-18
#
# Processing file 'j8up02usq_single_sci.fits'
#    * Primary header:
#      - 'PHOTFLAM' = 1.3162776e-18 found in the primary header.
#      - Data conversion factor based on primary header: 1.0
#
# Done.
# ***** drizzlepac.photeq started on 2022-08-29 14:46:47.435433
#       Version 0.2 (06-Nov-2015)
#
# PRIMARY PHOTOMETRIC KEYWORD: PHOTFLAM
# SECONDARY PHOTOMETRIC KEYWORD(S): PHOTFNU
# REFERENCE VALUE FROM FILE: 'j8up02utq_sci1_blt.fits[0]'
# REFERENCE 'PHOTFLAM' VALUE IS: 1.3049743e-18
#
# Processing file 'j8up02utq_sci1_blt.fits'
#    * Primary header:
#      - 'PHOTFLAM' = 1.3049743e-18 found in the primary header.
#      - Data conversion factor based on primary header: 1.0
#
# Done.
# ***** drizzlepac.photeq started on 2022-08-29 14:46:47.469682
#       Version 0.2 (06-Nov-2015)
#
# PRIMARY PHOTOMETRIC KEYWORD: PHOTFLAM
# SECONDARY PHOTOMETRIC KEYWORD(S): PHOTFNU
# REFERENCE VALUE FROM FILE: 'j8up02utq_single_sci.fits[0]'
# REFERENCE 'PHOTFLAM' VALUE IS: 1.3049743e-18
#
# Processing file 'j8up02utq_single_sci.fits'
#    * Primary header:
#      - 'PHOTFLAM' = 1.3049743e-18 found in the primary header.
#      - Data conversion factor based on primary header: 1.0
#
# Done.
# ***** drizzlepac.photeq started on 2022-08-29 14:46:47.489221
#       Version 0.2 (06-Nov-2015)
#
# PRIMARY PHOTOMETRIC KEYWORD: PHOTFLAM
# SECONDARY PHOTOMETRIC KEYWORD(S): PHOTFNU
# REFERENCE VALUE FROM FILE: 'j8up02uuq_sci1_blt.fits[0]'
# REFERENCE 'PHOTFLAM' VALUE IS: 1.23711e-18
#
# Processing file 'j8up02uuq_sci1_blt.fits'
#    * Primary header:
#      - 'PHOTFLAM' = 1.23711e-18 found in the primary header.
#      - Data conversion factor based on primary header: 1.0
#
# Done.
# ***** drizzlepac.photeq started on 2022-08-29 14:46:47.523404
#       Version 0.2 (06-Nov-2015)
#
# PRIMARY PHOTOMETRIC KEYWORD: PHOTFLAM
# SECONDARY PHOTOMETRIC KEYWORD(S): PHOTFNU
# REFERENCE VALUE FROM FILE: 'j8up02uuq_single_sci.fits[0]'
# REFERENCE 'PHOTFLAM' VALUE IS: 1.23711e-18
#
# Processing file 'j8up02uuq_single_sci.fits'
#    * Primary header:
#      - 'PHOTFLAM' = 1.23711e-18 found in the primary header.
#      - Data conversion factor based on primary header: 1.0
#
# Done.
# ***** drizzlepac.photeq started on 2022-08-29 14:46:47.543047
#       Version 0.2 (06-Nov-2015)
#
# PRIMARY PHOTOMETRIC KEYWORD: PHOTFLAM
# SECONDARY PHOTOMETRIC KEYWORD(S): PHOTFNU
# REFERENCE VALUE FROM FILE: 'j8up02uvq_sci1_blt.fits[0]'
# REFERENCE 'PHOTFLAM' VALUE IS: 1.7160227e-17
#
# Processing file 'j8up02uvq_sci1_blt.fits'
#    * Primary header:
#      - 'PHOTFLAM' = 1.7160227e-17 found in the primary header.
#      - Data conversion factor based on primary header: 1.0
#
# Done.
# ***** drizzlepac.photeq started on 2022-08-29 14:46:47.577476
#       Version 0.2 (06-Nov-2015)
#
# PRIMARY PHOTOMETRIC KEYWORD: PHOTFLAM
# SECONDARY PHOTOMETRIC KEYWORD(S): PHOTFNU
# REFERENCE VALUE FROM FILE: 'j8up02uvq_single_sci.fits[0]'
# REFERENCE 'PHOTFLAM' VALUE IS: 1.7160227e-17
#
# Processing file 'j8up02uvq_single_sci.fits'
#    * Primary header:
#      - 'PHOTFLAM' = 1.7160227e-17 found in the primary header.
#      - Data conversion factor based on primary header: 1.0
#
# Done.
# ***** drizzlepac.photeq started on 2022-08-29 14:46:47.596710
#       Version 0.2 (06-Nov-2015)
#
# PRIMARY PHOTOMETRIC KEYWORD: PHOTFLAM
# SECONDARY PHOTOMETRIC KEYWORD(S): PHOTFNU
# REFERENCE VALUE FROM FILE: 'j8up02uwq_sci1_blt.fits[0]'
# REFERENCE 'PHOTFLAM' VALUE IS: 1.0318147e-17
#
# Processing file 'j8up02uwq_sci1_blt.fits'
#    * Primary header:
#      - 'PHOTFLAM' = 1.0318147e-17 found in the primary header.
#      - Data conversion factor based on primary header: 1.0
#
# Done.
# ***** drizzlepac.photeq started on 2022-08-29 14:46:47.637792
#       Version 0.2 (06-Nov-2015)
#
# PRIMARY PHOTOMETRIC KEYWORD: PHOTFLAM
# SECONDARY PHOTOMETRIC KEYWORD(S): PHOTFNU
# REFERENCE VALUE FROM FILE: 'j8up02uwq_single_sci.fits[0]'
# REFERENCE 'PHOTFLAM' VALUE IS: 1.0318147e-17
#
# Processing file 'j8up02uwq_single_sci.fits'
#    * Primary header:
#      - 'PHOTFLAM' = 1.0318147e-17 found in the primary header.
#      - Data conversion factor based on primary header: 1.0
#
# Done.
# ***** drizzlepac.photeq started on 2022-08-29 14:46:47.656479
#       Version 0.2 (06-Nov-2015)
#
# PRIMARY PHOTOMETRIC KEYWORD: PHOTFLAM
# SECONDARY PHOTOMETRIC KEYWORD(S): PHOTFNU
# REFERENCE VALUE FROM FILE: 'j8up02uyq_sci1_blt.fits[0]'
# REFERENCE 'PHOTFLAM' VALUE IS: 2.7348452e-18
#
# Processing file 'j8up02uyq_sci1_blt.fits'
#    * Primary header:
#      - 'PHOTFLAM' = 2.7348452e-18 found in the primary header.
#      - Data conversion factor based on primary header: 1.0
#
# Done.
# ***** drizzlepac.photeq started on 2022-08-29 14:46:47.691120
#       Version 0.2 (06-Nov-2015)
#
# PRIMARY PHOTOMETRIC KEYWORD: PHOTFLAM
# SECONDARY PHOTOMETRIC KEYWORD(S): PHOTFNU
# REFERENCE VALUE FROM FILE: 'j8up02uyq_single_sci.fits[0]'
# REFERENCE 'PHOTFLAM' VALUE IS: 2.7348452e-18
#
# Processing file 'j8up02uyq_single_sci.fits'
#    * Primary header:
#      - 'PHOTFLAM' = 2.7348452e-18 found in the primary header.
#      - Data conversion factor based on primary header: 1.0
#
# Done.
# ***** drizzlepac.photeq started on 2022-08-29 14:46:47.711248
#       Version 0.2 (06-Nov-2015)
#
# PRIMARY PHOTOMETRIC KEYWORD: PHOTFLAM
# SECONDARY PHOTOMETRIC KEYWORD(S): PHOTFNU
# REFERENCE VALUE FROM FILE: 'j8up02v0q_sci1_blt.fits[0]'
# REFERENCE 'PHOTFLAM' VALUE IS: 2.8298463e-18
#
# Processing file 'j8up02v0q_sci1_blt.fits'
#    * Primary header:
#      - 'PHOTFLAM' = 2.8298463e-18 found in the primary header.
#      - Data conversion factor based on primary header: 1.0
#
# Done.
# ***** drizzlepac.photeq started on 2022-08-29 14:46:47.745686
#       Version 0.2 (06-Nov-2015)
#
# PRIMARY PHOTOMETRIC KEYWORD: PHOTFLAM
# SECONDARY PHOTOMETRIC KEYWORD(S): PHOTFNU
# REFERENCE VALUE FROM FILE: 'j8up02v0q_single_sci.fits[0]'
# REFERENCE 'PHOTFLAM' VALUE IS: 2.8298463e-18
#
# Processing file 'j8up02v0q_single_sci.fits'
#    * Primary header:
#      - 'PHOTFLAM' = 2.8298463e-18 found in the primary header.
#      - Data conversion factor based on primary header: 1.0
#
# Done.
# ***** drizzlepac.photeq started on 2022-08-29 14:46:47.764801
#       Version 0.2 (06-Nov-2015)
#
# PRIMARY PHOTOMETRIC KEYWORD: PHOTFLAM
# SECONDARY PHOTOMETRIC KEYWORD(S): PHOTFNU
# REFERENCE VALUE FROM FILE: 'j8up02v5q_sci1_blt.fits[0]'
# REFERENCE 'PHOTFLAM' VALUE IS: 2.8734418e-18
#
# Processing file 'j8up02v5q_sci1_blt.fits'
#    * Primary header:
#      - 'PHOTFLAM' = 2.8734418e-18 found in the primary header.
#      - Data conversion factor based on primary header: 1.0
#
# Done.
# ***** drizzlepac.photeq started on 2022-08-29 14:46:47.798075
#       Version 0.2 (06-Nov-2015)
#
# PRIMARY PHOTOMETRIC KEYWORD: PHOTFLAM
# SECONDARY PHOTOMETRIC KEYWORD(S): PHOTFNU
# REFERENCE VALUE FROM FILE: 'j8up02v5q_single_sci.fits[0]'
# REFERENCE 'PHOTFLAM' VALUE IS: 2.8734418e-18
#
# Processing file 'j8up02v5q_single_sci.fits'
#    * Primary header:
#      - 'PHOTFLAM' = 2.8734418e-18 found in the primary header.
#      - Data conversion factor based on primary header: 1.0
#
# Done.
# ***** drizzlepac.photeq started on 2022-08-29 14:46:47.817471
#       Version 0.2 (06-Nov-2015)
#
# PRIMARY PHOTOMETRIC KEYWORD: PHOTFLAM
# SECONDARY PHOTOMETRIC KEYWORD(S): PHOTFNU
# REFERENCE VALUE FROM FILE: 'j8up02v7q_sci1_blt.fits[0]'
# REFERENCE 'PHOTFLAM' VALUE IS: 1.0143808e-18
#
# Processing file 'j8up02v7q_sci1_blt.fits'
#    * Primary header:
#      - 'PHOTFLAM' = 1.0143808e-18 found in the primary header.
#      - Data conversion factor based on primary header: 1.0
#
# Done.
# ***** drizzlepac.photeq started on 2022-08-29 14:46:47.848920
#       Version 0.2 (06-Nov-2015)
#
# PRIMARY PHOTOMETRIC KEYWORD: PHOTFLAM
# SECONDARY PHOTOMETRIC KEYWORD(S): PHOTFNU
# REFERENCE VALUE FROM FILE: 'j8up02v7q_single_sci.fits[0]'
# REFERENCE 'PHOTFLAM' VALUE IS: 1.0143808e-18
#
# Processing file 'j8up02v7q_single_sci.fits'
#    * Primary header:
#      - 'PHOTFLAM' = 1.0143808e-18 found in the primary header.
#      - Data conversion factor based on primary header: 1.0
#
# Done.
# ***** drizzlepac.photeq started on 2022-08-29 14:46:47.868430
#       Version 0.2 (06-Nov-2015)
#
# PRIMARY PHOTOMETRIC KEYWORD: PHOTFLAM
# SECONDARY PHOTOMETRIC KEYWORD(S): PHOTFNU
# REFERENCE VALUE FROM FILE: 'j8up02v9q_sci1_blt.fits[0]'
# REFERENCE 'PHOTFLAM' VALUE IS: 6.2963406e-19
#
# Processing file 'j8up02v9q_sci1_blt.fits'
#    * Primary header:
#      - 'PHOTFLAM' = 6.2963406e-19 found in the primary header.
#      - Data conversion factor based on primary header: 1.0
#
# Done.
# ***** drizzlepac.photeq started on 2022-08-29 14:46:47.901165
#       Version 0.2 (06-Nov-2015)
#
# PRIMARY PHOTOMETRIC KEYWORD: PHOTFLAM
# SECONDARY PHOTOMETRIC KEYWORD(S): PHOTFNU
# REFERENCE VALUE FROM FILE: 'j8up02v9q_single_sci.fits[0]'
# REFERENCE 'PHOTFLAM' VALUE IS: 6.2963406e-19
#
# Processing file 'j8up02v9q_single_sci.fits'
#    * Primary header:
#      - 'PHOTFLAM' = 6.2963406e-19 found in the primary header.
#      - Data conversion factor based on primary header: 1.0
#
# Done.

# %% [markdown]
# ### Edit this, currently copied.
# In the above command, we instruct photeq to "equalize" all chips of all input images using the first image as a reference. This reference PHOTFLAM value is printed out above, and stored in a reference file.

# %% [markdown]
# ### Stacking images with tweakreg

# %%
astrodrizzle.AstroDrizzle('j8up02*flt.fits',
                          preserve=False,
                          driz_sep_bits='8,1024',
                          driz_sep_wcs=True,
                          driz_sep_scale=0.0996,
                          combine_type='median',
                          driz_cr_snr='5.5 3.5',
                          driz_cr_scale='2.0 1.5',
                          final_fillval=None,
                          final_bits='8,1024',
                          final_wcs=True,
                          final_scale=0.0996)
# Out:
# Setting up logfile :  astrodrizzle.log
# AstroDrizzle Version 3.1.8 (2020-07-27 10:34:52 -0400) started at: 14:47:50.359 (29/08/2022)
#
# ==== Processing Step  Initialization  started at  14:47:50.362 (29/08/2022)
#
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 83.81914675198314  -5.39002696079146
# CRPIX : 533.3795180722892  520.8293172690763
# CD1_1 CD1_2  : -1.851293165171373e-05  2.0560053650305003e-05
# CD2_1 CD2_2  : 2.0560053650305003e-05  1.851293165171373e-05
# NAXIS : 1066  1041
# ********************************************************************************
# *
# *  Estimated memory usage:  up to 357 Mb.
# *  Output image size:       1066 X 1041 pixels.
# *  Output image file:       ~ 12 Mb.
# *  Cores available:         8
# *
# ********************************************************************************
# ==== Processing Step Initialization finished at 14:47:51.698 (29/08/2022)
# ==== Processing Step  Static Mask  started at  14:47:51.701 (29/08/2022)
#
# ==== Processing Step Static Mask finished at 14:47:52.653 (29/08/2022)
# ==== Processing Step  Subtract Sky  started at  14:47:52.65 (29/08/2022)
#
# ***** skymatch started on 2022-08-29 14:47:52.885199
#       Version 1.0.8
#
# 'skymatch' task will apply computed sky differences to input image file(s).
#
# NOTE: Computed sky values WILL NOT be subtracted from image data ('subtractsky'=False).
# 'MDRIZSKY' header keyword will represent sky value *computed* from data.
#
# -----  User specified keywords:  -----
#        Sky Value Keyword:  'MDRIZSKY'
#        Data Units Keyword: 'BUNIT'
#
#
# -----  Input file list:  -----
#
#    **  Input image: 'j8up02usq_flt.fits'
#        EXT: 'SCI',1;	MASK: j8up02usq_skymatch_mask_sci1.fits[0]
#
#    **  Input image: 'j8up02utq_flt.fits'
#        EXT: 'SCI',1;	MASK: j8up02utq_skymatch_mask_sci1.fits[0]
#
#    **  Input image: 'j8up02uuq_flt.fits'
#        EXT: 'SCI',1;	MASK: j8up02uuq_skymatch_mask_sci1.fits[0]
#
#    **  Input image: 'j8up02uvq_flt.fits'
#        EXT: 'SCI',1;	MASK: j8up02uvq_skymatch_mask_sci1.fits[0]
#
#    **  Input image: 'j8up02uwq_flt.fits'
#        EXT: 'SCI',1;	MASK: j8up02uwq_skymatch_mask_sci1.fits[0]
#
#    **  Input image: 'j8up02uyq_flt.fits'
#        EXT: 'SCI',1;	MASK: j8up02uyq_skymatch_mask_sci1.fits[0]
#
#    **  Input image: 'j8up02v0q_flt.fits'
#        EXT: 'SCI',1;	MASK: j8up02v0q_skymatch_mask_sci1.fits[0]
#
#    **  Input image: 'j8up02v5q_flt.fits'
#        EXT: 'SCI',1;	MASK: j8up02v5q_skymatch_mask_sci1.fits[0]
#
#    **  Input image: 'j8up02v7q_flt.fits'
#        EXT: 'SCI',1;	MASK: j8up02v7q_skymatch_mask_sci1.fits[0]
#
#    **  Input image: 'j8up02v9q_flt.fits'
#        EXT: 'SCI',1;	MASK: j8up02v9q_skymatch_mask_sci1.fits[0]
#
# -----  Sky statistics parameters:  -----
#        statistics function: 'median'
#        lower = None
#        upper = None
#        nclip = 5
#        lsigma = 4.0
#        usigma = 4.0
#        binwidth = 0.1
#
# -----  Data->Brightness conversion parameters for input files:  -----
#
#    *   Image: j8up02usq_flt.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 150.0 [s]
#              Conversion factor (data->brightness):  2.666666666666666
#
#    *   Image: j8up02utq_flt.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 150.0 [s]
#              Conversion factor (data->brightness):  2.666666666666666
#
#    *   Image: j8up02uuq_flt.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 150.0 [s]
#              Conversion factor (data->brightness):  2.666666666666666
#
#    *   Image: j8up02uvq_flt.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 150.0 [s]
#              Conversion factor (data->brightness):  2.666666666666666
#
#    *   Image: j8up02uwq_flt.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 400.0 [s]
#              Conversion factor (data->brightness):  0.9999999999999999
#
#    *   Image: j8up02uyq_flt.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 150.0 [s]
#              Conversion factor (data->brightness):  2.666666666666666
#
#    *   Image: j8up02v0q_flt.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 150.0 [s]
#              Conversion factor (data->brightness):  2.666666666666666
#
#    *   Image: j8up02v5q_flt.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 150.0 [s]
#              Conversion factor (data->brightness):  2.666666666666666
#
#    *   Image: j8up02v7q_flt.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 150.0 [s]
#              Conversion factor (data->brightness):  2.666666666666666
#
#    *   Image: j8up02v9q_flt.fits
#        EXT = 'SCI',1
#              Data units type: COUNTS
#              EXPTIME: 150.0 [s]
#              Conversion factor (data->brightness):  2.666666666666666
#
#
# -----  Computing sky values requested image extensions (detector chips):  -----
#
#    *   Image:   'j8up02usq_flt.fits['SCI',1]'  --  SKY = 8959.907552083332 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 3359.97   NEW MDRIZSKY = 3359.97
#    *   Image:   'j8up02utq_flt.fits['SCI',1]'  --  SKY = 7667.268229166665 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 2875.23   NEW MDRIZSKY = 2875.23
#    *   Image:   'j8up02uuq_flt.fits['SCI',1]'  --  SKY = 478.6145833333332 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 179.48   NEW MDRIZSKY = 179.48
#    *   Image:   'j8up02uvq_flt.fits['SCI',1]'  --  SKY = 175.11442057291663 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 65.6679   NEW MDRIZSKY = 65.6679
#    *   Image:   'j8up02uwq_flt.fits['SCI',1]'  --  SKY = 123.11336517333983 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 123.113   NEW MDRIZSKY = 123.113
#    *   Image:   'j8up02uyq_flt.fits['SCI',1]'  --  SKY = 3921.5442708333326 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 1470.58   NEW MDRIZSKY = 1470.58
#    *   Image:   'j8up02v0q_flt.fits['SCI',1]'  --  SKY = 3962.505859374999 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 1485.94   NEW MDRIZSKY = 1485.94
#    *   Image:   'j8up02v5q_flt.fits['SCI',1]'  --  SKY = 1010.2781575520831 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 378.854   NEW MDRIZSKY = 378.854
#    *   Image:   'j8up02v7q_flt.fits['SCI',1]'  --  SKY = 1218.3016764322913 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 456.863   NEW MDRIZSKY = 456.863
#    *   Image:   'j8up02v9q_flt.fits['SCI',1]'  --  SKY = 7606.187499999998 (brightness units)
#        Sky change (data units):
#       - EXT = 'SCI',1   delta(MDRIZSKY) = 2852.32   NEW MDRIZSKY = 2852.32
# ***** skymatch ended on 2022-08-29 14:47:54.591580
# TOTAL RUN TIME: 0:00:01.706381
# ==== Processing Step Subtract Sky finished at 14:47:54.834 (29/08/2022)
# ==== Processing Step  Separate Drizzle  started at  14:47:54.835 (29/08/2022)
#
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 83.81914675198314  -5.39002696079146
# CRPIX : 533.3795180722892  520.8293172690763
# CD1_1 CD1_2  : -1.851293165171373e-05  2.0560053650305003e-05
# CD2_1 CD2_2  : 2.0560053650305003e-05  1.851293165171373e-05
# NAXIS : 1066  1041
# -Generating simple FITS output: j8up02utq_single_sci.fits
# -Generating simple FITS output: j8up02uuq_single_sci.fits
# -Generating simple FITS output: j8up02uvq_single_sci.fits
# -Generating simple FITS output: j8up02v0q_single_sci.fits
# -Generating simple FITS output: j8up02usq_single_sci.fits
# -Generating simple FITS output: j8up02uyq_single_sci.fits
# -Generating simple FITS output: j8up02v5q_single_sci.fits
# -Generating simple FITS output: j8up02uwq_single_sci.fits
# Writing out image to disk: j8up02utq_single_sci.fits
# Writing out image to disk: j8up02uuq_single_sci.fits
# Writing out image to disk: j8up02v0q_single_sci.fits
# Writing out image to disk: j8up02uvq_single_sci.fits
# Writing out image to disk: j8up02usq_single_sci.fits
# Writing out image to disk: j8up02utq_single_wht.fits
# Writing out image to disk: j8up02v5q_single_sci.fits
# Writing out image to disk: j8up02v0q_single_wht.fits
# Writing out image to disk: j8up02uyq_single_sci.fits
# Writing out image to disk: j8up02uwq_single_sci.fits
# Writing out image to disk: j8up02uuq_single_wht.fits
# Writing out image to disk: j8up02usq_single_wht.fits
# Writing out image to disk: j8up02uvq_single_wht.fits
# Writing out image to disk: j8up02v5q_single_wht.fits
# Writing out image to disk: j8up02uyq_single_wht.fits
# Writing out image to disk: j8up02uwq_single_wht.fits
# -Generating simple FITS output: j8up02v7q_single_sci.fits
# -Generating simple FITS output: j8up02v9q_single_sci.fits
# Writing out image to disk: j8up02v9q_single_sci.fits
# Writing out image to disk: j8up02v7q_single_sci.fits
# Writing out image to disk: j8up02v9q_single_wht.fits
# Writing out image to disk: j8up02v7q_single_wht.fits
# ==== Processing Step Separate Drizzle finished at 14:47:58.085 (29/08/2022)
# ==== Processing Step  Create Median  started at  14:47:58.094 (29/08/2022)
#
# reference sky value for image 'j8up02usq_flt.fits' is 3359.9653320312505
# reference sky value for image 'j8up02utq_flt.fits' is 2875.2255859375
# reference sky value for image 'j8up02uuq_flt.fits' is 179.48046875
# reference sky value for image 'j8up02uvq_flt.fits' is 65.66790771484375
# reference sky value for image 'j8up02uwq_flt.fits' is 123.11336517333984
# reference sky value for image 'j8up02uyq_flt.fits' is 1470.5791015625
# reference sky value for image 'j8up02v0q_flt.fits' is 1485.939697265625
# reference sky value for image 'j8up02v5q_flt.fits' is 378.85430908203125
# reference sky value for image 'j8up02v7q_flt.fits' is 456.8631286621093
# reference sky value for image 'j8up02v9q_flt.fits' is 2852.3203125
# Saving output median image to: 'final_med.fits'
# ==== Processing Step Create Median finished at 14:47:58.835 (29/08/2022)
# ==== Processing Step  Blot  started at  14:47:58.836 (29/08/2022)
#
#     Blot: creating blotted image:  j8up02usq_flt.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: j8up02usq_sci1_blt.fits
# Writing out image to disk: j8up02usq_sci1_blt.fits
#     Blot: creating blotted image:  j8up02utq_flt.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: j8up02utq_sci1_blt.fits
# Writing out image to disk: j8up02utq_sci1_blt.fits
#     Blot: creating blotted image:  j8up02uuq_flt.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: j8up02uuq_sci1_blt.fits
# Writing out image to disk: j8up02uuq_sci1_blt.fits
#     Blot: creating blotted image:  j8up02uvq_flt.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: j8up02uvq_sci1_blt.fits
# Writing out image to disk: j8up02uvq_sci1_blt.fits
#     Blot: creating blotted image:  j8up02uwq_flt.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: j8up02uwq_sci1_blt.fits
# Writing out image to disk: j8up02uwq_sci1_blt.fits
#     Blot: creating blotted image:  j8up02uyq_flt.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: j8up02uyq_sci1_blt.fits
# Writing out image to disk: j8up02uyq_sci1_blt.fits
#     Blot: creating blotted image:  j8up02v0q_flt.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: j8up02v0q_sci1_blt.fits
# Writing out image to disk: j8up02v0q_sci1_blt.fits
#     Blot: creating blotted image:  j8up02v5q_flt.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: j8up02v5q_sci1_blt.fits
# Writing out image to disk: j8up02v5q_sci1_blt.fits
#     Blot: creating blotted image:  j8up02v7q_flt.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: j8up02v7q_sci1_blt.fits
# Writing out image to disk: j8up02v7q_sci1_blt.fits
#     Blot: creating blotted image:  j8up02v9q_flt.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: j8up02v9q_sci1_blt.fits
# Writing out image to disk: j8up02v9q_sci1_blt.fits
# ==== Processing Step Blot finished at 14:48:03.819 (29/08/2022)
# ==== Processing Step  Driz_CR  started at  14:48:03.820 (29/08/2022)
#
# Removed old cosmic ray mask file: 'j8up02usq_sci1_crmask.fits'
# Removed old cosmic ray mask file: 'j8up02utq_sci1_crmask.fits'
# Creating output: j8up02usq_sci1_crmask.fits
# Creating output: j8up02utq_sci1_crmask.fits
# Removed old cosmic ray mask file: 'j8up02uvq_sci1_crmask.fits'
# Creating output: j8up02uvq_sci1_crmask.fits
# Removed old cosmic ray mask file: 'j8up02uuq_sci1_crmask.fits'
# Creating output: j8up02uuq_sci1_crmask.fits
# Removed old cosmic ray mask file: 'j8up02uwq_sci1_crmask.fits'
# Creating output: j8up02uwq_sci1_crmask.fits
# Removed old cosmic ray mask file: 'j8up02v0q_sci1_crmask.fits'
# Creating output: j8up02v0q_sci1_crmask.fits
# Removed old cosmic ray mask file: 'j8up02uyq_sci1_crmask.fits'
# Creating output: j8up02uyq_sci1_crmask.fits
# Removed old cosmic ray mask file: 'j8up02v5q_sci1_crmask.fits'
# Creating output: j8up02v5q_sci1_crmask.fits
# Removed old cosmic ray mask file: 'j8up02v7q_sci1_crmask.fits'
# Creating output: j8up02v7q_sci1_crmask.fits
# Removed old cosmic ray mask file: 'j8up02v9q_sci1_crmask.fits'
# Creating output: j8up02v9q_sci1_crmask.fits
# ==== Processing Step Driz_CR finished at 14:48:07.665 (29/08/2022)
# ==== Processing Step  Final Drizzle  started at  14:48:07.692 (29/08/2022)
#
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 83.81914675198314  -5.39002696079146
# CRPIX : 533.3795180722892  520.8293172690763
# CD1_1 CD1_2  : -1.851293165171373e-05  2.0560053650305003e-05
# CD2_1 CD2_2  : 2.0560053650305003e-05  1.851293165171373e-05
# NAXIS : 1066  1041
# -Generating simple FITS output: final_drz_sci.fits
# Writing out image to disk: final_drz_sci.fits
# Writing out image to disk: final_drz_wht.fits
# Writing out image to disk: final_drz_ctx.fits
# ==== Processing Step Final Drizzle finished at 14:48:16.019 (29/08/2022)
#
# AstroDrizzle Version 3.1.8 is finished processing at 14:48:16.020 (29/08/2022).
#
#
#
#    --------------------          --------------------
#                    Step          Elapsed time
#    --------------------          --------------------
#
#          Initialization          1.3354 sec.
#             Static Mask          0.9520 sec.
#            Subtract Sky          2.1805 sec.
#        Separate Drizzle          3.2506 sec.
#           Create Median          0.7408 sec.
#                    Blot          4.9837 sec.
#                 Driz_CR          3.8450 sec.
#           Final Drizzle          8.3270 sec.
#    ====================          ====================
#                   Total          25.6150 sec.
#
# Trailer file written to:  astrodrizzle.log

# %% [markdown]
# Finally, we visualize our beautiful combined image!

# %%
from matplotlib import colors
drz = fits.getdata('final_drz_sci.fits')
plt.figure(figsize=(15, 15))
drz.min(), np.nanmax(drz), drz[drz>0].min()
plt.imshow(drz, cmap='Spectral',norm = colors.LogNorm(1,1e3), origin='lower')

# %% [markdown]
# ## Assignment 2

# %% [markdown]
# The above color scheme is a personal preference. Play around with the color map and scale to highlight the features that appeal to you the most.

# %% [markdown]
# ## Assignment 3
#
# Notice that we only stacked the optical images so far! Repeat the above process for the infrared images, stored in the `infrared` table. Tip: compile the steps above into a function that takes the table and an output directory as its inputs.
#
# How do the images compare? What objects/processes can we learn from in the infrared that are hidden in the optical? What about the other way around?

# %% [markdown]
# ***

# %% [markdown]
# ## About this Notebook
#
# **Author:** Urmila Chadayammuri, Postdoctoral Fellow, Smithsonian Astrophysical Observatory
#
# **Updated On:** 2022-08-24

# %% [markdown]
# ## Citations
# Provide your reader with guidelines on how to cite open source software and other resources in their own published work.
#
# ```
# If you use `astropy` for published research, please cite the
# authors. Follow these links for more information about citing `astropy` and
# `lightkurve`:
#
# * [Citing `astropy`](https://www.astropy.org/acknowledging.html)
#
# ```

# %% [markdown]
# ***

# %% [markdown]
# [Top of Page](#top)
# <img style="float: right;" src="https://raw.githubusercontent.com/spacetelescope/notebooks/master/assets/stsci_pri_combo_mark_horizonal_white_bkgd.png" alt="Space Telescope Logo" width="200px"/>
